# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]

coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = np.transpose(coeff_scaler.fit_transform(np.transpose(pca_coeffs)))

# %%
num_sims = np.shape(locs)[0]
num_ivs = np.shape(locs)[1]
num_coeffs = np.shape(pca_coeffs)[0]
burn_in = 20

# %%
# Reshape
training_data_ip = np.zeros(shape=(num_sims,num_coeffs+num_ivs,burn_in),dtype='double')
training_data_op = np.zeros(shape=(num_sims,num_coeffs+num_ivs,500-burn_in),dtype='double')

for sim in range(num_sims):
    training_data_ip[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim:500*sim+burn_in]
    training_data_ip[sim,-num_ivs:,:] = locs[sim,:,None]
    training_data_op[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim+burn_in:500*(sim+1)]
    training_data_op[sim,-num_ivs:,:] = locs[sim,:,None]

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout, Bidirectional
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_BLSTM_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(num_coeffs+num_ivs,burn_in),name='nat_inputs')
h1 = Bidirectional(LSTM(145,return_sequences=True))(lstm_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = Bidirectional(LSTM(145,return_sequences=True))(h1)
h2 = Dropout(0.2)(h2,training=True)
lstm_outputs = Dense(500-burn_in,activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 14:38:00.965128 139652210804544 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0127 14:38:00.971766 139652210804544 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0127 14:38:00.972941 139652210804544 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0127 14:38:00.973713 139652210804544 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# nat_inputs (InputLayer)      [(None, 42, 20)]          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 42, 290)           192560
# _________________________________________________________________
# dropout (Dropout)            (None, 42, 290)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 42, 290)           505760
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 290)           0
# _________________________________________________________________
# dense (Dense)                (None, 42, 480)           139680
# =================================================================
# Total params: 838,000
# Trainable params: 838,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = True

if train_mode:
    train_history = lstm_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_BLSTM_PT.npy',train_history.history['loss'])
# Out:
# W0120 20:40:27.281677 139731651966784 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5000
# 12/20 [=================>............] - ETA: 1s - loss: 0.2456 - coeff_determination: -53.3017
# Epoch 00001: loss improved from inf to 0.23422, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 2s 104ms/sample - loss: 0.2342 - coeff_determination: -42.7294
# Epoch 2/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.1546 - coeff_determination: -7.1425
# Epoch 00002: loss improved from 0.23422 to 0.14539, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.1454 - coeff_determination: -6.0414
# Epoch 3/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0791 - coeff_determination: -0.4380
# Epoch 00003: loss improved from 0.14539 to 0.07692, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0769 - coeff_determination: -0.4290
# Epoch 4/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0501 - coeff_determination: -0.4761
# Epoch 00004: loss improved from 0.07692 to 0.04687, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0469 - coeff_determination: -0.4689
# Epoch 5/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0357 - coeff_determination: -0.8700
# Epoch 00005: loss improved from 0.04687 to 0.03525, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0352 - coeff_determination: -0.8794
# Epoch 6/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0322 - coeff_determination: -0.9468
# Epoch 00006: loss improved from 0.03525 to 0.03233, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0323 - coeff_determination: -0.9301
# Epoch 7/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0289 - coeff_determination: -0.7257
# Epoch 00007: loss improved from 0.03233 to 0.02941, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0294 - coeff_determination: -0.7662
# Epoch 8/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0268 - coeff_determination: -0.7051
# Epoch 00008: loss improved from 0.02941 to 0.02731, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0273 - coeff_determination: -0.7536
# Epoch 9/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0253 - coeff_determination: -0.8291
# Epoch 00009: loss improved from 0.02731 to 0.02541, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0254 - coeff_determination: -0.8413
# Epoch 10/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0247 - coeff_determination: -0.8402
# Epoch 00010: loss improved from 0.02541 to 0.02457, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0246 - coeff_determination: -0.8216
# Epoch 11/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0238 - coeff_determination: -0.7933
# Epoch 00011: loss improved from 0.02457 to 0.02347, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0235 - coeff_determination: -0.7678
# Epoch 12/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0235 - coeff_determination: -0.7887
# Epoch 00012: loss improved from 0.02347 to 0.02325, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0233 - coeff_determination: -0.7927
# Epoch 13/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0235 - coeff_determination: -0.8208
# Epoch 00013: loss improved from 0.02325 to 0.02295, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0229 - coeff_determination: -0.8052
# Epoch 14/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0227 - coeff_determination: -0.7686
# Epoch 00014: loss improved from 0.02295 to 0.02169, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0217 - coeff_determination: -0.7313
# Epoch 15/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0217 - coeff_determination: -0.7315
# Epoch 00015: loss improved from 0.02169 to 0.02117, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0212 - coeff_determination: -0.7633
# Epoch 16/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0207 - coeff_determination: -0.6883
# Epoch 00016: loss improved from 0.02117 to 0.02058, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0206 - coeff_determination: -0.6863
# Epoch 17/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0202 - coeff_determination: -0.6335
# Epoch 00017: loss improved from 0.02058 to 0.02016, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0202 - coeff_determination: -0.6533
# Epoch 18/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0199 - coeff_determination: -0.6148
# Epoch 00018: loss improved from 0.02016 to 0.01999, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0200 - coeff_determination: -0.6003
# Epoch 19/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0200 - coeff_determination: -0.5576
# Epoch 00019: loss improved from 0.01999 to 0.01979, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0198 - coeff_determination: -0.5325
# Epoch 20/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0197 - coeff_determination: -0.5547
# Epoch 00020: loss improved from 0.01979 to 0.01952, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0195 - coeff_determination: -0.5190
# Epoch 21/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0182 - coeff_determination: -0.5349
# Epoch 00021: loss improved from 0.01952 to 0.01900, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0190 - coeff_determination: -0.4714
# Epoch 22/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0189 - coeff_determination: -0.4704
# Epoch 00022: loss improved from 0.01900 to 0.01875, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0188 - coeff_determination: -0.4275
# Epoch 23/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0187 - coeff_determination: -0.2819
# Epoch 00023: loss improved from 0.01875 to 0.01861, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0186 - coeff_determination: -0.3920
# Epoch 24/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0175 - coeff_determination: -0.3566
# Epoch 00024: loss improved from 0.01861 to 0.01800, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0180 - coeff_determination: -0.3111
# Epoch 25/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0175 - coeff_determination: -0.3393
# Epoch 00025: loss improved from 0.01800 to 0.01788, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0179 - coeff_determination: -0.3191
# Epoch 26/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0176 - coeff_determination: -0.2044
# Epoch 00026: loss improved from 0.01788 to 0.01767, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0177 - coeff_determination: -0.2983
# Epoch 27/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0171 - coeff_determination: -0.2030
# Epoch 00027: loss improved from 0.01767 to 0.01737, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0174 - coeff_determination: -0.2263
# Epoch 28/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0171 - coeff_determination: -0.1801
# Epoch 00028: loss did not improve from 0.01737
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0175 - coeff_determination: -0.2369
# Epoch 29/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0177 - coeff_determination: -0.1753
# Epoch 00029: loss improved from 0.01737 to 0.01731, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0173 - coeff_determination: -0.1721
# Epoch 30/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0164 - coeff_determination: -0.1883
# Epoch 00030: loss improved from 0.01731 to 0.01683, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0168 - coeff_determination: -0.2125
# Epoch 31/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0166 - coeff_determination: -0.1870
# Epoch 00031: loss improved from 0.01683 to 0.01677, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0168 - coeff_determination: -0.1430
# Epoch 32/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0166 - coeff_determination: -0.1574
# Epoch 00032: loss improved from 0.01677 to 0.01664, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0166 - coeff_determination: -0.1220
# Epoch 33/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0165 - coeff_determination: -0.1305
# Epoch 00033: loss improved from 0.01664 to 0.01635, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0164 - coeff_determination: -0.0982
# Epoch 34/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0167 - coeff_determination: -0.0789
# Epoch 00034: loss did not improve from 0.01635
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0164 - coeff_determination: -0.0889
# Epoch 35/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0158 - coeff_determination: -0.1799
# Epoch 00035: loss improved from 0.01635 to 0.01615, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0161 - coeff_determination: -0.1397
# Epoch 36/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0160 - coeff_determination: -0.1117
# Epoch 00036: loss improved from 0.01615 to 0.01592, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0159 - coeff_determination: -0.0610
# Epoch 37/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0155 - coeff_determination: -0.0507
# Epoch 00037: loss improved from 0.01592 to 0.01591, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0159 - coeff_determination: -0.0399
# Epoch 38/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0159 - coeff_determination: -0.0292
# Epoch 00038: loss improved from 0.01591 to 0.01565, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0157 - coeff_determination: -0.0308
# Epoch 39/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0155 - coeff_determination: 0.0236
# Epoch 00039: loss improved from 0.01565 to 0.01561, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0156 - coeff_determination: -0.0555
# Epoch 40/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0159 - coeff_determination: -0.2188
# Epoch 00040: loss did not improve from 0.01561
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0157 - coeff_determination: -0.1234
# Epoch 41/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0149 - coeff_determination: 0.0402
# Epoch 00041: loss improved from 0.01561 to 0.01548, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0155 - coeff_determination: -0.0106
# Epoch 42/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0150 - coeff_determination: 0.1363
# Epoch 00042: loss improved from 0.01548 to 0.01517, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0152 - coeff_determination: 0.0356
# Epoch 43/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0149 - coeff_determination: 0.0922
# Epoch 00043: loss improved from 0.01517 to 0.01498, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0150 - coeff_determination: 0.0276
# Epoch 44/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0148 - coeff_determination: 0.1052
# Epoch 00044: loss improved from 0.01498 to 0.01484, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0148 - coeff_determination: 0.0700
# Epoch 45/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0147 - coeff_determination: 0.0804
# Epoch 00045: loss improved from 0.01484 to 0.01482, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0148 - coeff_determination: 0.0374
# Epoch 46/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0145 - coeff_determination: 0.1827
# Epoch 00046: loss improved from 0.01482 to 0.01454, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0145 - coeff_determination: 0.1233
# Epoch 47/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0146 - coeff_determination: 0.1265
# Epoch 00047: loss improved from 0.01454 to 0.01453, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0145 - coeff_determination: 0.1475
# Epoch 48/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0142 - coeff_determination: 0.0486
# Epoch 00048: loss improved from 0.01453 to 0.01440, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0144 - coeff_determination: 0.0743
# Epoch 49/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0144 - coeff_determination: 0.0754
# Epoch 00049: loss improved from 0.01440 to 0.01434, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0143 - coeff_determination: 0.0838
# Epoch 50/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0147 - coeff_determination: 0.0991
# Epoch 00050: loss improved from 0.01434 to 0.01429, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0143 - coeff_determination: 0.0225
# Epoch 51/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0140 - coeff_determination: 0.1143
# Epoch 00051: loss improved from 0.01429 to 0.01399, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0140 - coeff_determination: 0.1453
# Epoch 52/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0142 - coeff_determination: 0.0686
# Epoch 00052: loss did not improve from 0.01399
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0141 - coeff_determination: 0.0995
# Epoch 53/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0138 - coeff_determination: 0.1447
# Epoch 00053: loss improved from 0.01399 to 0.01380, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0138 - coeff_determination: 0.1467
# Epoch 54/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0138 - coeff_determination: 0.1484
# Epoch 00054: loss improved from 0.01380 to 0.01378, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0138 - coeff_determination: 0.1380
# Epoch 55/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0137 - coeff_determination: 0.0521
# Epoch 00055: loss improved from 0.01378 to 0.01367, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0137 - coeff_determination: 0.1340
# Epoch 56/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0136 - coeff_determination: 0.1353
# Epoch 00056: loss did not improve from 0.01367
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0137 - coeff_determination: 0.1456
# Epoch 57/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0136 - coeff_determination: -0.0659
# Epoch 00057: loss did not improve from 0.01367
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0137 - coeff_determination: -0.0270
# Epoch 58/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0134 - coeff_determination: 0.1671
# Epoch 00058: loss improved from 0.01367 to 0.01338, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0134 - coeff_determination: 0.1653
# Epoch 59/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0135 - coeff_determination: 0.1840
# Epoch 00059: loss did not improve from 0.01338
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0134 - coeff_determination: 0.1985
# Epoch 60/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.1058
# Epoch 00060: loss did not improve from 0.01338
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0134 - coeff_determination: 0.1156
# Epoch 61/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.2312
# Epoch 00061: loss improved from 0.01338 to 0.01319, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0132 - coeff_determination: 0.1853
# Epoch 62/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.1652
# Epoch 00062: loss did not improve from 0.01319
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0132 - coeff_determination: 0.1631
# Epoch 63/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.2100
# Epoch 00063: loss did not improve from 0.01319
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0133 - coeff_determination: 0.1683
# Epoch 64/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0130 - coeff_determination: 0.2018
# Epoch 00064: loss improved from 0.01319 to 0.01299, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0130 - coeff_determination: 0.2516
# Epoch 65/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.1696
# Epoch 00065: loss did not improve from 0.01299
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0130 - coeff_determination: 0.1068
# Epoch 66/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.0390
# Epoch 00066: loss improved from 0.01299 to 0.01296, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0130 - coeff_determination: 0.0950
# Epoch 67/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.2171
# Epoch 00067: loss did not improve from 0.01296
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0130 - coeff_determination: 0.1564
# Epoch 68/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0131 - coeff_determination: 0.1803
# Epoch 00068: loss did not improve from 0.01296
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0132 - coeff_determination: 0.2317
# Epoch 69/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.3675
# Epoch 00069: loss improved from 0.01296 to 0.01267, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0127 - coeff_determination: 0.1922
# Epoch 70/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.1757
# Epoch 00070: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0129 - coeff_determination: 0.1939
# Epoch 71/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.0607
# Epoch 00071: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0127 - coeff_determination: 0.1420
# Epoch 72/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0131 - coeff_determination: 0.2561
# Epoch 00072: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0129 - coeff_determination: 0.2405
# Epoch 73/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.2054
# Epoch 00073: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0128 - coeff_determination: 0.2074
# Epoch 74/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.0429
# Epoch 00074: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0129 - coeff_determination: 0.1329
# Epoch 75/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.1895
# Epoch 00075: loss did not improve from 0.01267
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0127 - coeff_determination: 0.0886
# Epoch 76/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.2300
# Epoch 00076: loss improved from 0.01267 to 0.01263, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0126 - coeff_determination: 0.2642
# Epoch 77/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.2320
# Epoch 00077: loss improved from 0.01263 to 0.01261, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0126 - coeff_determination: 0.2304
# Epoch 78/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.0737
# Epoch 00078: loss did not improve from 0.01261
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0128 - coeff_determination: 0.1587
# Epoch 79/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.1802
# Epoch 00079: loss did not improve from 0.01261
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0127 - coeff_determination: 0.2320
# Epoch 80/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.3298
# Epoch 00080: loss improved from 0.01261 to 0.01234, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0123 - coeff_determination: 0.1978
# Epoch 81/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.1297
# Epoch 00081: loss did not improve from 0.01234
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0125 - coeff_determination: 0.1815
# Epoch 82/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.2458
# Epoch 00082: loss did not improve from 0.01234
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0125 - coeff_determination: 0.2010
# Epoch 83/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2975
# Epoch 00083: loss did not improve from 0.01234
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0125 - coeff_determination: 0.2085
# Epoch 84/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.0845
# Epoch 00084: loss did not improve from 0.01234
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0124 - coeff_determination: 0.1407
# Epoch 85/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.2900
# Epoch 00085: loss did not improve from 0.01234
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0124 - coeff_determination: 0.2751
# Epoch 86/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.2669
# Epoch 00086: loss improved from 0.01234 to 0.01218, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0122 - coeff_determination: 0.2335
# Epoch 87/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.2317
# Epoch 00087: loss improved from 0.01218 to 0.01214, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0121 - coeff_determination: 0.2471
# Epoch 88/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.0817
# Epoch 00088: loss did not improve from 0.01214
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0122 - coeff_determination: 0.1609
# Epoch 89/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.3607
# Epoch 00089: loss improved from 0.01214 to 0.01200, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0120 - coeff_determination: 0.2902
# Epoch 90/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.2517
# Epoch 00090: loss did not improve from 0.01200
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0123 - coeff_determination: 0.2771
# Epoch 91/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.2365
# Epoch 00091: loss improved from 0.01200 to 0.01199, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0120 - coeff_determination: 0.2794
# Epoch 92/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.2069
# Epoch 00092: loss did not improve from 0.01199
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0122 - coeff_determination: 0.2592
# Epoch 93/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.1235
# Epoch 00093: loss did not improve from 0.01199
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0122 - coeff_determination: 0.1703
# Epoch 94/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.3294
# Epoch 00094: loss did not improve from 0.01199
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0121 - coeff_determination: 0.2522
# Epoch 95/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.2994
# Epoch 00095: loss did not improve from 0.01199
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0121 - coeff_determination: 0.3173
# Epoch 96/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.1569
# Epoch 00096: loss did not improve from 0.01199
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0121 - coeff_determination: 0.2375
# Epoch 97/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.1276
# Epoch 00097: loss improved from 0.01199 to 0.01197, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0120 - coeff_determination: 0.1797
# Epoch 98/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.3221
# Epoch 00098: loss improved from 0.01197 to 0.01183, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0118 - coeff_determination: 0.3350
# Epoch 99/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.2601
# Epoch 00099: loss did not improve from 0.01183
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0120 - coeff_determination: 0.2812
# Epoch 100/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.1596
# Epoch 00100: loss did not improve from 0.01183
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0120 - coeff_determination: 0.2404
# Epoch 101/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.3268
# Epoch 00101: loss did not improve from 0.01183
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0122 - coeff_determination: 0.2749
# Epoch 102/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.3007
# Epoch 00102: loss did not improve from 0.01183
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0118 - coeff_determination: 0.2473
# Epoch 103/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.2655
# Epoch 00103: loss did not improve from 0.01183
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0118 - coeff_determination: 0.2480
# Epoch 104/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2455
# Epoch 00104: loss improved from 0.01183 to 0.01167, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0117 - coeff_determination: 0.2677
# Epoch 105/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.3342
# Epoch 00105: loss did not improve from 0.01167
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0119 - coeff_determination: 0.3334
# Epoch 106/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2979
# Epoch 00106: loss improved from 0.01167 to 0.01154, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0115 - coeff_determination: 0.3310
# Epoch 107/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.4042
# Epoch 00107: loss improved from 0.01154 to 0.01153, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0115 - coeff_determination: 0.3231
# Epoch 108/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.3080
# Epoch 00108: loss did not improve from 0.01153
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0117 - coeff_determination: 0.2513
# Epoch 109/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.2646
# Epoch 00109: loss did not improve from 0.01153
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0118 - coeff_determination: 0.3083
# Epoch 110/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2527
# Epoch 00110: loss improved from 0.01153 to 0.01149, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0115 - coeff_determination: 0.3047
# Epoch 111/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.2467
# Epoch 00111: loss did not improve from 0.01149
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0118 - coeff_determination: 0.3054
# Epoch 112/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.3627
# Epoch 00112: loss did not improve from 0.01149
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0117 - coeff_determination: 0.3073
# Epoch 113/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.2600
# Epoch 00113: loss did not improve from 0.01149
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0117 - coeff_determination: 0.2772
# Epoch 114/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.2952
# Epoch 00114: loss improved from 0.01149 to 0.01145, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0114 - coeff_determination: 0.3297
# Epoch 115/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.3674
# Epoch 00115: loss did not improve from 0.01145
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0115 - coeff_determination: 0.3418
# Epoch 116/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.2255
# Epoch 00116: loss improved from 0.01145 to 0.01133, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0113 - coeff_determination: 0.2929
# Epoch 117/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.3578
# Epoch 00117: loss improved from 0.01133 to 0.01129, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0113 - coeff_determination: 0.3868
# Epoch 118/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.4445
# Epoch 00118: loss did not improve from 0.01129
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0113 - coeff_determination: 0.2886
# Epoch 119/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.3826
# Epoch 00119: loss did not improve from 0.01129
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0114 - coeff_determination: 0.2914
# Epoch 120/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.3677
# Epoch 00120: loss improved from 0.01129 to 0.01123, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0112 - coeff_determination: 0.3549
# Epoch 121/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0112 - coeff_determination: 0.0030
# Epoch 00121: loss improved from 0.01123 to 0.01118, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0112 - coeff_determination: 0.1025
# Epoch 122/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.2497
# Epoch 00122: loss improved from 0.01118 to 0.01104, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0110 - coeff_determination: 0.3195
# Epoch 123/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.3291
# Epoch 00123: loss did not improve from 0.01104
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0113 - coeff_determination: 0.2078
# Epoch 124/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.4629
# Epoch 00124: loss did not improve from 0.01104
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0113 - coeff_determination: 0.3628
# Epoch 125/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.2606
# Epoch 00125: loss did not improve from 0.01104
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0113 - coeff_determination: 0.3104
# Epoch 126/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.3788
# Epoch 00126: loss did not improve from 0.01104
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0112 - coeff_determination: 0.3224
# Epoch 127/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.3276
# Epoch 00127: loss did not improve from 0.01104
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0111 - coeff_determination: 0.3203
# Epoch 128/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.4012
# Epoch 00128: loss improved from 0.01104 to 0.01102, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0110 - coeff_determination: 0.4203
# Epoch 129/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.4306
# Epoch 00129: loss improved from 0.01102 to 0.01099, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0110 - coeff_determination: 0.3903
# Epoch 130/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.3171
# Epoch 00130: loss improved from 0.01099 to 0.01091, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0109 - coeff_determination: 0.3606
# Epoch 131/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.2530
# Epoch 00131: loss did not improve from 0.01091
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0111 - coeff_determination: 0.2704
# Epoch 132/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.4529
# Epoch 00132: loss improved from 0.01091 to 0.01080, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0108 - coeff_determination: 0.3799
# Epoch 133/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.3705
# Epoch 00133: loss did not improve from 0.01080
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0109 - coeff_determination: 0.3013
# Epoch 134/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.3250
# Epoch 00134: loss did not improve from 0.01080
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0109 - coeff_determination: 0.3853
# Epoch 135/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.2190
# Epoch 00135: loss did not improve from 0.01080
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0109 - coeff_determination: 0.2815
# Epoch 136/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.4416
# Epoch 00136: loss did not improve from 0.01080
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0109 - coeff_determination: 0.3403
# Epoch 137/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.2352
# Epoch 00137: loss did not improve from 0.01080
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0109 - coeff_determination: 0.3005
# Epoch 138/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.2977
# Epoch 00138: loss improved from 0.01080 to 0.01073, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0107 - coeff_determination: 0.3542
# Epoch 139/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3636
# Epoch 00139: loss improved from 0.01073 to 0.01057, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0106 - coeff_determination: 0.3521
# Epoch 140/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.4367
# Epoch 00140: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0107 - coeff_determination: 0.3951
# Epoch 141/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.2378
# Epoch 00141: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0107 - coeff_determination: 0.2973
# Epoch 142/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.3835
# Epoch 00142: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0107 - coeff_determination: 0.4050
# Epoch 143/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.4369
# Epoch 00143: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0108 - coeff_determination: 0.4303
# Epoch 144/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.4199
# Epoch 00144: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0106 - coeff_determination: 0.3912
# Epoch 145/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3430
# Epoch 00145: loss did not improve from 0.01057
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0106 - coeff_determination: 0.3892
# Epoch 146/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3812
# Epoch 00146: loss improved from 0.01057 to 0.01051, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0105 - coeff_determination: 0.3834
# Epoch 147/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.4337
# Epoch 00147: loss improved from 0.01051 to 0.01041, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0104 - coeff_determination: 0.4208
# Epoch 148/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.4023
# Epoch 00148: loss did not improve from 0.01041
# 20/20 [==============================] - 1s 34ms/sample - loss: 0.0105 - coeff_determination: 0.3868
# Epoch 149/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.4054
# Epoch 00149: loss improved from 0.01041 to 0.01033, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 32ms/sample - loss: 0.0103 - coeff_determination: 0.3867
# Epoch 150/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3816
# Epoch 00150: loss did not improve from 0.01033
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0104 - coeff_determination: 0.3891
# Epoch 151/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3966
# Epoch 00151: loss did not improve from 0.01033
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0105 - coeff_determination: 0.3984
# Epoch 152/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3627
# Epoch 00152: loss did not improve from 0.01033
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0104 - coeff_determination: 0.4227
# Epoch 153/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.4605
# Epoch 00153: loss improved from 0.01033 to 0.01022, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0102 - coeff_determination: 0.4140
# Epoch 154/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.4820
# Epoch 00154: loss did not improve from 0.01022
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0104 - coeff_determination: 0.3962
# Epoch 155/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.4435
# Epoch 00155: loss did not improve from 0.01022
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0105 - coeff_determination: 0.4326
# Epoch 156/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3409
# Epoch 00156: loss did not improve from 0.01022
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0103 - coeff_determination: 0.3611
# Epoch 157/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4459
# Epoch 00157: loss did not improve from 0.01022
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0103 - coeff_determination: 0.4501
# Epoch 158/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3092
# Epoch 00158: loss improved from 0.01022 to 0.01020, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0102 - coeff_determination: 0.3610
# Epoch 159/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.2971
# Epoch 00159: loss did not improve from 0.01020
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0103 - coeff_determination: 0.2973
# Epoch 160/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4466
# Epoch 00160: loss improved from 0.01020 to 0.01020, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0102 - coeff_determination: 0.4501
# Epoch 161/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.5063
# Epoch 00161: loss did not improve from 0.01020
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0104 - coeff_determination: 0.4485
# Epoch 162/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4105
# Epoch 00162: loss improved from 0.01020 to 0.01015, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0101 - coeff_determination: 0.3994
# Epoch 163/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3158
# Epoch 00163: loss did not improve from 0.01015
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0102 - coeff_determination: 0.3906
# Epoch 164/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4143
# Epoch 00164: loss improved from 0.01015 to 0.01011, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0101 - coeff_determination: 0.4364
# Epoch 165/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.4603
# Epoch 00165: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0104 - coeff_determination: 0.4300
# Epoch 166/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4612
# Epoch 00166: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0102 - coeff_determination: 0.3512
# Epoch 167/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4326
# Epoch 00167: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0102 - coeff_determination: 0.4190
# Epoch 168/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3583
# Epoch 00168: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0103 - coeff_determination: 0.4140
# Epoch 169/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3723
# Epoch 00169: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0103 - coeff_determination: 0.3668
# Epoch 170/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4221
# Epoch 00170: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0102 - coeff_determination: 0.4164
# Epoch 171/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.4421
# Epoch 00171: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0102 - coeff_determination: 0.4435
# Epoch 172/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4536
# Epoch 00172: loss did not improve from 0.01011
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0101 - coeff_determination: 0.4156
# Epoch 173/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4330
# ...
# Epoch 04939: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9597
# Epoch 4940/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9549
# Epoch 04940: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9539
# Epoch 4941/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9563
# Epoch 04941: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9552
# Epoch 4942/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9516
# Epoch 04942: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9550
# Epoch 4943/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9619
# Epoch 04943: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9609
# Epoch 4944/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9534
# Epoch 04944: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9525
# Epoch 4945/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9552
# Epoch 04945: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0012 - coeff_determination: 0.9524
# Epoch 4946/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9551
# Epoch 04946: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9569
# Epoch 4947/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9550
# Epoch 04947: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9532
# Epoch 4948/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9545
# Epoch 04948: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0012 - coeff_determination: 0.9568
# Epoch 4949/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9562
# Epoch 04949: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9565
# Epoch 4950/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9540
# Epoch 04950: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0012 - coeff_determination: 0.9544
# Epoch 4951/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0010 - coeff_determination: 0.9589
# Epoch 04951: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9580
# Epoch 4952/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9597
# Epoch 04952: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9572
# Epoch 4953/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9560
# Epoch 04953: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9551
# Epoch 4954/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9553
# Epoch 04954: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0012 - coeff_determination: 0.9564
# Epoch 4955/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9559
# Epoch 04955: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0011 - coeff_determination: 0.9563
# Epoch 4956/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9588
# Epoch 04956: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9594
# Epoch 4957/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9480
# Epoch 04957: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0012 - coeff_determination: 0.9501
# Epoch 4958/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9575
# Epoch 04958: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9579
# Epoch 4959/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9598
# Epoch 04959: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9554
# Epoch 4960/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9541
# Epoch 04960: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9552
# Epoch 4961/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9519
# Epoch 04961: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0012 - coeff_determination: 0.9549
# Epoch 4962/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9612
# Epoch 04962: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0010 - coeff_determination: 0.9584
# Epoch 4963/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9505
# Epoch 04963: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9542
# Epoch 4964/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9575
# Epoch 04964: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9586
# Epoch 4965/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9471
# Epoch 04965: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0012 - coeff_determination: 0.9516
# Epoch 4966/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9572
# Epoch 04966: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9573
# Epoch 4967/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.9536
# Epoch 04967: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0013 - coeff_determination: 0.9521
# Epoch 4968/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9543
# Epoch 04968: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9545
# Epoch 4969/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9570
# Epoch 04969: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9572
# Epoch 4970/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9551
# Epoch 04970: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9568
# Epoch 4971/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9556
# Epoch 04971: loss did not improve from 0.00101
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0011 - coeff_determination: 0.9543
# Epoch 4972/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9558
# Epoch 04972: loss did not improve from 0.00101
# 20/20 [==============================] - 1s 30ms/sample - loss: 0.0012 - coeff_determination: 0.9560
# Epoch 4973/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9626
# Epoch 04973: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0011 - coeff_determination: 0.9597
# Epoch 4974/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9535
# Epoch 04974: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0012 - coeff_determination: 0.9534
# Epoch 4975/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9606
# Epoch 04975: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0010 - coeff_determination: 0.9600
# Epoch 4976/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9583
# Epoch 04976: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0012 - coeff_determination: 0.9544
# Epoch 4977/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9573
# Epoch 04977: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9568
# Epoch 4978/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9581
# Epoch 04978: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9556
# Epoch 4979/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9573
# Epoch 04979: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9582
# Epoch 4980/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9554
# Epoch 04980: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0012 - coeff_determination: 0.9552
# Epoch 4981/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9546
# Epoch 04981: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0011 - coeff_determination: 0.9565
# Epoch 4982/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9565
# Epoch 04982: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9523
# Epoch 4983/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9613
# Epoch 04983: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9579
# Epoch 4984/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9579
# Epoch 04984: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9578
# Epoch 4985/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9556
# Epoch 04985: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9540
# Epoch 4986/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9522
# Epoch 04986: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0012 - coeff_determination: 0.9532
# Epoch 4987/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9564
# Epoch 04987: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0012 - coeff_determination: 0.9572
# Epoch 4988/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9573
# Epoch 04988: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9561
# Epoch 4989/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0010 - coeff_determination: 0.9594
# Epoch 04989: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9576
# Epoch 4990/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0010 - coeff_determination: 0.9608
# Epoch 04990: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0011 - coeff_determination: 0.9580
# Epoch 4991/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9567
# Epoch 04991: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0011 - coeff_determination: 0.9558
# Epoch 4992/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9592
# Epoch 04992: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0011 - coeff_determination: 0.9582
# Epoch 4993/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9560
# Epoch 04993: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9567
# Epoch 4994/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9563
# Epoch 04994: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0012 - coeff_determination: 0.9553
# Epoch 4995/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9564
# Epoch 04995: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0011 - coeff_determination: 0.9567
# Epoch 4996/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9503
# Epoch 04996: loss did not improve from 0.00101
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0012 - coeff_determination: 0.9538
# Epoch 4997/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0010 - coeff_determination: 0.9599
# Epoch 04997: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 25ms/sample - loss: 0.0011 - coeff_determination: 0.9581
# Epoch 4998/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9514
# Epoch 04998: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0011 - coeff_determination: 0.9523
# Epoch 4999/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9514
# Epoch 04999: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0011 - coeff_determination: 0.9531
# Epoch 5000/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9574
# Epoch 05000: loss did not improve from 0.00101
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0012 - coeff_determination: 0.9571

# %%
import matplotlib.pyplot as plt
lstm_model.load_weights(weights_filepath)

# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:64*64,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(1,num_coeffs+num_ivs,500))
test_data[0,0:num_coeffs,:] = np.transpose(true_pca_evol[:,:])

test_data[0,-2,:] = -1.0/2.7
test_data[0,-1,:] = -1.0/4.0

viz = False

mse_val = 0.0
num_inference = 1000
pred_mean = np.zeros_like(test_data)
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[1],np.shape(test_data)[2]))

from time import time

start_time = time()

for inference in range(num_inference):
    
    pred_pca = lstm_model.predict(test_data[:,:,:burn_in])
    pred_pca = np.concatenate((test_data[:,:,:burn_in],pred_pca),axis=-1)
    
    pred_pca_array[inference,:,:] = pred_pca[0,:,:]
    mse_val = mse_val + np.sum((pred_pca-test_data)**2)
    pred_mean = pred_mean + pred_pca
    
    if viz:
    
        fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
        ax[0,0].plot(test_data[0,0,:],label='True')
        ax[0,0].plot(pred_pca[0,0,:],label='Predicted')
        ax[0,0].set_title('Mode 1')


        ax[1,0].plot(test_data[0,1,:],label='True')
        ax[1,0].plot(pred_pca[0,1,:],label='Predicted')
        ax[1,0].set_title('Mode 2')

        ax[0,1].plot(test_data[0,2,:],label='True')
        ax[0,1].plot(pred_pca[0,2,:],label='Predicted')
        ax[0,1].set_title('Mode 3')

        ax[1,1].plot(test_data[0,3,:],label='True')
        ax[1,1].plot(pred_pca[0,3,:],label='Predicted')
        ax[1,1].set_title('Mode 4')

        plt.tight_layout()
        plt.legend()
        plt.show()

        # Plotting some contours
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-2].reshape(64,64)

        pred_rb = np.transpose(pred_pca[0,:num_modes,:])
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-2].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()
        
end_time = time()

# %%
print('Elapsed time per inference:',(end_time-start_time)/num_inference)
# Out:
# Elapsed time per inference: 0.01609032154083252

# %%
pred_mean = pred_mean/num_inference

# Calculate standard deviation
pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[0,:,:])**2,axis=0)/(num_inference-1))
        
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[0,0,:],label='True')
ax[0,0].plot(pred_mean[0,0,:],label='Predicted mean')
ax[0,0].fill_between(np.arange(500),pred_mean[0,0,:]+pred_sdev[0,:],pred_mean[0,0,:]-pred_sdev[0,:],label='1 std')
ax[0,0].set_title('Mode 1')



ax[1,0].plot(test_data[0,1,:],label='True')
ax[1,0].plot(pred_mean[0,1,:],label='Predicted mean')
ax[1,0].fill_between(np.arange(500),pred_mean[0,1,:]+pred_sdev[1,:],pred_mean[0,1,:]-pred_sdev[1,:],label='1 std')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[0,2,:],label='True')
ax[0,1].plot(pred_mean[0,2,:],label='Predicted mean')
ax[0,1].fill_between(np.arange(500),pred_mean[0,2,:]+pred_sdev[2,:],pred_mean[0,2,:]-pred_sdev[2,:],label='1 std')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[0,3,:],label='True')
ax[1,1].plot(pred_mean[0,3,:],label='Predicted mean')
ax[1,1].fill_between(np.arange(500),pred_mean[0,3,:]+pred_sdev[3,:],pred_mean[0,3,:]-pred_sdev[3,:],label='1 std')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
np.save('../Figures/NAT_BLSTM_PT_Mean.npy',pred_mean)
np.save('../Figures/NAT_BLSTM_PT_SD.npy',pred_sdev)
