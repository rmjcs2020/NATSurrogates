# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]
coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = coeff_scaler.fit_transform(np.transpose(pca_coeffs))

# %%
# The total shape is large due to multiple simulations
num_samples_total = np.shape(pca_coeffs_scaled)[0]
num_sims = int(num_samples_total/500)
pca_coeffs_scaled = np.reshape(pca_coeffs_scaled,newshape=(num_sims,500,40))

# %%
state_len = np.shape(pca_coeffs_scaled)[-1]
seq_num = 20

num_samples = 500-seq_num-1
input_data = np.zeros(shape=(num_sims*num_samples,seq_num,state_len+2))
output_data = np.zeros(shape=(num_sims*num_samples,state_len))

batch_num = 0
for simnum in range(num_sims):            
    sub_data = pca_coeffs_scaled[simnum,:,:]
    
    for t in range(np.shape(sub_data)[0]-seq_num-1):
        input_seq = sub_data[t:t+seq_num,:]
        output_seq = sub_data[t+seq_num,:]
        input_data[batch_num,:,:state_len] = input_seq[None,:,:state_len]
        input_data[batch_num,:,-2] = locs[simnum,0]
        input_data[batch_num,:,-1] = locs[simnum,1]
        
        output_data[batch_num,:] = output_seq[:]
        batch_num = batch_num + 1

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'AT_LSTM_TP.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(seq_num,state_len+2),name='at_inputs')
h1 = LSTM(169,return_sequences=True)(lstm_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = LSTM(169,return_sequences=False)(h1)
h2 = Dropout(0.2)(h2,training=True)
lstm_outputs = Dense(state_len,activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)
   
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 12:39:11.050356 139980352894784 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# at_inputs (InputLayer)       [(None, 20, 42)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 169)           143312
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 169)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 169)               229164
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 169)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                6800
# =================================================================
# Total params: 379,276
# Trainable params: 379,276
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 500
batch_size = 128
train_mode = False

if train_mode:
    train_history = lstm_model.fit(x=input_data, y=output_data, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('AT_LSTM_TP.npy',train_history.history['loss'])
# Out:
# W0120 21:18:39.037146 140169672333120 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0642 - coeff_determination: -1.4821
# Epoch 00001: loss improved from inf to 0.06316, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 325us/sample - loss: 0.0632 - coeff_determination: -1.4528
# Epoch 2/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0200 - coeff_determination: -0.4515
# Epoch 00002: loss improved from 0.06316 to 0.01994, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0199 - coeff_determination: -0.4518
# Epoch 3/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0153 - coeff_determination: -0.4154
# Epoch 00003: loss improved from 0.01994 to 0.01528, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0153 - coeff_determination: -0.4137
# Epoch 4/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0124 - coeff_determination: -0.1980
# Epoch 00004: loss improved from 0.01528 to 0.01232, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0123 - coeff_determination: -0.1943
# Epoch 5/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.0389
# Epoch 00005: loss improved from 0.01232 to 0.01017, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0102 - coeff_determination: 0.0409
# Epoch 6/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0087 - coeff_determination: 0.1998
# Epoch 00006: loss improved from 0.01017 to 0.00867, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0087 - coeff_determination: 0.2012
# Epoch 7/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0077 - coeff_determination: 0.2898
# Epoch 00007: loss improved from 0.00867 to 0.00773, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0077 - coeff_determination: 0.2909
# Epoch 8/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0070 - coeff_determination: 0.3509
# Epoch 00008: loss improved from 0.00773 to 0.00701, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 273us/sample - loss: 0.0070 - coeff_determination: 0.3521
# Epoch 9/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0064 - coeff_determination: 0.4047
# Epoch 00009: loss improved from 0.00701 to 0.00644, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0064 - coeff_determination: 0.4047
# Epoch 10/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0061 - coeff_determination: 0.4362
# Epoch 00010: loss improved from 0.00644 to 0.00609, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0061 - coeff_determination: 0.4357
# Epoch 11/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0057 - coeff_determination: 0.4722
# Epoch 00011: loss improved from 0.00609 to 0.00567, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0057 - coeff_determination: 0.4732
# Epoch 12/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0054 - coeff_determination: 0.5031
# Epoch 00012: loss improved from 0.00567 to 0.00537, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 2s 260us/sample - loss: 0.0054 - coeff_determination: 0.5031
# Epoch 13/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0051 - coeff_determination: 0.5227
# Epoch 00013: loss improved from 0.00537 to 0.00513, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0051 - coeff_determination: 0.5224
# Epoch 14/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0049 - coeff_determination: 0.5487
# Epoch 00014: loss improved from 0.00513 to 0.00484, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0048 - coeff_determination: 0.5491
# Epoch 15/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0046 - coeff_determination: 0.5658
# Epoch 00015: loss improved from 0.00484 to 0.00464, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 271us/sample - loss: 0.0046 - coeff_determination: 0.5656
# Epoch 16/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0045 - coeff_determination: 0.5840
# Epoch 00016: loss improved from 0.00464 to 0.00445, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 274us/sample - loss: 0.0044 - coeff_determination: 0.5844
# Epoch 17/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0043 - coeff_determination: 0.5989
# Epoch 00017: loss improved from 0.00445 to 0.00429, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0043 - coeff_determination: 0.5983
# Epoch 18/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.6178
# Epoch 00018: loss improved from 0.00429 to 0.00409, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 272us/sample - loss: 0.0041 - coeff_determination: 0.6174
# Epoch 19/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0039 - coeff_determination: 0.6316
# Epoch 00019: loss improved from 0.00409 to 0.00393, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 275us/sample - loss: 0.0039 - coeff_determination: 0.6317
# Epoch 20/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.6454
# Epoch 00020: loss improved from 0.00393 to 0.00379, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0038 - coeff_determination: 0.6454
# Epoch 21/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0037 - coeff_determination: 0.6574
# Epoch 00021: loss improved from 0.00379 to 0.00366, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0037 - coeff_determination: 0.6576
# Epoch 22/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0036 - coeff_determination: 0.6607
# Epoch 00022: loss improved from 0.00366 to 0.00360, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 281us/sample - loss: 0.0036 - coeff_determination: 0.6613
# Epoch 23/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0035 - coeff_determination: 0.6728
# Epoch 00023: loss improved from 0.00360 to 0.00349, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0035 - coeff_determination: 0.6730
# Epoch 24/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0033 - coeff_determination: 0.6874
# Epoch 00024: loss improved from 0.00349 to 0.00333, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0033 - coeff_determination: 0.6875
# Epoch 25/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0032 - coeff_determination: 0.6973
# Epoch 00025: loss improved from 0.00333 to 0.00322, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 285us/sample - loss: 0.0032 - coeff_determination: 0.6972
# Epoch 26/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0031 - coeff_determination: 0.7047
# Epoch 00026: loss improved from 0.00322 to 0.00314, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 291us/sample - loss: 0.0031 - coeff_determination: 0.7056
# Epoch 27/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0030 - coeff_determination: 0.7130
# Epoch 00027: loss improved from 0.00314 to 0.00304, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 290us/sample - loss: 0.0030 - coeff_determination: 0.7130
# Epoch 28/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0029 - coeff_determination: 0.7258
# Epoch 00028: loss improved from 0.00304 to 0.00293, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 293us/sample - loss: 0.0029 - coeff_determination: 0.7260
# Epoch 29/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0029 - coeff_determination: 0.7314
# Epoch 00029: loss improved from 0.00293 to 0.00286, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0029 - coeff_determination: 0.7314
# Epoch 30/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0028 - coeff_determination: 0.7401
# Epoch 00030: loss improved from 0.00286 to 0.00277, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 2s 260us/sample - loss: 0.0028 - coeff_determination: 0.7402
# Epoch 31/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0027 - coeff_determination: 0.7470
# Epoch 00031: loss improved from 0.00277 to 0.00269, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0027 - coeff_determination: 0.7473
# Epoch 32/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0026 - coeff_determination: 0.7549
# Epoch 00032: loss improved from 0.00269 to 0.00261, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0026 - coeff_determination: 0.7547
# Epoch 33/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.7616
# Epoch 00033: loss improved from 0.00261 to 0.00254, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0025 - coeff_determination: 0.7618
# Epoch 34/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.7672
# Epoch 00034: loss improved from 0.00254 to 0.00248, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0025 - coeff_determination: 0.7676
# Epoch 35/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.7735
# Epoch 00035: loss improved from 0.00248 to 0.00242, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 271us/sample - loss: 0.0024 - coeff_determination: 0.7732
# Epoch 36/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.7805
# Epoch 00036: loss improved from 0.00242 to 0.00235, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0023 - coeff_determination: 0.7802
# Epoch 37/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.7869
# Epoch 00037: loss improved from 0.00235 to 0.00228, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0023 - coeff_determination: 0.7871
# Epoch 38/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.7916
# Epoch 00038: loss improved from 0.00228 to 0.00222, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0022 - coeff_determination: 0.7920
# Epoch 39/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.7994
# Epoch 00039: loss improved from 0.00222 to 0.00215, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0022 - coeff_determination: 0.7989
# Epoch 40/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0021 - coeff_determination: 0.8039
# Epoch 00040: loss improved from 0.00215 to 0.00210, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0021 - coeff_determination: 0.8043
# Epoch 41/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0021 - coeff_determination: 0.8084
# Epoch 00041: loss improved from 0.00210 to 0.00205, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0021 - coeff_determination: 0.8083
# Epoch 42/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.8151
# Epoch 00042: loss improved from 0.00205 to 0.00198, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 2s 259us/sample - loss: 0.0020 - coeff_determination: 0.8150
# Epoch 43/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.8182
# Epoch 00043: loss improved from 0.00198 to 0.00195, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0020 - coeff_determination: 0.8182
# Epoch 44/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8223
# Epoch 00044: loss improved from 0.00195 to 0.00191, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0019 - coeff_determination: 0.8223
# Epoch 45/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8272
# Epoch 00045: loss improved from 0.00191 to 0.00186, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0019 - coeff_determination: 0.8274
# Epoch 46/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0018 - coeff_determination: 0.8303
# Epoch 00046: loss improved from 0.00186 to 0.00183, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0018 - coeff_determination: 0.8305
# Epoch 47/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0018 - coeff_determination: 0.8364
# Epoch 00047: loss improved from 0.00183 to 0.00177, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0018 - coeff_determination: 0.8364
# Epoch 48/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8392
# Epoch 00048: loss improved from 0.00177 to 0.00173, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0017 - coeff_determination: 0.8392
# Epoch 49/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8427
# Epoch 00049: loss improved from 0.00173 to 0.00170, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0017 - coeff_determination: 0.8426
# Epoch 50/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8461
# Epoch 00050: loss improved from 0.00170 to 0.00167, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0017 - coeff_determination: 0.8459
# Epoch 51/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8492
# Epoch 00051: loss improved from 0.00167 to 0.00164, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0016 - coeff_determination: 0.8493
# Epoch 52/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8506
# Epoch 00052: loss improved from 0.00164 to 0.00162, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0016 - coeff_determination: 0.8505
# Epoch 53/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8540
# Epoch 00053: loss improved from 0.00162 to 0.00159, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 273us/sample - loss: 0.0016 - coeff_determination: 0.8539
# Epoch 54/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8562
# Epoch 00054: loss improved from 0.00159 to 0.00157, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0016 - coeff_determination: 0.8562
# Epoch 55/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8579
# Epoch 00055: loss improved from 0.00157 to 0.00155, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0015 - coeff_determination: 0.8578
# Epoch 56/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8598
# Epoch 00056: loss improved from 0.00155 to 0.00153, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0015 - coeff_determination: 0.8599
# Epoch 57/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8622
# Epoch 00057: loss improved from 0.00153 to 0.00151, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 261us/sample - loss: 0.0015 - coeff_determination: 0.8623
# Epoch 58/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8633
# Epoch 00058: loss improved from 0.00151 to 0.00149, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0015 - coeff_determination: 0.8636
# Epoch 59/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8664
# Epoch 00059: loss improved from 0.00149 to 0.00146, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0015 - coeff_determination: 0.8666
# Epoch 60/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8681
# Epoch 00060: loss improved from 0.00146 to 0.00145, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 4s 372us/sample - loss: 0.0014 - coeff_determination: 0.8681
# Epoch 61/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8689
# Epoch 00061: loss improved from 0.00145 to 0.00144, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 291us/sample - loss: 0.0014 - coeff_determination: 0.8689
# Epoch 62/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8718
# Epoch 00062: loss improved from 0.00144 to 0.00141, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 290us/sample - loss: 0.0014 - coeff_determination: 0.8718
# Epoch 63/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8721
# Epoch 00063: loss improved from 0.00141 to 0.00141, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 296us/sample - loss: 0.0014 - coeff_determination: 0.8722
# Epoch 64/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8745
# Epoch 00064: loss improved from 0.00141 to 0.00138, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 288us/sample - loss: 0.0014 - coeff_determination: 0.8746
# Epoch 65/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8753
# Epoch 00065: loss improved from 0.00138 to 0.00138, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 292us/sample - loss: 0.0014 - coeff_determination: 0.8752
# Epoch 66/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8765
# Epoch 00066: loss improved from 0.00138 to 0.00137, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 280us/sample - loss: 0.0014 - coeff_determination: 0.8765
# Epoch 67/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8761
# Epoch 00067: loss did not improve from 0.00137
# 9580/9580 [==============================] - 3s 281us/sample - loss: 0.0014 - coeff_determination: 0.8760
# Epoch 68/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8787
# Epoch 00068: loss improved from 0.00137 to 0.00135, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0013 - coeff_determination: 0.8783
# Epoch 69/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8791
# Epoch 00069: loss improved from 0.00135 to 0.00134, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 280us/sample - loss: 0.0013 - coeff_determination: 0.8790
# Epoch 70/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8807
# Epoch 00070: loss improved from 0.00134 to 0.00132, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0013 - coeff_determination: 0.8807
# Epoch 71/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8812
# Epoch 00071: loss improved from 0.00132 to 0.00132, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0013 - coeff_determination: 0.8811
# Epoch 72/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8828
# Epoch 00072: loss improved from 0.00132 to 0.00130, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0013 - coeff_determination: 0.8827
# Epoch 73/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8816
# Epoch 00073: loss did not improve from 0.00130
# 9580/9580 [==============================] - 3s 281us/sample - loss: 0.0013 - coeff_determination: 0.8817
# Epoch 74/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8832
# Epoch 00074: loss improved from 0.00130 to 0.00130, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 281us/sample - loss: 0.0013 - coeff_determination: 0.8833
# Epoch 75/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8837
# Epoch 00075: loss improved from 0.00130 to 0.00129, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0013 - coeff_determination: 0.8837
# Epoch 76/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8839
# Epoch 00076: loss did not improve from 0.00129
# 9580/9580 [==============================] - 3s 289us/sample - loss: 0.0013 - coeff_determination: 0.8838
# Epoch 77/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8852
# Epoch 00077: loss improved from 0.00129 to 0.00128, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0013 - coeff_determination: 0.8852
# Epoch 78/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8869
# Epoch 00078: loss improved from 0.00128 to 0.00126, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0013 - coeff_determination: 0.8872
# Epoch 79/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8853
# Epoch 00079: loss did not improve from 0.00126
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0013 - coeff_determination: 0.8853
# Epoch 80/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8867
# Epoch 00080: loss did not improve from 0.00126
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0013 - coeff_determination: 0.8865
# Epoch 81/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8867
# Epoch 00081: loss did not improve from 0.00126
# 9580/9580 [==============================] - 3s 293us/sample - loss: 0.0013 - coeff_determination: 0.8868
# Epoch 82/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8879
# Epoch 00082: loss improved from 0.00126 to 0.00125, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0013 - coeff_determination: 0.8879
# Epoch 83/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8878
# Epoch 00083: loss improved from 0.00125 to 0.00125, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 292us/sample - loss: 0.0013 - coeff_determination: 0.8879
# Epoch 84/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8878
# Epoch 00084: loss did not improve from 0.00125
# 9580/9580 [==============================] - 3s 286us/sample - loss: 0.0013 - coeff_determination: 0.8876
# Epoch 85/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8883
# Epoch 00085: loss improved from 0.00125 to 0.00125, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8884
# Epoch 86/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8878
# Epoch 00086: loss did not improve from 0.00125
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0013 - coeff_determination: 0.8880
# Epoch 87/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8895
# Epoch 00087: loss improved from 0.00125 to 0.00124, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0012 - coeff_determination: 0.8892
# Epoch 88/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8883
# Epoch 00088: loss did not improve from 0.00124
# 9580/9580 [==============================] - 3s 312us/sample - loss: 0.0012 - coeff_determination: 0.8884
# Epoch 89/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8889
# Epoch 00089: loss did not improve from 0.00124
# 9580/9580 [==============================] - 3s 282us/sample - loss: 0.0012 - coeff_determination: 0.8890
# Epoch 90/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8904
# Epoch 00090: loss improved from 0.00124 to 0.00123, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8901
# Epoch 91/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8897
# Epoch 00091: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 278us/sample - loss: 0.0012 - coeff_determination: 0.8896
# Epoch 92/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8893
# Epoch 00092: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 275us/sample - loss: 0.0012 - coeff_determination: 0.8889
# Epoch 93/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8886
# Epoch 00093: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 274us/sample - loss: 0.0012 - coeff_determination: 0.8887
# Epoch 94/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8904
# Epoch 00094: loss improved from 0.00123 to 0.00123, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8904
# Epoch 95/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8896
# Epoch 00095: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 275us/sample - loss: 0.0012 - coeff_determination: 0.8896
# Epoch 96/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8896
# Epoch 00096: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0012 - coeff_determination: 0.8898
# Epoch 97/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8888
# Epoch 00097: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 274us/sample - loss: 0.0012 - coeff_determination: 0.8889
# Epoch 98/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8903
# Epoch 00098: loss did not improve from 0.00123
# 9580/9580 [==============================] - 3s 277us/sample - loss: 0.0012 - coeff_determination: 0.8900
# Epoch 99/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8918
# Epoch 00099: loss improved from 0.00123 to 0.00121, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 277us/sample - loss: 0.0012 - coeff_determination: 0.8919
# Epoch 100/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8907
# Epoch 00100: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8906
# Epoch 101/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8913
# Epoch 00101: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0012 - coeff_determination: 0.8915
# Epoch 102/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8922
# Epoch 00102: loss improved from 0.00121 to 0.00121, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8922
# Epoch 103/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8923
# Epoch 00103: loss improved from 0.00121 to 0.00121, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0012 - coeff_determination: 0.8925
# Epoch 104/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8905
# Epoch 00104: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 275us/sample - loss: 0.0012 - coeff_determination: 0.8907
# Epoch 105/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8904
# Epoch 00105: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8903
# Epoch 106/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8911
# Epoch 00106: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0012 - coeff_determination: 0.8910
# Epoch 107/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8915
# Epoch 00107: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 278us/sample - loss: 0.0012 - coeff_determination: 0.8915
# Epoch 108/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8915
# Epoch 00108: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8916
# Epoch 109/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8908
# Epoch 00109: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 277us/sample - loss: 0.0012 - coeff_determination: 0.8906
# Epoch 110/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8907
# Epoch 00110: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 277us/sample - loss: 0.0012 - coeff_determination: 0.8908
# Epoch 111/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8920
# Epoch 00111: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8919
# Epoch 112/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8926
# Epoch 00112: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 275us/sample - loss: 0.0012 - coeff_determination: 0.8926
# Epoch 113/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8922
# Epoch 00113: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 278us/sample - loss: 0.0012 - coeff_determination: 0.8921
# Epoch 114/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8925
# Epoch 00114: loss did not improve from 0.00121
# 9580/9580 [==============================] - 3s 279us/sample - loss: 0.0012 - coeff_determination: 0.8926
# Epoch 115/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8930
# Epoch 00115: loss improved from 0.00121 to 0.00120, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8931
# Epoch 116/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8918
# Epoch 00116: loss did not improve from 0.00120
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0012 - coeff_determination: 0.8920
# Epoch 117/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8937
# Epoch 00117: loss improved from 0.00120 to 0.00119, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0012 - coeff_determination: 0.8937
# Epoch 118/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8925
# Epoch 00118: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8927
# Epoch 119/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8921
# Epoch 00119: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0012 - coeff_determination: 0.8920
# Epoch 120/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8927
# Epoch 00120: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8925
# Epoch 121/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8932
# Epoch 00121: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0012 - coeff_determination: 0.8930
# Epoch 122/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8924
# Epoch 00122: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8922
# Epoch 123/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8916
# Epoch 00123: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0012 - coeff_determination: 0.8915
# Epoch 124/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8936
# Epoch 00124: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8932
# Epoch 125/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8936
# Epoch 00125: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 261us/sample - loss: 0.0012 - coeff_determination: 0.8936
# Epoch 126/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8929
# Epoch 00126: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8929
# Epoch 127/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8928
# Epoch 00127: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8928
# Epoch 128/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8921
# Epoch 00128: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8920
# Epoch 129/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8940
# Epoch 00129: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8937
# Epoch 130/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8942
# Epoch 00130: loss improved from 0.00119 to 0.00119, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8944
# Epoch 131/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8938
# Epoch 00131: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8939
# Epoch 132/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8938
# Epoch 00132: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8937
# Epoch 133/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 00133: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8936
# Epoch 134/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8923
# Epoch 00134: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 285us/sample - loss: 0.0012 - coeff_determination: 0.8920
# Epoch 135/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8934
# Epoch 00135: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 136/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8936
# Epoch 00136: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8935
# Epoch 137/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8941
# Epoch 00137: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8941
# Epoch 138/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8940
# Epoch 00138: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8940
# Epoch 139/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8945
# Epoch 00139: loss improved from 0.00119 to 0.00119, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8946
# Epoch 140/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8921
# Epoch 00140: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0012 - coeff_determination: 0.8922
# Epoch 141/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8929
# Epoch 00141: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8928
# Epoch 142/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8946
# Epoch 00142: loss improved from 0.00119 to 0.00119, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8946
# Epoch 143/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8935
# Epoch 00143: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 144/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8928
# Epoch 00144: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8927
# Epoch 145/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8926
# Epoch 00145: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0012 - coeff_determination: 0.8924
# Epoch 146/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8930
# Epoch 00146: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8930
# Epoch 147/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8941
# Epoch 00147: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0012 - coeff_determination: 0.8940
# Epoch 148/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8941
# Epoch 00148: loss did not improve from 0.00119
# 9580/9580 [==============================] - 3s 280us/sample - loss: 0.0012 - coeff_determination: 0.8943
# Epoch 149/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8948
# Epoch 00149: loss improved from 0.00119 to 0.00118, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8949
# Epoch 150/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8932
# Epoch 00150: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 151/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8924
# Epoch 00151: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 281us/sample - loss: 0.0012 - coeff_determination: 0.8923
# Epoch 152/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 00152: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 153/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8945
# Epoch 00153: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8944
# Epoch 154/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8943
# Epoch 00154: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8943
# Epoch 155/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8938
# Epoch 00155: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 262us/sample - loss: 0.0012 - coeff_determination: 0.8938
# Epoch 156/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8948
# Epoch 00156: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0012 - coeff_determination: 0.8950
# Epoch 157/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8943
# Epoch 00157: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 264us/sample - loss: 0.0012 - coeff_determination: 0.8944
# Epoch 158/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8945
# Epoch 00158: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8946
# Epoch 159/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8942
# Epoch 00159: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8939
# Epoch 160/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8939
# Epoch 00160: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8941
# Epoch 161/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8943
# Epoch 00161: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8944
# Epoch 162/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8949
# Epoch 00162: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8949
# Epoch 163/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8933
# Epoch 00163: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0012 - coeff_determination: 0.8934
# Epoch 164/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8934
# Epoch 00164: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8932
# Epoch 165/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8949
# Epoch 00165: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8949
# Epoch 166/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8937
# Epoch 00166: loss did not improve from 0.00118
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8938
# Epoch 167/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8957
# Epoch 00167: loss improved from 0.00118 to 0.00117, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0012 - coeff_determination: 0.8956
# Epoch 168/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8951
# Epoch 00168: loss did not improve from 0.00117
# ...
# Epoch 441/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00441: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 442/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 00442: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 285us/sample - loss: 0.0012 - coeff_determination: 0.8977
# Epoch 443/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8989
# Epoch 00443: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0011 - coeff_determination: 0.8992
# Epoch 444/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8976
# Epoch 00444: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 285us/sample - loss: 0.0012 - coeff_determination: 0.8977
# Epoch 445/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8988
# Epoch 00445: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 286us/sample - loss: 0.0011 - coeff_determination: 0.8989
# Epoch 446/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 00446: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 447/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8974
# Epoch 00447: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0012 - coeff_determination: 0.8972
# Epoch 448/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8989
# Epoch 00448: loss did not improve from 0.00114
# 9580/9580 [==============================] - 3s 288us/sample - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 449/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8999
# Epoch 00449: loss improved from 0.00114 to 0.00113, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 288us/sample - loss: 0.0011 - coeff_determination: 0.8999
# Epoch 450/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 00450: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 286us/sample - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 451/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 00451: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 287us/sample - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 452/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8991
# Epoch 00452: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 283us/sample - loss: 0.0011 - coeff_determination: 0.8988
# Epoch 453/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8971
# Epoch 00453: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 290us/sample - loss: 0.0012 - coeff_determination: 0.8969
# Epoch 454/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 00454: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 455/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8981
# Epoch 00455: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 263us/sample - loss: 0.0012 - coeff_determination: 0.8981
# Epoch 456/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00456: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 457/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8982
# Epoch 00457: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8982
# Epoch 458/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 00458: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0012 - coeff_determination: 0.8979
# Epoch 459/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 00459: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 460/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00460: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 461/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8981
# Epoch 00461: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 462/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8977
# Epoch 00462: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 278us/sample - loss: 0.0012 - coeff_determination: 0.8977
# Epoch 463/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8970
# Epoch 00463: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 273us/sample - loss: 0.0012 - coeff_determination: 0.8969
# Epoch 464/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8975
# Epoch 00464: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 465/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 00465: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0012 - coeff_determination: 0.8977
# Epoch 466/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8975
# Epoch 00466: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8974
# Epoch 467/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 00467: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 468/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8976
# Epoch 00468: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8976
# Epoch 469/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 00469: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 470/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 00470: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 471/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8984
# Epoch 00471: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 472/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 00472: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 473/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8983
# Epoch 00473: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0012 - coeff_determination: 0.8982
# Epoch 474/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 00474: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8984
# Epoch 475/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8993
# Epoch 00475: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0011 - coeff_determination: 0.8993
# Epoch 476/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00476: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 477/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00477: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 478/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8989
# Epoch 00478: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 479/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9002
# Epoch 00479: loss improved from 0.00113 to 0.00113, saving model to AT_LSTM_TP.h5
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.9001
# Epoch 480/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 00480: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 271us/sample - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 481/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 00481: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 271us/sample - loss: 0.0011 - coeff_determination: 0.8981
# Epoch 482/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 00482: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 276us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 483/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8981
# Epoch 00483: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 272us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 484/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 00484: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 270us/sample - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 485/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8991
# Epoch 00485: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 267us/sample - loss: 0.0011 - coeff_determination: 0.8992
# Epoch 486/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8992
# Epoch 00486: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0011 - coeff_determination: 0.8994
# Epoch 487/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8994
# Epoch 00487: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8995
# Epoch 488/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8978
# Epoch 00488: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8979
# Epoch 489/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8976
# Epoch 00489: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8976
# Epoch 490/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8979
# Epoch 00490: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 491/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00491: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0012 - coeff_determination: 0.8980
# Epoch 492/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8984
# Epoch 00492: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 266us/sample - loss: 0.0011 - coeff_determination: 0.8984
# Epoch 493/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8986
# Epoch 00493: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 265us/sample - loss: 0.0011 - coeff_determination: 0.8988
# Epoch 494/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8982
# Epoch 00494: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 284us/sample - loss: 0.0012 - coeff_determination: 0.8979
# Epoch 495/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8983
# Epoch 00495: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 341us/sample - loss: 0.0011 - coeff_determination: 0.8982
# Epoch 496/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 00496: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 307us/sample - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 497/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8996
# Epoch 00497: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8993
# Epoch 498/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8988
# Epoch 00498: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 280us/sample - loss: 0.0011 - coeff_determination: 0.8987
# Epoch 499/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8993
# Epoch 00499: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 268us/sample - loss: 0.0011 - coeff_determination: 0.8993
# Epoch 500/500
# 9344/9580 [============================>.] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.8985
# Epoch 00500: loss did not improve from 0.00113
# 9580/9580 [==============================] - 3s 269us/sample - loss: 0.0011 - coeff_determination: 0.8984

# %%
import matplotlib.pyplot as plt
# Load model weights first
lstm_model.load_weights(weights_filepath)

# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(500,num_modes+2))
test_data[:,:num_modes] = true_pca_evol[:,:]

test_data[:,-2] = -1.0/2.7
test_data[:,-1] = -1.0/4.0

testing_inputs = np.copy(test_data)
num_preds = np.shape(testing_inputs)[0]

viz = False

mse_val = 0.0
num_inference = 1000
pred_mean = np.zeros_like(test_data)[:,:]
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[0],np.shape(test_data)[1]))

from time import time
start_time = time()

for inference in range(num_inference):

    predictions = np.zeros_like(testing_inputs)
    predictions[0:seq_num,:] = testing_inputs[0:seq_num,:]

    for t in range(seq_num,num_preds):
        input_state = np.expand_dims(predictions[t-seq_num:t,:],0)
        output_state = lstm_model.predict(input_state)

        predictions[t,:state_len] = output_state[0,:]
        predictions[t,state_len:] = testing_inputs[t,state_len:]
        
    pred_pca_array[inference,:,:] = predictions[:,:]
    pred_mean = pred_mean + predictions[:,:]
    mse_val = mse_val + np.sum((predictions[:,:]-test_data[:,:])**2)
        
    if viz:

        fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
        ax[0,0].plot(testing_inputs[:,0],label='True')
        ax[0,0].plot(predictions[:,0],label='Predicted')
        ax[0,0].set_title('Mode 1')


        ax[1,0].plot(testing_inputs[:,1],label='True')
        ax[1,0].plot(predictions[:,1],label='Predicted')
        ax[1,0].set_title('Mode 2')

        ax[0,1].plot(testing_inputs[:,2],label='True')
        ax[0,1].plot(predictions[:,2],label='Predicted')
        ax[0,1].set_title('Mode 3')

        ax[1,1].plot(testing_inputs[:,3],label='True')
        ax[1,1].plot(predictions[:,3],label='Predicted')
        ax[1,1].set_title('Mode 4')


        plt.tight_layout()
        plt.legend()
        plt.show()

        # Plotting some contours
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

        pred_rb = predictions[:,:-2]
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()
        
end_time = time()

# %%
print('Time elapsed per inference:',(end_time-start_time)/inference)

# %%
pred_mean = pred_mean/num_inference

# Calculate standard deviation
pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[:,:])**2,axis=0)/(num_inference-1))
        
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[0,:],label='True')
ax[0,0].plot(pred_mean[0,:],label='Predicted mean')
ax[0,0].fill_between(np.arange(500),pred_mean[:,0]+pred_sdev[:,0],pred_mean[:,0]-pred_sdev[:,0],label='1 std')
ax[0,0].set_title('Mode 1')



ax[1,0].plot(test_data[:,1],label='True')
ax[1,0].plot(pred_mean[:,1],label='Predicted mean')
ax[1,0].fill_between(np.arange(500),pred_mean[:,1]+pred_sdev[:,1],pred_mean[:,1]-pred_sdev[:,1],label='1 std')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[:,2],label='True')
ax[0,1].plot(pred_mean[:,2],label='Predicted mean')
ax[0,1].fill_between(np.arange(500),pred_mean[:,2]+pred_sdev[:,2],pred_mean[:,2]-pred_sdev[:,2],label='1 std')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[:,3],label='True')
ax[1,1].plot(pred_mean[:,3],label='Predicted mean')
ax[1,1].fill_between(np.arange(500),pred_mean[:,3]+pred_sdev[:,3],pred_mean[:,3]-pred_sdev[:,3],label='1 std')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
np.save('../Figures/AT_LSTM_TP_Mean.npy',pred_mean)
np.save('../Figures/AT_LSTM_TP_SD.npy',pred_sdev)
