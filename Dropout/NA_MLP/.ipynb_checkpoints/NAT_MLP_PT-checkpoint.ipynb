# %%
import numpy as np
np.random.seed(5)
import tensorflow as tf
tf.set_random_seed(15)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]
coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = coeff_scaler.fit_transform(np.transpose(pca_coeffs))

# %%
# The total shape is large due to multiple simulations
num_samples_total = np.shape(pca_coeffs_scaled)[0]
num_sims = int(num_samples_total/500)
pca_coeffs_scaled = np.reshape(pca_coeffs_scaled,newshape=(num_sims,500*40))

# %%
seq_num = 20
training_data_ip = np.copy(pca_coeffs_scaled[:,:40*(seq_num)])
training_data_ip = np.concatenate((training_data_ip,locs),axis=-1)
training_data_op = np.copy(pca_coeffs_scaled[:,40*(seq_num):])

# %%
# Visualize a modal evolution
mode_num = 1
plt_array = np.arange(500,dtype='int')
plt.plot(pca_coeffs_scaled[0,plt_array*(40)+mode_num])
plt.show()

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_MLP_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
mlp_inputs = Input(shape=(40*seq_num+2),name='mlp_inputs')
h1 = Dense(88,activation='tanh')(mlp_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = Dense(88,activation='tanh')(h1)
h2 = Dropout(0.2)(h2,training=True)
mlp_outputs = Dense((500-seq_num)*(40),activation=None)(h2)

mlp_model = Model(inputs=mlp_inputs,outputs=mlp_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
mlp_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
mlp_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 15:03:41.960528 140578808059712 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mlp_inputs (InputLayer)      [(None, 802)]             0
# _________________________________________________________________
# dense (Dense)                (None, 88)                70664
# _________________________________________________________________
# dropout (Dropout)            (None, 88)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 88)                7832
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 88)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 19200)             1708800
# =================================================================
# Total params: 1,787,296
# Trainable params: 1,787,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = False

if train_mode:
    train_history = mlp_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_MLP_PT.npy',train_history.history['loss'])
# Out:
# Epoch 1/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.2671 - coeff_determination: -209.9603
# Epoch 00001: loss improved from inf to 0.23425, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.2342 - coeff_determination: -157.3929
# Epoch 2/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.1688 - coeff_determination: -56.6417
# Epoch 00002: loss improved from 0.23425 to 0.12494, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.1249 - coeff_determination: -36.9125
# Epoch 3/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0667 - coeff_determination: -15.9581
# Epoch 00003: loss improved from 0.12494 to 0.03782, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0378 - coeff_determination: -8.0736
# Epoch 4/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0157 - coeff_determination: -2.4819
# Epoch 00004: loss improved from 0.03782 to 0.01527, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0153 - coeff_determination: -2.0927
# Epoch 5/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0295 - coeff_determination: -4.8719
# Epoch 00005: loss did not improve from 0.01527
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0223 - coeff_determination: -3.2310
# Epoch 6/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0180 - coeff_determination: -1.6302
# Epoch 00006: loss did not improve from 0.01527
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0165 - coeff_determination: -1.0635
# Epoch 7/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0169 - coeff_determination: -0.2379
# Epoch 00007: loss did not improve from 0.01527
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0173 - coeff_determination: -0.4234
# Epoch 8/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0120 - coeff_determination: -0.3140
# Epoch 00008: loss improved from 0.01527 to 0.01491, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0149 - coeff_determination: -0.9151
# Epoch 9/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0130 - coeff_determination: -1.1729
# Epoch 00009: loss improved from 0.01491 to 0.01264, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0126 - coeff_determination: -0.9978
# Epoch 10/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0128 - coeff_determination: -1.8769
# Epoch 00010: loss improved from 0.01264 to 0.01181, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0118 - coeff_determination: -1.4238
# Epoch 11/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0117 - coeff_determination: -1.4827
# Epoch 00011: loss did not improve from 0.01181
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0123 - coeff_determination: -1.3171
# Epoch 12/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.1598
# Epoch 00012: loss did not improve from 0.01181
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0126 - coeff_determination: -1.0866
# Epoch 13/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -1.0256
# Epoch 00013: loss improved from 0.01181 to 0.01140, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0114 - coeff_determination: -1.1512
# Epoch 14/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -0.9869
# Epoch 00014: loss did not improve from 0.01140
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0117 - coeff_determination: -1.3294
# Epoch 15/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0126 - coeff_determination: -0.8564
# Epoch 00015: loss did not improve from 0.01140
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0115 - coeff_determination: -0.9725
# Epoch 16/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0189 - coeff_determination: -0.9090
# Epoch 00016: loss did not improve from 0.01140
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0140 - coeff_determination: -1.1965
# Epoch 17/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.5648
# Epoch 00017: loss did not improve from 0.01140
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0120 - coeff_determination: -1.1220
# Epoch 18/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0157 - coeff_determination: -1.0913
# Epoch 00018: loss did not improve from 0.01140
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0126 - coeff_determination: -1.0462
# Epoch 19/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0116 - coeff_determination: -1.1463
# Epoch 00019: loss improved from 0.01140 to 0.01139, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0114 - coeff_determination: -1.1372
# Epoch 20/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -0.7898
# Epoch 00020: loss improved from 0.01139 to 0.01117, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0112 - coeff_determination: -0.9962
# Epoch 21/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0120 - coeff_determination: -1.0850
# Epoch 00021: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0132 - coeff_determination: -0.8909
# Epoch 22/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.1178
# Epoch 00022: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0115 - coeff_determination: -1.3818
# Epoch 23/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0117 - coeff_determination: -1.3204
# Epoch 00023: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0115 - coeff_determination: -1.1889
# Epoch 24/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0115 - coeff_determination: -1.2956
# Epoch 00024: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0120 - coeff_determination: -1.1514
# Epoch 25/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -0.8846
# Epoch 00025: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0115 - coeff_determination: -0.9661
# Epoch 26/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0149 - coeff_determination: -1.0944
# Epoch 00026: loss did not improve from 0.01117
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0124 - coeff_determination: -0.8910
# Epoch 27/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.7255
# Epoch 00027: loss improved from 0.01117 to 0.01102, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0110 - coeff_determination: -1.0156
# Epoch 28/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0122 - coeff_determination: -0.9240
# Epoch 00028: loss did not improve from 0.01102
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0126 - coeff_determination: -1.0162
# Epoch 29/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -0.7911
# Epoch 00029: loss did not improve from 0.01102
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0114 - coeff_determination: -1.1717
# Epoch 30/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.6919
# Epoch 00030: loss did not improve from 0.01102
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0125 - coeff_determination: -1.3551
# Epoch 31/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.2498
# Epoch 00031: loss did not improve from 0.01102
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0111 - coeff_determination: -1.2045
# Epoch 32/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -1.0485
# Epoch 00032: loss improved from 0.01102 to 0.01089, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0109 - coeff_determination: -1.1051
# Epoch 33/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0128 - coeff_determination: -2.3775
# Epoch 00033: loss did not improve from 0.01089
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0119 - coeff_determination: -1.2202
# Epoch 34/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0113 - coeff_determination: -0.8887
# Epoch 00034: loss did not improve from 0.01089
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0121 - coeff_determination: -1.0167
# Epoch 35/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -0.7980
# Epoch 00035: loss did not improve from 0.01089
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0111 - coeff_determination: -1.2000
# Epoch 36/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.2911
# Epoch 00036: loss improved from 0.01089 to 0.01068, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0107 - coeff_determination: -1.2798
# Epoch 37/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.2494
# Epoch 00037: loss improved from 0.01068 to 0.01068, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0107 - coeff_determination: -1.0087
# Epoch 38/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0191 - coeff_determination: -0.7223
# Epoch 00038: loss did not improve from 0.01068
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0128 - coeff_determination: -0.9656
# Epoch 39/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -0.8725
# Epoch 00039: loss did not improve from 0.01068
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0121 - coeff_determination: -0.8420
# Epoch 40/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0097 - coeff_determination: -0.9522
# Epoch 00040: loss improved from 0.01068 to 0.01065, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0106 - coeff_determination: -1.0914
# Epoch 41/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.9978
# Epoch 00041: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0114 - coeff_determination: -1.1742
# Epoch 42/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.1993
# Epoch 00042: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0118 - coeff_determination: -1.3891
# Epoch 43/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0138 - coeff_determination: -0.5319
# Epoch 00043: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0129 - coeff_determination: -1.0705
# Epoch 44/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: -1.1550
# Epoch 00044: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0129 - coeff_determination: -1.1081
# Epoch 45/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.0731
# Epoch 00045: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0130 - coeff_determination: -0.8932
# Epoch 46/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.0784
# Epoch 00046: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0117 - coeff_determination: -0.9187
# Epoch 47/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: -1.3895
# Epoch 00047: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0112 - coeff_determination: -1.5163
# Epoch 48/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -0.8957
# Epoch 00048: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0115 - coeff_determination: -1.4361
# Epoch 49/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.8729
# Epoch 00049: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0108 - coeff_determination: -1.3980
# Epoch 50/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.9454
# Epoch 00050: loss did not improve from 0.01065
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0113 - coeff_determination: -1.0827
# Epoch 51/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -0.8724
# Epoch 00051: loss improved from 0.01065 to 0.01037, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0104 - coeff_determination: -1.0172
# Epoch 52/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -0.9215
# Epoch 00052: loss improved from 0.01037 to 0.01027, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0103 - coeff_determination: -1.2716
# Epoch 53/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0128 - coeff_determination: -1.2015
# Epoch 00053: loss did not improve from 0.01027
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0111 - coeff_determination: -1.1816
# Epoch 54/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -0.9906
# Epoch 00054: loss improved from 0.01027 to 0.01019, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0102 - coeff_determination: -1.3072
# Epoch 55/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0137 - coeff_determination: -0.8435
# Epoch 00055: loss did not improve from 0.01019
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0110 - coeff_determination: -0.9056
# Epoch 56/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.9610
# Epoch 00056: loss improved from 0.01019 to 0.01010, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 6ms/sample - loss: 0.0101 - coeff_determination: -0.8374
# Epoch 57/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -0.5744
# Epoch 00057: loss did not improve from 0.01010
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0104 - coeff_determination: -1.3818
# Epoch 58/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0124 - coeff_determination: -1.3544
# Epoch 00058: loss did not improve from 0.01010
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0114 - coeff_determination: -1.1326
# Epoch 59/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.8101
# Epoch 00059: loss did not improve from 0.01010
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0103 - coeff_determination: -1.0969
# Epoch 60/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0097 - coeff_determination: -1.2047
# Epoch 00060: loss did not improve from 0.01010
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0106 - coeff_determination: -0.8245
# Epoch 61/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.4737
# Epoch 00061: loss improved from 0.01010 to 0.01001, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0100 - coeff_determination: -1.1500
# Epoch 62/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.1452
# Epoch 00062: loss improved from 0.01001 to 0.00954, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0095 - coeff_determination: -1.0970
# Epoch 63/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.1503
# Epoch 00063: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0106 - coeff_determination: -1.2361
# Epoch 64/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.6525
# Epoch 00064: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0105 - coeff_determination: -0.5986
# Epoch 65/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.7904
# Epoch 00065: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0096 - coeff_determination: -0.7391
# Epoch 66/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -0.7085
# Epoch 00066: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0102 - coeff_determination: -0.9702
# Epoch 67/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0111 - coeff_determination: -0.6190
# Epoch 00067: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0100 - coeff_determination: -0.8280
# Epoch 68/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.8285
# Epoch 00068: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0102 - coeff_determination: -0.8477
# Epoch 69/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.1450
# Epoch 00069: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0104 - coeff_determination: -0.8356
# Epoch 70/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0123 - coeff_determination: -0.5673
# Epoch 00070: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0098 - coeff_determination: -0.5910
# Epoch 71/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.6605
# Epoch 00071: loss improved from 0.00954 to 0.00925, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0093 - coeff_determination: -0.6463
# Epoch 72/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -0.7814
# Epoch 00072: loss did not improve from 0.00925
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0093 - coeff_determination: -0.9705
# Epoch 73/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0127 - coeff_determination: -1.7791
# Epoch 00073: loss did not improve from 0.00925
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0121 - coeff_determination: -1.0314
# Epoch 74/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -0.8866
# Epoch 00074: loss did not improve from 0.00925
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0093 - coeff_determination: -0.5749
# Epoch 75/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0117 - coeff_determination: -0.7489
# Epoch 00075: loss did not improve from 0.00925
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0101 - coeff_determination: -0.6897
# Epoch 76/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -0.3316
# Epoch 00076: loss improved from 0.00925 to 0.00921, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0092 - coeff_determination: -0.5741
# Epoch 77/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.8493
# Epoch 00077: loss improved from 0.00921 to 0.00871, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.6699
# Epoch 78/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0077 - coeff_determination: -0.3478
# Epoch 00078: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0088 - coeff_determination: -0.6870
# Epoch 79/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0089 - coeff_determination: -0.7770
# Epoch 00079: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0099 - coeff_determination: -0.5369
# Epoch 80/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0142 - coeff_determination: -1.3128
# Epoch 00080: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0098 - coeff_determination: -0.5166
# Epoch 81/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0108 - coeff_determination: -0.4757
# Epoch 00081: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0094 - coeff_determination: -0.3973
# Epoch 82/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.6006
# Epoch 00082: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0103 - coeff_determination: -0.8182
# Epoch 83/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0083 - coeff_determination: -0.3466
# Epoch 00083: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -0.4502
# Epoch 84/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0145 - coeff_determination: -0.6549
# Epoch 00084: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0096 - coeff_determination: -0.5725
# Epoch 85/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.7229
# Epoch 00085: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0100 - coeff_determination: -0.4162
# Epoch 86/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0116 - coeff_determination: -0.6529
# Epoch 00086: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0101 - coeff_determination: -0.6187
# Epoch 87/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0114 - coeff_determination: -1.2352
# Epoch 00087: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0089 - coeff_determination: -0.7850
# Epoch 88/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -1.0526
# Epoch 00088: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0096 - coeff_determination: -0.7429
# Epoch 89/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0116 - coeff_determination: -0.7343
# Epoch 00089: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0109 - coeff_determination: -0.3769
# Epoch 90/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0117 - coeff_determination: -0.2313
# Epoch 00090: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0100 - coeff_determination: -0.4738
# Epoch 91/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.2530
# Epoch 00091: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0087 - coeff_determination: -0.5355
# Epoch 92/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.5966
# Epoch 00092: loss did not improve from 0.00871
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0095 - coeff_determination: -0.7466
# Epoch 93/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0074 - coeff_determination: -0.3900
# Epoch 00093: loss improved from 0.00871 to 0.00866, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0087 - coeff_determination: -0.6505
# Epoch 94/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -0.4228
# Epoch 00094: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0098 - coeff_determination: -0.4057
# Epoch 95/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -0.3827
# Epoch 00095: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0091 - coeff_determination: -0.3662
# Epoch 96/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0106 - coeff_determination: -0.6087
# Epoch 00096: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0099 - coeff_determination: -0.9556
# Epoch 97/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -0.2292
# Epoch 00097: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -0.3439
# Epoch 98/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.5040
# Epoch 00098: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -0.3897
# Epoch 99/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0109 - coeff_determination: -0.3589
# Epoch 00099: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0101 - coeff_determination: -0.4704
# Epoch 100/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.4465
# Epoch 00100: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.4718
# Epoch 101/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.5002
# Epoch 00101: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0098 - coeff_determination: -0.5828
# Epoch 102/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -0.5983
# Epoch 00102: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0119 - coeff_determination: -0.7149
# Epoch 103/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.5505
# Epoch 00103: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -0.4891
# Epoch 104/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0155 - coeff_determination: -1.2470
# Epoch 00104: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0102 - coeff_determination: -0.5878
# Epoch 105/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.6644
# Epoch 00105: loss did not improve from 0.00866
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0092 - coeff_determination: -0.4574
# Epoch 106/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -0.6992
# Epoch 00106: loss improved from 0.00866 to 0.00851, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0085 - coeff_determination: -0.4884
# Epoch 107/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0118 - coeff_determination: -0.5513
# Epoch 00107: loss did not improve from 0.00851
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0101 - coeff_determination: -0.6487
# Epoch 108/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0124 - coeff_determination: -0.7222
# Epoch 00108: loss did not improve from 0.00851
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0100 - coeff_determination: -0.4632
# Epoch 109/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0108 - coeff_determination: -0.3864
# Epoch 00109: loss did not improve from 0.00851
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0100 - coeff_determination: -0.5354
# Epoch 110/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0089 - coeff_determination: -0.6229
# Epoch 00110: loss did not improve from 0.00851
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0092 - coeff_determination: -0.7072
# Epoch 111/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -0.5916
# Epoch 00111: loss did not improve from 0.00851
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0087 - coeff_determination: -0.4674
# Epoch 112/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.6483
# Epoch 00112: loss improved from 0.00851 to 0.00841, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0084 - coeff_determination: -0.4425
# Epoch 113/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -0.4631
# Epoch 00113: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -0.4729
# Epoch 114/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0078 - coeff_determination: -0.2300
# Epoch 00114: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0087 - coeff_determination: -0.6592
# Epoch 115/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.7658
# Epoch 00115: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0114 - coeff_determination: -1.1226
# Epoch 116/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -0.3638
# Epoch 00116: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0104 - coeff_determination: -0.3915
# Epoch 117/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0111 - coeff_determination: -0.3262
# Epoch 00117: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0097 - coeff_determination: -0.3977
# Epoch 118/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.7043
# Epoch 00118: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0111 - coeff_determination: -1.1031
# Epoch 119/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -0.7766
# Epoch 00119: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0104 - coeff_determination: -0.6379
# Epoch 120/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0118 - coeff_determination: -0.3418
# Epoch 00120: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0098 - coeff_determination: -0.5302
# Epoch 121/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0075 - coeff_determination: -0.1593
# Epoch 00121: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0094 - coeff_determination: -0.5212
# Epoch 122/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -0.9958
# Epoch 00122: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0086 - coeff_determination: -0.4303
# Epoch 123/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -0.7629
# Epoch 00123: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0097 - coeff_determination: -0.6217
# Epoch 124/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -0.2432
# Epoch 00124: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -0.4924
# Epoch 125/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -0.6924
# Epoch 00125: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0090 - coeff_determination: -0.5018
# Epoch 126/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.4001
# Epoch 00126: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -0.4298
# Epoch 127/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.7294
# Epoch 00127: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -0.4558
# Epoch 128/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0076 - coeff_determination: 0.0576
# Epoch 00128: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -0.3364
# Epoch 129/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -0.2313
# Epoch 00129: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -0.5037
# Epoch 130/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -0.5526
# Epoch 00130: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0094 - coeff_determination: -0.4433
# Epoch 131/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.3619
# Epoch 00131: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0092 - coeff_determination: -0.4766
# Epoch 132/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0114 - coeff_determination: -1.2464
# Epoch 00132: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0099 - coeff_determination: -0.5271
# Epoch 133/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0106 - coeff_determination: -0.5873
# Epoch 00133: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0097 - coeff_determination: -0.4154
# Epoch 134/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.2186
# Epoch 00134: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0093 - coeff_determination: -0.4319
# Epoch 135/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0073 - coeff_determination: -0.0944
# Epoch 00135: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.5092
# Epoch 136/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -0.3871
# Epoch 00136: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.2885
# Epoch 137/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0111 - coeff_determination: -0.3562
# Epoch 00137: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0101 - coeff_determination: -0.4282
# Epoch 138/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -0.7469
# Epoch 00138: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0086 - coeff_determination: -0.4183
# Epoch 139/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0081 - coeff_determination: -0.3327
# Epoch 00139: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0086 - coeff_determination: -0.2030
# Epoch 140/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0062 - coeff_determination: 0.2002
# Epoch 00140: loss improved from 0.00841 to 0.00814, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0081 - coeff_determination: -0.3358
# Epoch 141/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.9690
# Epoch 00141: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.4854
# Epoch 142/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -0.5945
# Epoch 00142: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0094 - coeff_determination: -0.3926
# Epoch 143/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.3534
# Epoch 00143: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -0.3519
# Epoch 144/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0118 - coeff_determination: -0.4733
# Epoch 00144: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0100 - coeff_determination: -0.3718
# Epoch 145/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0117 - coeff_determination: -0.4862
# Epoch 00145: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -0.3523
# Epoch 146/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -0.1900
# Epoch 00146: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -0.3110
# Epoch 147/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.2588
# Epoch 00147: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0084 - coeff_determination: -0.2660
# Epoch 148/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0076 - coeff_determination: -0.1574
# Epoch 00148: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0089 - coeff_determination: -0.3804
# Epoch 149/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.3676
# Epoch 00149: loss did not improve from 0.00814
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0085 - coeff_determination: -0.4928
# Epoch 150/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0055 - coeff_determination: 0.2688
# Epoch 00150: loss improved from 0.00814 to 0.00812, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0081 - coeff_determination: -0.4090
# Epoch 151/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0103 - coeff_determination: -0.8113
# Epoch 00151: loss improved from 0.00812 to 0.00786, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0079 - coeff_determination: -0.1893
# Epoch 152/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -0.1553
# Epoch 00152: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0087 - coeff_determination: -0.4212
# Epoch 153/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0073 - coeff_determination: -0.3386
# Epoch 00153: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0085 - coeff_determination: -0.5812
# Epoch 154/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.9958
# Epoch 00154: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0095 - coeff_determination: -0.4743
# Epoch 155/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -0.4674
# Epoch 00155: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -0.3059
# Epoch 156/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0110 - coeff_determination: -0.2418
# Epoch 00156: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0108 - coeff_determination: -0.6968
# Epoch 157/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -0.2714
# Epoch 00157: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0092 - coeff_determination: -0.6316
# Epoch 158/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0062 - coeff_determination: 0.1284
# Epoch 00158: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 4ms/sample - loss: 0.0093 - coeff_determination: -0.1986
# Epoch 159/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -0.2062
# Epoch 00159: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0084 - coeff_determination: -0.2078
# Epoch 160/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.0836
# Epoch 00160: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0098 - coeff_determination: -0.2643
# Epoch 161/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0114 - coeff_determination: -0.7335
# Epoch 00161: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0099 - coeff_determination: -0.4536
# Epoch 162/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0067 - coeff_determination: -0.0951
# Epoch 00162: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0089 - coeff_determination: -0.3353
# Epoch 163/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0078 - coeff_determination: 0.0558
# Epoch 00163: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0085 - coeff_determination: -0.2009
# Epoch 164/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -0.2487
# Epoch 00164: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0085 - coeff_determination: -0.5783
# Epoch 165/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0074 - coeff_determination: 0.0377
# Epoch 00165: loss did not improve from 0.00786
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -0.2535
# Epoch 166/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0055 - coeff_determination: 0.2098
# Epoch 00166: loss improved from 0.00786 to 0.00776, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0078 - coeff_determination: -0.0862
# Epoch 167/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -0.3740
# Epoch 00167: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0089 - coeff_determination: -0.2327
# Epoch 168/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -0.4071
# Epoch 00168: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0082 - coeff_determination: -0.4780
# Epoch 169/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0077 - coeff_determination: -0.4575
# Epoch 00169: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0079 - coeff_determination: -0.2446
# Epoch 170/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0097 - coeff_determination: -0.2205
# Epoch 00170: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0100 - coeff_determination: -0.2340
# Epoch 171/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.4210
# Epoch 00171: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0085 - coeff_determination: -0.2853
# Epoch 172/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0072 - coeff_determination: -0.5634
# Epoch 00172: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0087 - coeff_determination: -0.4152
# Epoch 173/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -0.0952
# Epoch 00173: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0085 - coeff_determination: -0.3488
# Epoch 174/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -0.0344
# Epoch 00174: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0079 - coeff_determination: -0.1042
# Epoch 175/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.4939
# Epoch 00175: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -0.3682
# Epoch 176/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -0.4837
# Epoch 00176: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0090 - coeff_determination: -0.4564
# Epoch 177/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0081 - coeff_determination: -0.1364
# Epoch 00177: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 5ms/sample - loss: 0.0081 - coeff_determination: -0.1004
# Epoch 178/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -0.2198
# Epoch 00178: loss did not improve from 0.00776
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0087 - coeff_determination: -0.1070
# Epoch 179/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0074 - coeff_determination: 0.0037
# Epoch 00179: loss improved from 0.00776 to 0.00741, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0074 - coeff_determination: -0.2111
# Epoch 180/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.6073
# Epoch 00180: loss did not improve from 0.00741
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0083 - coeff_determination: -0.4267
# Epoch 181/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0065 - coeff_determination: -0.1708
# Epoch 00181: loss did not improve from 0.00741
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -0.2809
# Epoch 182/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0062 - coeff_determination: 0.1599
# Epoch 00182: loss did not improve from 0.00741
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0080 - coeff_determination: -0.0722
# Epoch 183/5000
# ...
# Epoch 4939/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8483
# Epoch 04939: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8444
# Epoch 4940/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8642
# Epoch 04940: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0018 - coeff_determination: 0.8494
# Epoch 4941/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8673
# Epoch 04941: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8621
# Epoch 4942/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8453
# Epoch 04942: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8463
# Epoch 4943/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8684
# Epoch 04943: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8539
# Epoch 4944/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0021 - coeff_determination: 0.8147
# Epoch 04944: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8477
# Epoch 4945/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0018 - coeff_determination: 0.8207
# Epoch 04945: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8679
# Epoch 4946/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8714
# Epoch 04946: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8535
# Epoch 4947/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8606
# Epoch 04947: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8450
# Epoch 4948/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.7899
# Epoch 04948: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8644
# Epoch 4949/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8426
# Epoch 04949: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8603
# Epoch 4950/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.8234
# Epoch 04950: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8715
# Epoch 4951/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8571
# Epoch 04951: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8581
# Epoch 4952/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8264
# Epoch 04952: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8714
# Epoch 4953/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8896
# Epoch 04953: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8577
# Epoch 4954/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8324
# Epoch 04954: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0018 - coeff_determination: 0.8431
# Epoch 4955/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8752
# Epoch 04955: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8618
# Epoch 4956/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0018 - coeff_determination: 0.8494
# Epoch 04956: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8622
# Epoch 4957/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8491
# Epoch 04957: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8473
# Epoch 4958/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8904
# Epoch 04958: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8477
# Epoch 4959/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8944
# Epoch 04959: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8573
# Epoch 4960/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8741
# Epoch 04960: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8514
# Epoch 4961/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8636
# Epoch 04961: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8625
# Epoch 4962/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8728
# Epoch 04962: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0018 - coeff_determination: 0.8328
# Epoch 4963/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8973
# Epoch 04963: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8648
# Epoch 4964/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9053
# Epoch 04964: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8643
# Epoch 4965/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.9019
# Epoch 04965: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8712
# Epoch 4966/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.1597e-04 - coeff_determination: 0.9260
# Epoch 04966: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8764
# Epoch 4967/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0015 - coeff_determination: 0.8673
# Epoch 04967: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8789
# Epoch 4968/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8702
# Epoch 04968: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8891
# Epoch 4969/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.7977
# Epoch 04969: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0019 - coeff_determination: 0.8199
# Epoch 4970/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8925
# Epoch 04970: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8707
# Epoch 4971/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8292
# Epoch 04971: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8568
# Epoch 4972/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8708
# Epoch 04972: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8695
# Epoch 4973/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0018 - coeff_determination: 0.8272
# Epoch 04973: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8739
# Epoch 4974/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9047
# Epoch 04974: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0019 - coeff_determination: 0.8427
# Epoch 4975/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8550
# Epoch 04975: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8682
# Epoch 4976/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8912
# Epoch 04976: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8620
# Epoch 4977/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9048
# Epoch 04977: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8644
# Epoch 4978/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8917
# Epoch 04978: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8563
# Epoch 4979/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0011 - coeff_determination: 0.9151
# Epoch 04979: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8556
# Epoch 4980/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.8059
# Epoch 04980: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8572
# Epoch 4981/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8827
# Epoch 04981: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0018 - coeff_determination: 0.8315
# Epoch 4982/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8651
# Epoch 04982: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8718
# Epoch 4983/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.8885
# Epoch 04983: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8726
# Epoch 4984/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8874
# Epoch 04984: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8756
# Epoch 4985/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8902
# Epoch 04985: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8432
# Epoch 4986/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8574
# Epoch 04986: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8662
# Epoch 4987/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0013 - coeff_determination: 0.8838
# Epoch 04987: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8691
# Epoch 4988/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.8547
# Epoch 04988: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8610
# Epoch 4989/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8785
# Epoch 04989: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8470
# Epoch 4990/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8671
# Epoch 04990: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8680
# Epoch 4991/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0020 - coeff_determination: 0.8327
# Epoch 04991: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8447
# Epoch 4992/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8285
# Epoch 04992: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0018 - coeff_determination: 0.8327
# Epoch 4993/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0019 - coeff_determination: 0.8550
# Epoch 04993: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8780
# Epoch 4994/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0014 - coeff_determination: 0.8667
# Epoch 04994: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0017 - coeff_determination: 0.8540
# Epoch 4995/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8581
# Epoch 04995: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8532
# Epoch 4996/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0012 - coeff_determination: 0.9100
# Epoch 04996: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0014 - coeff_determination: 0.8759
# Epoch 4997/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.8091
# Epoch 04997: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8643
# Epoch 4998/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8491
# Epoch 04998: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8678
# Epoch 4999/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0017 - coeff_determination: 0.8589
# Epoch 04999: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0015 - coeff_determination: 0.8647
# Epoch 5000/5000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0016 - coeff_determination: 0.8603
# Epoch 05000: loss did not improve from 0.00122
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0016 - coeff_determination: 0.8648

# %%
mlp_model.load_weights(weights_filepath)
# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.reshape(np.copy(true_pca_evol),newshape=(1,500*40))

test_inputs = np.copy(test_data[:,:40*seq_num])
test_outputs = np.copy(test_data[:,40*seq_num:])

test_locs = np.zeros(shape=(1,2))
test_locs[0,0] = -1.0/2.7
test_locs[0,1] = -1.0/4.0
viz = False

test_inputs = np.concatenate((test_inputs,test_locs),axis=-1)

mse_val = 0.0

num_inference = 1000
pred_mean = np.zeros_like(test_data)
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[1]))

from time import time

start_time = time()

for inference in range(num_inference):

    pred_pca = mlp_model.predict(test_inputs)
    pred_pca = np.concatenate((test_inputs[:,:800],pred_pca),axis=-1)
    pred_pca_array[inference,:] = pred_pca[0,:]
    
    mse_val = mse_val + np.sum((pred_pca-test_data)**2)
    pred_mean = pred_mean + pred_pca
    
    if viz:

        fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
        mode_num = 0
        ax[0,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
        ax[0,0].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
        ax[0,0].set_title('Mode 1')

        mode_num = 1
        ax[1,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
        ax[1,0].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
        ax[1,0].set_title('Mode 2')

        mode_num = 2
        ax[0,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
        ax[0,1].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
        ax[0,1].set_title('Mode 3')

        mode_num = 3
        ax[1,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
        ax[1,1].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
        ax[1,1].set_title('Mode 4')

        plt.tight_layout()
        plt.legend()
        plt.show()

        # Plotting some contours
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

        pred_rb = pred_pca[0,:].reshape(500,40)
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()
        
end_time = time()

# %%
print('Time elapsed per inference:',(end_time-start_time)/num_inference)
# Out:
# Time elapsed per inference: 0.005597872018814087

# %%
print(np.shape(pred_mean))
print(np.shape(np.sqrt(np.sum((pred_pca_array - pred_mean[0,:])**2,axis=0)/(num_inference-1))))
# Out:
# (1, 20000)
# (20000,)

# %%
pred_mean = pred_mean/num_inference

# Calculate standard deviation
pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[0,:])**2,axis=0)/(num_inference-1))

        
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))

mode_num = 0
ax[0,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[0,0].plot(pred_mean[0,plt_array*(40)+mode_num],label='Predicted mean')
ax[0,0].fill_between(np.arange(500),pred_mean[0,plt_array*(40)+mode_num]+pred_sdev[plt_array*(40)+mode_num],pred_mean[0,plt_array*(40)+mode_num]-pred_sdev[plt_array*(40)+mode_num],label='1 std')
ax[0,0].set_title('Mode 1')

mode_num = 1
ax[1,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[1,0].plot(pred_mean[0,plt_array*(40)+mode_num],label='Predicted mean')
ax[1,0].fill_between(np.arange(500),pred_mean[0,plt_array*(40)+mode_num]+pred_sdev[plt_array*(40)+mode_num],pred_mean[0,plt_array*(40)+mode_num]-pred_sdev[plt_array*(40)+mode_num],label='1 std')
ax[1,0].set_title('Mode 2')

mode_num = 2
ax[0,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[0,1].plot(pred_mean[0,plt_array*(40)+mode_num],label='Predicted mean')
ax[0,1].fill_between(np.arange(500),pred_mean[0,plt_array*(40)+mode_num]+pred_sdev[plt_array*(40)+mode_num],pred_mean[0,plt_array*(40)+mode_num]-pred_sdev[plt_array*(40)+mode_num],label='1 std')
ax[0,1].set_title('Mode 3')

mode_num = 3
ax[1,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[1,1].plot(pred_mean[0,plt_array*(40)+mode_num],label='Predicted mean')
ax[1,1].fill_between(np.arange(500),pred_mean[0,plt_array*(40)+mode_num]+pred_sdev[plt_array*(40)+mode_num],pred_mean[0,plt_array*(40)+mode_num]-pred_sdev[plt_array*(40)+mode_num],label='1 std')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
np.save('../Figures/NAT_MLP_PT_Mean.npy',pred_mean)
np.save('../Figures/NAT_MLP_PT_SD.npy',pred_sdev)
