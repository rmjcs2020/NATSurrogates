# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]
coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = coeff_scaler.fit_transform(np.transpose(pca_coeffs))

# %%
# The total shape is large due to multiple simulations
num_samples_total = np.shape(pca_coeffs_scaled)[0]
num_sims = int(num_samples_total/500)
pca_coeffs_scaled = np.reshape(pca_coeffs_scaled,newshape=(num_sims,500,40))

# %%
state_len = np.shape(pca_coeffs_scaled)[-1]
seq_num = 20

num_samples = 500-seq_num-1
input_data = np.zeros(shape=(num_sims*num_samples,seq_num,state_len+2))
output_data = np.zeros(shape=(num_sims*num_samples,seq_num,state_len+2))

batch_num = 0
output_seq_list = []
num_steps_rec = 2

for simnum in range(num_sims):            
    sub_data = pca_coeffs_scaled[simnum,:,:]
    for t in range(np.shape(sub_data)[0]-seq_num-1):
        input_seq = sub_data[t:t+seq_num,:]
        input_data[batch_num,:,:state_len] = input_seq[None,:,:state_len]
        input_data[batch_num,:,-2] = locs[simnum,0]
        input_data[batch_num,:,-1] = locs[simnum,1]
        batch_num = batch_num + 1
        

output_seq_list = []
for step in range(num_steps_rec):
    batch_num = 0
    for simnum in range(num_sims):            
        sub_data = pca_coeffs_scaled[simnum,:,:]
        
        for t in range(np.shape(sub_data)[0]-seq_num-step-1):
            input_seq = sub_data[t:t+seq_num,:]
            output_data[batch_num,:,:state_len] = input_seq[None,:,:state_len]
            output_data[batch_num,:,-2] = locs[simnum,0]
            output_data[batch_num,:,-1] = locs[simnum,1]
            
            batch_num = batch_num + 1
            
    output_seq_list.append(output_data)

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'A_LSTM_T_R.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(seq_num,state_len+2),name='at_inputs')
h1 = LSTM(106,return_sequences=True)(lstm_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = LSTM(106,return_sequences=True)(h1)
h2 = Dropout(0.2)(h2,training=True)
lstm_outputs = Dense(state_len+2,activation=None)(h2)
lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)

input_traj = Input(shape=(seq_num,state_len+2))
next_step = lstm_model(input_traj)

output_list = []
output_list.append(next_step)
for _ in range(num_steps_rec-1):
    next_step = lstm_model(next_step)
    output_list.append(next_step)
    
upper_model = Model(inputs=input_traj,outputs=output_list)    

# design network
my_adam = optimizers.Adam(lr=0.002823350805177, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
upper_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
upper_model.summary()

train_mode = False
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 13:47:20.407138 139873585813312 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20, 42)]     0
# __________________________________________________________________________________________________
# model (Model)                   (None, 20, 42)       157982      input_1[0][0]
#                                                                  model[1][0]
# ==================================================================================================
# Total params: 157,982
# Trainable params: 157,982
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
num_epochs = 500
batch_size = 256
train_mode = False

if train_mode:
    from time import time
    start_time = time()
    train_history = upper_model.fit(x=input_data, y=output_seq_list, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('A_LSTM_T_R.npy',train_history.history['loss'])
    end_time = time()
# Out:
# W0122 00:10:29.049614 139848241575744 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.1488 - model_loss: 0.0685 - model_1_loss: 0.0803 - model_coeff_determination: -1.5351 - model_1_coeff_determination: -23.4199
# Epoch 00001: loss improved from inf to 0.14773, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 6s 600us/sample - loss: 0.1477 - model_loss: 0.0679 - model_1_loss: 0.0796 - model_coeff_determination: -1.5153 - model_1_coeff_determination: -23.1090
# Epoch 2/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0483 - model_loss: 0.0233 - model_1_loss: 0.0250 - model_coeff_determination: -0.0225 - model_1_coeff_determination: -0.0518
# Epoch 00002: loss improved from 0.14773 to 0.04823, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 435us/sample - loss: 0.0482 - model_loss: 0.0233 - model_1_loss: 0.0249 - model_coeff_determination: -0.0222 - model_1_coeff_determination: -0.0515
# Epoch 3/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0385 - model_loss: 0.0191 - model_1_loss: 0.0194 - model_coeff_determination: 0.0380 - model_1_coeff_determination: 0.0206
# Epoch 00003: loss improved from 0.04823 to 0.03849, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 454us/sample - loss: 0.0385 - model_loss: 0.0190 - model_1_loss: 0.0194 - model_coeff_determination: 0.0381 - model_1_coeff_determination: 0.0208
# Epoch 4/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0342 - model_loss: 0.0168 - model_1_loss: 0.0174 - model_coeff_determination: 0.1337 - model_1_coeff_determination: 0.0824
# Epoch 00004: loss improved from 0.03849 to 0.03421, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 7s 739us/sample - loss: 0.0342 - model_loss: 0.0168 - model_1_loss: 0.0174 - model_coeff_determination: 0.1345 - model_1_coeff_determination: 0.0825
# Epoch 5/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0309 - model_loss: 0.0151 - model_1_loss: 0.0158 - model_coeff_determination: 0.2374 - model_1_coeff_determination: 0.1615
# Epoch 00005: loss improved from 0.03421 to 0.03095, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 6s 625us/sample - loss: 0.0309 - model_loss: 0.0151 - model_1_loss: 0.0158 - model_coeff_determination: 0.2375 - model_1_coeff_determination: 0.1617
# Epoch 6/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0284 - model_loss: 0.0138 - model_1_loss: 0.0145 - model_coeff_determination: 0.3207 - model_1_coeff_determination: 0.2457
# Epoch 00006: loss improved from 0.03095 to 0.02834, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 5s 552us/sample - loss: 0.0283 - model_loss: 0.0138 - model_1_loss: 0.0145 - model_coeff_determination: 0.3208 - model_1_coeff_determination: 0.2457
# Epoch 7/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0266 - model_loss: 0.0129 - model_1_loss: 0.0136 - model_coeff_determination: 0.3686 - model_1_coeff_determination: 0.2990
# Epoch 00007: loss improved from 0.02834 to 0.02658, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 6s 667us/sample - loss: 0.0266 - model_loss: 0.0130 - model_1_loss: 0.0136 - model_coeff_determination: 0.3684 - model_1_coeff_determination: 0.2986
# Epoch 8/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0252 - model_loss: 0.0122 - model_1_loss: 0.0130 - model_coeff_determination: 0.4092 - model_1_coeff_determination: 0.3371
# Epoch 00008: loss improved from 0.02658 to 0.02515, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 7s 687us/sample - loss: 0.0251 - model_loss: 0.0122 - model_1_loss: 0.0130 - model_coeff_determination: 0.4102 - model_1_coeff_determination: 0.3382
# Epoch 9/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0237 - model_loss: 0.0114 - model_1_loss: 0.0123 - model_coeff_determination: 0.4568 - model_1_coeff_determination: 0.3805
# Epoch 00009: loss improved from 0.02515 to 0.02367, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 5s 482us/sample - loss: 0.0237 - model_loss: 0.0114 - model_1_loss: 0.0123 - model_coeff_determination: 0.4571 - model_1_coeff_determination: 0.3807
# Epoch 10/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0224 - model_loss: 0.0108 - model_1_loss: 0.0116 - model_coeff_determination: 0.4941 - model_1_coeff_determination: 0.4170
# Epoch 00010: loss improved from 0.02367 to 0.02245, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0225 - model_loss: 0.0108 - model_1_loss: 0.0117 - model_coeff_determination: 0.4938 - model_1_coeff_determination: 0.4166
# Epoch 11/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0215 - model_loss: 0.0103 - model_1_loss: 0.0112 - model_coeff_determination: 0.5213 - model_1_coeff_determination: 0.4436
# Epoch 00011: loss improved from 0.02245 to 0.02148, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0215 - model_loss: 0.0103 - model_1_loss: 0.0112 - model_coeff_determination: 0.5216 - model_1_coeff_determination: 0.4438
# Epoch 12/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0206 - model_loss: 0.0099 - model_1_loss: 0.0108 - model_coeff_determination: 0.5467 - model_1_coeff_determination: 0.4685
# Epoch 00012: loss improved from 0.02148 to 0.02064, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0206 - model_loss: 0.0099 - model_1_loss: 0.0108 - model_coeff_determination: 0.5468 - model_1_coeff_determination: 0.4688
# Epoch 13/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0198 - model_loss: 0.0095 - model_1_loss: 0.0104 - model_coeff_determination: 0.5700 - model_1_coeff_determination: 0.4918
# Epoch 00013: loss improved from 0.02064 to 0.01986, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0199 - model_loss: 0.0095 - model_1_loss: 0.0104 - model_coeff_determination: 0.5696 - model_1_coeff_determination: 0.4914
# Epoch 14/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0191 - model_loss: 0.0091 - model_1_loss: 0.0100 - model_coeff_determination: 0.5903 - model_1_coeff_determination: 0.5124
# Epoch 00014: loss improved from 0.01986 to 0.01912, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 423us/sample - loss: 0.0191 - model_loss: 0.0091 - model_1_loss: 0.0100 - model_coeff_determination: 0.5906 - model_1_coeff_determination: 0.5128
# Epoch 15/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0184 - model_loss: 0.0087 - model_1_loss: 0.0096 - model_coeff_determination: 0.6107 - model_1_coeff_determination: 0.5326
# Epoch 00015: loss improved from 0.01912 to 0.01843, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 422us/sample - loss: 0.0184 - model_loss: 0.0088 - model_1_loss: 0.0097 - model_coeff_determination: 0.6102 - model_1_coeff_determination: 0.5321
# Epoch 16/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0178 - model_loss: 0.0085 - model_1_loss: 0.0093 - model_coeff_determination: 0.6283 - model_1_coeff_determination: 0.5511
# Epoch 00016: loss improved from 0.01843 to 0.01776, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 422us/sample - loss: 0.0178 - model_loss: 0.0084 - model_1_loss: 0.0093 - model_coeff_determination: 0.6290 - model_1_coeff_determination: 0.5518
# Epoch 17/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0171 - model_loss: 0.0081 - model_1_loss: 0.0090 - model_coeff_determination: 0.6449 - model_1_coeff_determination: 0.5705
# Epoch 00017: loss improved from 0.01776 to 0.01712, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 441us/sample - loss: 0.0171 - model_loss: 0.0081 - model_1_loss: 0.0090 - model_coeff_determination: 0.6456 - model_1_coeff_determination: 0.5714
# Epoch 18/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0166 - model_loss: 0.0079 - model_1_loss: 0.0087 - model_coeff_determination: 0.6590 - model_1_coeff_determination: 0.5882
# Epoch 00018: loss improved from 0.01712 to 0.01659, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0166 - model_loss: 0.0079 - model_1_loss: 0.0087 - model_coeff_determination: 0.6587 - model_1_coeff_determination: 0.5879
# Epoch 19/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0161 - model_loss: 0.0077 - model_1_loss: 0.0084 - model_coeff_determination: 0.6693 - model_1_coeff_determination: 0.6023
# Epoch 00019: loss improved from 0.01659 to 0.01612, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 438us/sample - loss: 0.0161 - model_loss: 0.0077 - model_1_loss: 0.0084 - model_coeff_determination: 0.6696 - model_1_coeff_determination: 0.6027
# Epoch 20/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0157 - model_loss: 0.0075 - model_1_loss: 0.0082 - model_coeff_determination: 0.6789 - model_1_coeff_determination: 0.6152
# Epoch 00020: loss improved from 0.01612 to 0.01570, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 428us/sample - loss: 0.0157 - model_loss: 0.0075 - model_1_loss: 0.0082 - model_coeff_determination: 0.6794 - model_1_coeff_determination: 0.6159
# Epoch 21/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0154 - model_loss: 0.0073 - model_1_loss: 0.0080 - model_coeff_determination: 0.6864 - model_1_coeff_determination: 0.6266
# Epoch 00021: loss improved from 0.01570 to 0.01535, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0153 - model_loss: 0.0073 - model_1_loss: 0.0080 - model_coeff_determination: 0.6866 - model_1_coeff_determination: 0.6268
# Epoch 22/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0150 - model_loss: 0.0072 - model_1_loss: 0.0078 - model_coeff_determination: 0.6936 - model_1_coeff_determination: 0.6349
# Epoch 00022: loss improved from 0.01535 to 0.01503, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 422us/sample - loss: 0.0150 - model_loss: 0.0072 - model_1_loss: 0.0078 - model_coeff_determination: 0.6935 - model_1_coeff_determination: 0.6349
# Epoch 23/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0147 - model_loss: 0.0071 - model_1_loss: 0.0077 - model_coeff_determination: 0.6996 - model_1_coeff_determination: 0.6436
# Epoch 00023: loss improved from 0.01503 to 0.01475, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 5s 566us/sample - loss: 0.0148 - model_loss: 0.0071 - model_1_loss: 0.0077 - model_coeff_determination: 0.6995 - model_1_coeff_determination: 0.6435
# Epoch 24/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0145 - model_loss: 0.0069 - model_1_loss: 0.0075 - model_coeff_determination: 0.7057 - model_1_coeff_determination: 0.6515
# Epoch 00024: loss improved from 0.01475 to 0.01446, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 7s 695us/sample - loss: 0.0145 - model_loss: 0.0069 - model_1_loss: 0.0075 - model_coeff_determination: 0.7056 - model_1_coeff_determination: 0.6511
# Epoch 25/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0142 - model_loss: 0.0068 - model_1_loss: 0.0074 - model_coeff_determination: 0.7103 - model_1_coeff_determination: 0.6579
# Epoch 00025: loss improved from 0.01446 to 0.01421, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 7s 725us/sample - loss: 0.0142 - model_loss: 0.0068 - model_1_loss: 0.0074 - model_coeff_determination: 0.7104 - model_1_coeff_determination: 0.6580
# Epoch 26/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0139 - model_loss: 0.0067 - model_1_loss: 0.0072 - model_coeff_determination: 0.7165 - model_1_coeff_determination: 0.6650
# Epoch 00026: loss improved from 0.01421 to 0.01394, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 453us/sample - loss: 0.0139 - model_loss: 0.0067 - model_1_loss: 0.0072 - model_coeff_determination: 0.7168 - model_1_coeff_determination: 0.6654
# Epoch 27/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0137 - model_loss: 0.0066 - model_1_loss: 0.0071 - model_coeff_determination: 0.7218 - model_1_coeff_determination: 0.6716
# Epoch 00027: loss improved from 0.01394 to 0.01370, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 464us/sample - loss: 0.0137 - model_loss: 0.0066 - model_1_loss: 0.0071 - model_coeff_determination: 0.7222 - model_1_coeff_determination: 0.6719
# Epoch 28/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0134 - model_loss: 0.0065 - model_1_loss: 0.0070 - model_coeff_determination: 0.7281 - model_1_coeff_determination: 0.6785
# Epoch 00028: loss improved from 0.01370 to 0.01344, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 440us/sample - loss: 0.0134 - model_loss: 0.0065 - model_1_loss: 0.0070 - model_coeff_determination: 0.7282 - model_1_coeff_determination: 0.6785
# Epoch 29/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0132 - model_loss: 0.0063 - model_1_loss: 0.0069 - model_coeff_determination: 0.7329 - model_1_coeff_determination: 0.6834
# Epoch 00029: loss improved from 0.01344 to 0.01322, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 450us/sample - loss: 0.0132 - model_loss: 0.0063 - model_1_loss: 0.0069 - model_coeff_determination: 0.7331 - model_1_coeff_determination: 0.6837
# Epoch 30/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0130 - model_loss: 0.0063 - model_1_loss: 0.0068 - model_coeff_determination: 0.7370 - model_1_coeff_determination: 0.6888
# Epoch 00030: loss improved from 0.01322 to 0.01301, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 419us/sample - loss: 0.0130 - model_loss: 0.0062 - model_1_loss: 0.0068 - model_coeff_determination: 0.7376 - model_1_coeff_determination: 0.6895
# Epoch 31/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0128 - model_loss: 0.0062 - model_1_loss: 0.0067 - model_coeff_determination: 0.7415 - model_1_coeff_determination: 0.6954
# Epoch 00031: loss improved from 0.01301 to 0.01281, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0128 - model_loss: 0.0062 - model_1_loss: 0.0066 - model_coeff_determination: 0.7414 - model_1_coeff_determination: 0.6954
# Epoch 32/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0126 - model_loss: 0.0061 - model_1_loss: 0.0066 - model_coeff_determination: 0.7454 - model_1_coeff_determination: 0.6996
# Epoch 00032: loss improved from 0.01281 to 0.01264, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0126 - model_loss: 0.0061 - model_1_loss: 0.0066 - model_coeff_determination: 0.7454 - model_1_coeff_determination: 0.6996
# Epoch 33/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0125 - model_loss: 0.0060 - model_1_loss: 0.0065 - model_coeff_determination: 0.7484 - model_1_coeff_determination: 0.7039
# Epoch 00033: loss improved from 0.01264 to 0.01245, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0124 - model_loss: 0.0060 - model_1_loss: 0.0065 - model_coeff_determination: 0.7490 - model_1_coeff_determination: 0.7046
# Epoch 34/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0123 - model_loss: 0.0059 - model_1_loss: 0.0064 - model_coeff_determination: 0.7531 - model_1_coeff_determination: 0.7101
# Epoch 00034: loss improved from 0.01245 to 0.01226, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 419us/sample - loss: 0.0123 - model_loss: 0.0059 - model_1_loss: 0.0064 - model_coeff_determination: 0.7531 - model_1_coeff_determination: 0.7103
# Epoch 35/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0121 - model_loss: 0.0058 - model_1_loss: 0.0063 - model_coeff_determination: 0.7566 - model_1_coeff_determination: 0.7140
# Epoch 00035: loss improved from 0.01226 to 0.01210, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0121 - model_loss: 0.0058 - model_1_loss: 0.0063 - model_coeff_determination: 0.7564 - model_1_coeff_determination: 0.7139
# Epoch 36/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0120 - model_loss: 0.0058 - model_1_loss: 0.0062 - model_coeff_determination: 0.7589 - model_1_coeff_determination: 0.7172
# Epoch 00036: loss improved from 0.01210 to 0.01196, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0120 - model_loss: 0.0058 - model_1_loss: 0.0062 - model_coeff_determination: 0.7590 - model_1_coeff_determination: 0.7172
# Epoch 37/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0118 - model_loss: 0.0057 - model_1_loss: 0.0061 - model_coeff_determination: 0.7629 - model_1_coeff_determination: 0.7223
# Epoch 00037: loss improved from 0.01196 to 0.01180, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0118 - model_loss: 0.0057 - model_1_loss: 0.0061 - model_coeff_determination: 0.7628 - model_1_coeff_determination: 0.7222
# Epoch 38/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0117 - model_loss: 0.0056 - model_1_loss: 0.0060 - model_coeff_determination: 0.7654 - model_1_coeff_determination: 0.7256
# Epoch 00038: loss improved from 0.01180 to 0.01166, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0117 - model_loss: 0.0056 - model_1_loss: 0.0060 - model_coeff_determination: 0.7654 - model_1_coeff_determination: 0.7254
# Epoch 39/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0115 - model_loss: 0.0056 - model_1_loss: 0.0060 - model_coeff_determination: 0.7683 - model_1_coeff_determination: 0.7284
# Epoch 00039: loss improved from 0.01166 to 0.01154, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0115 - model_loss: 0.0056 - model_1_loss: 0.0060 - model_coeff_determination: 0.7680 - model_1_coeff_determination: 0.7282
# Epoch 40/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0114 - model_loss: 0.0055 - model_1_loss: 0.0059 - model_coeff_determination: 0.7702 - model_1_coeff_determination: 0.7313
# Epoch 00040: loss improved from 0.01154 to 0.01141, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0114 - model_loss: 0.0055 - model_1_loss: 0.0059 - model_coeff_determination: 0.7707 - model_1_coeff_determination: 0.7318
# Epoch 41/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0113 - model_loss: 0.0054 - model_1_loss: 0.0058 - model_coeff_determination: 0.7736 - model_1_coeff_determination: 0.7362
# Epoch 00041: loss improved from 0.01141 to 0.01127, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0113 - model_loss: 0.0054 - model_1_loss: 0.0058 - model_coeff_determination: 0.7735 - model_1_coeff_determination: 0.7360
# Epoch 42/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0111 - model_loss: 0.0054 - model_1_loss: 0.0057 - model_coeff_determination: 0.7766 - model_1_coeff_determination: 0.7400
# Epoch 00042: loss improved from 0.01127 to 0.01112, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0111 - model_loss: 0.0054 - model_1_loss: 0.0058 - model_coeff_determination: 0.7762 - model_1_coeff_determination: 0.7396
# Epoch 43/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0110 - model_loss: 0.0053 - model_1_loss: 0.0057 - model_coeff_determination: 0.7788 - model_1_coeff_determination: 0.7428
# Epoch 00043: loss improved from 0.01112 to 0.01100, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0110 - model_loss: 0.0053 - model_1_loss: 0.0057 - model_coeff_determination: 0.7789 - model_1_coeff_determination: 0.7428
# Epoch 44/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0109 - model_loss: 0.0053 - model_1_loss: 0.0056 - model_coeff_determination: 0.7803 - model_1_coeff_determination: 0.7446
# Epoch 00044: loss improved from 0.01100 to 0.01089, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 5s 483us/sample - loss: 0.0109 - model_loss: 0.0053 - model_1_loss: 0.0056 - model_coeff_determination: 0.7808 - model_1_coeff_determination: 0.7453
# Epoch 45/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0108 - model_loss: 0.0052 - model_1_loss: 0.0056 - model_coeff_determination: 0.7831 - model_1_coeff_determination: 0.7484
# Epoch 00045: loss improved from 0.01089 to 0.01079, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0108 - model_loss: 0.0052 - model_1_loss: 0.0056 - model_coeff_determination: 0.7834 - model_1_coeff_determination: 0.7485
# Epoch 46/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0107 - model_loss: 0.0052 - model_1_loss: 0.0055 - model_coeff_determination: 0.7858 - model_1_coeff_determination: 0.7505
# Epoch 00046: loss improved from 0.01079 to 0.01068, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 447us/sample - loss: 0.0107 - model_loss: 0.0052 - model_1_loss: 0.0055 - model_coeff_determination: 0.7861 - model_1_coeff_determination: 0.7509
# Epoch 47/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0105 - model_loss: 0.0051 - model_1_loss: 0.0055 - model_coeff_determination: 0.7887 - model_1_coeff_determination: 0.7547
# Epoch 00047: loss improved from 0.01068 to 0.01056, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 461us/sample - loss: 0.0106 - model_loss: 0.0051 - model_1_loss: 0.0055 - model_coeff_determination: 0.7884 - model_1_coeff_determination: 0.7543
# Epoch 48/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0104 - model_loss: 0.0050 - model_1_loss: 0.0054 - model_coeff_determination: 0.7917 - model_1_coeff_determination: 0.7581
# Epoch 00048: loss improved from 0.01056 to 0.01044, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0104 - model_loss: 0.0050 - model_1_loss: 0.0054 - model_coeff_determination: 0.7911 - model_1_coeff_determination: 0.7577
# Epoch 49/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0103 - model_loss: 0.0050 - model_1_loss: 0.0053 - model_coeff_determination: 0.7931 - model_1_coeff_determination: 0.7601
# Epoch 00049: loss improved from 0.01044 to 0.01034, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0103 - model_loss: 0.0050 - model_1_loss: 0.0053 - model_coeff_determination: 0.7933 - model_1_coeff_determination: 0.7603
# Epoch 50/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0103 - model_loss: 0.0050 - model_1_loss: 0.0053 - model_coeff_determination: 0.7949 - model_1_coeff_determination: 0.7622
# Epoch 00050: loss improved from 0.01034 to 0.01025, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0103 - model_loss: 0.0050 - model_1_loss: 0.0053 - model_coeff_determination: 0.7952 - model_1_coeff_determination: 0.7624
# Epoch 51/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0101 - model_loss: 0.0049 - model_1_loss: 0.0052 - model_coeff_determination: 0.7971 - model_1_coeff_determination: 0.7655
# Epoch 00051: loss improved from 0.01025 to 0.01015, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0102 - model_loss: 0.0049 - model_1_loss: 0.0052 - model_coeff_determination: 0.7971 - model_1_coeff_determination: 0.7656
# Epoch 52/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0101 - model_loss: 0.0049 - model_1_loss: 0.0052 - model_coeff_determination: 0.7992 - model_1_coeff_determination: 0.7671
# Epoch 00052: loss improved from 0.01015 to 0.01008, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 5s 482us/sample - loss: 0.0101 - model_loss: 0.0049 - model_1_loss: 0.0052 - model_coeff_determination: 0.7990 - model_1_coeff_determination: 0.7668
# Epoch 53/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0100 - model_loss: 0.0048 - model_1_loss: 0.0051 - model_coeff_determination: 0.8011 - model_1_coeff_determination: 0.7705
# Epoch 00053: loss improved from 0.01008 to 0.00996, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 446us/sample - loss: 0.0100 - model_loss: 0.0048 - model_1_loss: 0.0051 - model_coeff_determination: 0.8012 - model_1_coeff_determination: 0.7705
# Epoch 54/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0099 - model_loss: 0.0048 - model_1_loss: 0.0051 - model_coeff_determination: 0.8026 - model_1_coeff_determination: 0.7723
# Epoch 00054: loss improved from 0.00996 to 0.00989, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0099 - model_loss: 0.0048 - model_1_loss: 0.0051 - model_coeff_determination: 0.8027 - model_1_coeff_determination: 0.7725
# Epoch 55/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0098 - model_loss: 0.0047 - model_1_loss: 0.0051 - model_coeff_determination: 0.8043 - model_1_coeff_determination: 0.7737
# Epoch 00055: loss improved from 0.00989 to 0.00983, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 442us/sample - loss: 0.0098 - model_loss: 0.0047 - model_1_loss: 0.0051 - model_coeff_determination: 0.8046 - model_1_coeff_determination: 0.7741
# Epoch 56/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0097 - model_loss: 0.0047 - model_1_loss: 0.0050 - model_coeff_determination: 0.8064 - model_1_coeff_determination: 0.7775
# Epoch 00056: loss improved from 0.00983 to 0.00971, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 414us/sample - loss: 0.0097 - model_loss: 0.0047 - model_1_loss: 0.0050 - model_coeff_determination: 0.8066 - model_1_coeff_determination: 0.7777
# Epoch 57/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0096 - model_loss: 0.0047 - model_1_loss: 0.0050 - model_coeff_determination: 0.8085 - model_1_coeff_determination: 0.7792
# Epoch 00057: loss improved from 0.00971 to 0.00966, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 432us/sample - loss: 0.0097 - model_loss: 0.0047 - model_1_loss: 0.0050 - model_coeff_determination: 0.8079 - model_1_coeff_determination: 0.7787
# Epoch 58/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0096 - model_loss: 0.0046 - model_1_loss: 0.0050 - model_coeff_determination: 0.8097 - model_1_coeff_determination: 0.7804
# Epoch 00058: loss improved from 0.00966 to 0.00958, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0096 - model_loss: 0.0046 - model_1_loss: 0.0050 - model_coeff_determination: 0.8096 - model_1_coeff_determination: 0.7803
# Epoch 59/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0095 - model_loss: 0.0046 - model_1_loss: 0.0049 - model_coeff_determination: 0.8109 - model_1_coeff_determination: 0.7821
# Epoch 00059: loss improved from 0.00958 to 0.00954, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0095 - model_loss: 0.0046 - model_1_loss: 0.0049 - model_coeff_determination: 0.8109 - model_1_coeff_determination: 0.7821
# Epoch 60/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0095 - model_loss: 0.0046 - model_1_loss: 0.0049 - model_coeff_determination: 0.8122 - model_1_coeff_determination: 0.7839
# Epoch 00060: loss improved from 0.00954 to 0.00946, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0095 - model_loss: 0.0046 - model_1_loss: 0.0049 - model_coeff_determination: 0.8125 - model_1_coeff_determination: 0.7842
# Epoch 61/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0094 - model_loss: 0.0045 - model_1_loss: 0.0049 - model_coeff_determination: 0.8137 - model_1_coeff_determination: 0.7857
# Epoch 00061: loss improved from 0.00946 to 0.00941, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0094 - model_loss: 0.0045 - model_1_loss: 0.0049 - model_coeff_determination: 0.8137 - model_1_coeff_determination: 0.7856
# Epoch 62/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8156 - model_1_coeff_determination: 0.7879
# Epoch 00062: loss improved from 0.00941 to 0.00935, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 419us/sample - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8152 - model_1_coeff_determination: 0.7873
# Epoch 63/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8164 - model_1_coeff_determination: 0.7886
# Epoch 00063: loss improved from 0.00935 to 0.00930, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 433us/sample - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8164 - model_1_coeff_determination: 0.7886
# Epoch 64/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8169 - model_1_coeff_determination: 0.7892
# Epoch 00064: loss improved from 0.00930 to 0.00926, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0093 - model_loss: 0.0045 - model_1_loss: 0.0048 - model_coeff_determination: 0.8171 - model_1_coeff_determination: 0.7894
# Epoch 65/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0092 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8194 - model_1_coeff_determination: 0.7918
# Epoch 00065: loss improved from 0.00926 to 0.00921, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 431us/sample - loss: 0.0092 - model_loss: 0.0044 - model_1_loss: 0.0048 - model_coeff_determination: 0.8185 - model_1_coeff_determination: 0.7909
# Epoch 66/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0091 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8200 - model_1_coeff_determination: 0.7926
# Epoch 00066: loss improved from 0.00921 to 0.00915, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0092 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8198 - model_1_coeff_determination: 0.7924
# Epoch 67/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0091 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8210 - model_1_coeff_determination: 0.7947
# Epoch 00067: loss improved from 0.00915 to 0.00909, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0091 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8208 - model_1_coeff_determination: 0.7945
# Epoch 68/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0090 - model_loss: 0.0043 - model_1_loss: 0.0047 - model_coeff_determination: 0.8229 - model_1_coeff_determination: 0.7963
# Epoch 00068: loss improved from 0.00909 to 0.00906, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0091 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8217 - model_1_coeff_determination: 0.7949
# Epoch 69/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0090 - model_loss: 0.0043 - model_1_loss: 0.0047 - model_coeff_determination: 0.8234 - model_1_coeff_determination: 0.7967
# Epoch 00069: loss improved from 0.00906 to 0.00903, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0090 - model_loss: 0.0044 - model_1_loss: 0.0047 - model_coeff_determination: 0.8227 - model_1_coeff_determination: 0.7960
# Epoch 70/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0090 - model_loss: 0.0043 - model_1_loss: 0.0047 - model_coeff_determination: 0.8230 - model_1_coeff_determination: 0.7959
# Epoch 00070: loss improved from 0.00903 to 0.00900, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0090 - model_loss: 0.0043 - model_1_loss: 0.0047 - model_coeff_determination: 0.8234 - model_1_coeff_determination: 0.7964
# Epoch 71/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0089 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8250 - model_1_coeff_determination: 0.7992
# Epoch 00071: loss improved from 0.00900 to 0.00892, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0089 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8247 - model_1_coeff_determination: 0.7990
# Epoch 72/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0089 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8259 - model_1_coeff_determination: 0.7996
# Epoch 00072: loss improved from 0.00892 to 0.00889, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0089 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8260 - model_1_coeff_determination: 0.7997
# Epoch 73/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0088 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8271 - model_1_coeff_determination: 0.8016
# Epoch 00073: loss improved from 0.00889 to 0.00885, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0088 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8264 - model_1_coeff_determination: 0.8009
# Epoch 74/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0088 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8274 - model_1_coeff_determination: 0.8012
# Epoch 00074: loss did not improve from 0.00885
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0088 - model_loss: 0.0043 - model_1_loss: 0.0046 - model_coeff_determination: 0.8268 - model_1_coeff_determination: 0.8007
# Epoch 75/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0088 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8286 - model_1_coeff_determination: 0.8028
# Epoch 00075: loss improved from 0.00885 to 0.00879, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0088 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8282 - model_1_coeff_determination: 0.8024
# Epoch 76/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0088 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8283 - model_1_coeff_determination: 0.8027
# Epoch 00076: loss improved from 0.00879 to 0.00876, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0088 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8284 - model_1_coeff_determination: 0.8028
# Epoch 77/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8296 - model_1_coeff_determination: 0.8042
# Epoch 00077: loss improved from 0.00876 to 0.00872, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8296 - model_1_coeff_determination: 0.8043
# Epoch 78/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8302 - model_1_coeff_determination: 0.8041
# Epoch 00078: loss improved from 0.00872 to 0.00870, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8302 - model_1_coeff_determination: 0.8042
# Epoch 79/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8305 - model_1_coeff_determination: 0.8055
# Epoch 00079: loss improved from 0.00870 to 0.00868, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0087 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8304 - model_1_coeff_determination: 0.8051
# Epoch 80/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0086 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8320 - model_1_coeff_determination: 0.8070
# Epoch 00080: loss improved from 0.00868 to 0.00864, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0086 - model_loss: 0.0042 - model_1_loss: 0.0045 - model_coeff_determination: 0.8316 - model_1_coeff_determination: 0.8065
# Epoch 81/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0045 - model_coeff_determination: 0.8325 - model_1_coeff_determination: 0.8073
# Epoch 00081: loss improved from 0.00864 to 0.00861, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0045 - model_coeff_determination: 0.8324 - model_1_coeff_determination: 0.8072
# Epoch 82/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8329 - model_1_coeff_determination: 0.8078
# Epoch 00082: loss improved from 0.00861 to 0.00858, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8331 - model_1_coeff_determination: 0.8080
# Epoch 83/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8336 - model_1_coeff_determination: 0.8084
# Epoch 00083: loss improved from 0.00858 to 0.00857, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0086 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8332 - model_1_coeff_determination: 0.8080
# Epoch 84/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8339 - model_1_coeff_determination: 0.8087
# Epoch 00084: loss improved from 0.00857 to 0.00854, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8339 - model_1_coeff_determination: 0.8087
# Epoch 85/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8353 - model_1_coeff_determination: 0.8101
# Epoch 00085: loss improved from 0.00854 to 0.00850, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8343 - model_1_coeff_determination: 0.8090
# Epoch 86/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8358 - model_1_coeff_determination: 0.8111
# Epoch 00086: loss improved from 0.00850 to 0.00848, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8354 - model_1_coeff_determination: 0.8107
# Epoch 87/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8359 - model_1_coeff_determination: 0.8111
# Epoch 00087: loss improved from 0.00848 to 0.00846, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0085 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8358 - model_1_coeff_determination: 0.8110
# Epoch 88/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0084 - model_loss: 0.0041 - model_1_loss: 0.0044 - model_coeff_determination: 0.8367 - model_1_coeff_determination: 0.8121
# Epoch 00088: loss improved from 0.00846 to 0.00841, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0044 - model_coeff_determination: 0.8369 - model_1_coeff_determination: 0.8123
# Epoch 89/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0044 - model_coeff_determination: 0.8370 - model_1_coeff_determination: 0.8125
# Epoch 00089: loss improved from 0.00841 to 0.00839, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 415us/sample - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8374 - model_1_coeff_determination: 0.8128
# Epoch 90/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8378 - model_1_coeff_determination: 0.8132
# Epoch 00090: loss improved from 0.00839 to 0.00836, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8381 - model_1_coeff_determination: 0.8135
# Epoch 91/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0084 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8381 - model_1_coeff_determination: 0.8137
# Epoch 00091: loss improved from 0.00836 to 0.00835, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8384 - model_1_coeff_determination: 0.8139
# Epoch 92/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8389 - model_1_coeff_determination: 0.8145
# Epoch 00092: loss improved from 0.00835 to 0.00833, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8390 - model_1_coeff_determination: 0.8146
# Epoch 93/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8388 - model_1_coeff_determination: 0.8142
# Epoch 00093: loss improved from 0.00833 to 0.00831, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8393 - model_1_coeff_determination: 0.8148
# Epoch 94/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8401 - model_1_coeff_determination: 0.8155
# Epoch 00094: loss improved from 0.00831 to 0.00828, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8401 - model_1_coeff_determination: 0.8156
# Epoch 95/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8406 - model_1_coeff_determination: 0.8161
# Epoch 00095: loss improved from 0.00828 to 0.00826, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 421us/sample - loss: 0.0083 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8403 - model_1_coeff_determination: 0.8159
# Epoch 96/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0082 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8412 - model_1_coeff_determination: 0.8169
# Epoch 00096: loss improved from 0.00826 to 0.00824, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0082 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8407 - model_1_coeff_determination: 0.8164
# Epoch 97/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0082 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8407 - model_1_coeff_determination: 0.8161
# Epoch 00097: loss improved from 0.00824 to 0.00824, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0082 - model_loss: 0.0040 - model_1_loss: 0.0043 - model_coeff_determination: 0.8410 - model_1_coeff_determination: 0.8163
# Epoch 98/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0082 - model_loss: 0.0039 - model_1_loss: 0.0043 - model_coeff_determination: 0.8417 - model_1_coeff_determination: 0.8171
# Epoch 00098: loss improved from 0.00824 to 0.00822, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0082 - model_loss: 0.0039 - model_1_loss: 0.0043 - model_coeff_determination: 0.8417 - model_1_coeff_determination: 0.8172
# Epoch 99/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0082 - model_loss: 0.0039 - model_1_loss: 0.0042 - model_coeff_determination: 0.8428 - model_1_coeff_determination: 0.8185
# Epoch 00099: loss improved from 0.00822 to 0.00818, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0082 - model_loss: 0.0039 - model_1_loss: 0.0043 - model_coeff_determination: 0.8421 - model_1_coeff_determination: 0.8177
# Epoch 100/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0082 - model_loss: 0.0039 - model_1_loss: 0.0042 - model_coeff_determination: 0.8428 - model_1_coeff_determination: 0.8190
# Epoch 00100: loss improved from 0.00818 to 0.00815, saving model to AT_LSTM_TP_R.h5
# ...
# Epoch 00465: loss did not improve from 0.00621
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8665
# Epoch 466/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8665
# Epoch 00466: loss did not improve from 0.00621
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8666
# Epoch 467/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0063 - model_loss: 0.0030 - model_1_loss: 0.0033 - model_coeff_determination: 0.8830 - model_1_coeff_determination: 0.8642
# Epoch 00467: loss did not improve from 0.00621
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0063 - model_loss: 0.0030 - model_1_loss: 0.0033 - model_coeff_determination: 0.8831 - model_1_coeff_determination: 0.8644
# Epoch 468/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8840 - model_1_coeff_determination: 0.8668
# Epoch 00468: loss did not improve from 0.00621
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8666
# Epoch 469/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8671
# Epoch 00469: loss improved from 0.00621 to 0.00619, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8670
# Epoch 470/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8659
# Epoch 00470: loss did not improve from 0.00619
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8837 - model_1_coeff_determination: 0.8656
# Epoch 471/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8848 - model_1_coeff_determination: 0.8672
# Epoch 00471: loss did not improve from 0.00619
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8668
# Epoch 472/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0032 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8677
# Epoch 00472: loss improved from 0.00619 to 0.00618, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8674
# Epoch 473/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8666
# Epoch 00473: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8667
# Epoch 474/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8669
# Epoch 00474: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8667
# Epoch 475/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8834 - model_1_coeff_determination: 0.8653
# Epoch 00475: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8836 - model_1_coeff_determination: 0.8656
# Epoch 476/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8662
# Epoch 00476: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8662
# Epoch 477/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8840 - model_1_coeff_determination: 0.8667
# Epoch 00477: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 422us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8840 - model_1_coeff_determination: 0.8667
# Epoch 478/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8662
# Epoch 00478: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8661
# Epoch 479/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8673
# Epoch 00479: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8672
# Epoch 480/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8663
# Epoch 00480: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8664
# Epoch 481/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8659
# Epoch 00481: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8657
# Epoch 482/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8672
# Epoch 00482: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8670
# Epoch 483/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8672
# Epoch 00483: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8848 - model_1_coeff_determination: 0.8674
# Epoch 484/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8663
# Epoch 00484: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8841 - model_1_coeff_determination: 0.8666
# Epoch 485/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8664
# Epoch 00485: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 419us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8665
# Epoch 486/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8838 - model_1_coeff_determination: 0.8660
# Epoch 00486: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8836 - model_1_coeff_determination: 0.8659
# Epoch 487/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8847 - model_1_coeff_determination: 0.8672
# Epoch 00487: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8671
# Epoch 488/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8839 - model_1_coeff_determination: 0.8662
# Epoch 00488: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8664
# Epoch 489/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8666
# Epoch 00489: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8669
# Epoch 490/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8665
# Epoch 00490: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8665
# Epoch 491/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8663
# Epoch 00491: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8661
# Epoch 492/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8844 - model_1_coeff_determination: 0.8663
# Epoch 00492: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8661
# Epoch 493/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8847 - model_1_coeff_determination: 0.8671
# Epoch 00493: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8669
# Epoch 494/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8672
# Epoch 00494: loss improved from 0.00618 to 0.00618, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8672
# Epoch 495/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8842 - model_1_coeff_determination: 0.8668
# Epoch 00495: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8671
# Epoch 496/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8843 - model_1_coeff_determination: 0.8670
# Epoch 00496: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 418us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8674
# Epoch 497/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8849 - model_1_coeff_determination: 0.8674
# Epoch 00497: loss improved from 0.00618 to 0.00618, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 420us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8847 - model_1_coeff_determination: 0.8672
# Epoch 498/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8846 - model_1_coeff_determination: 0.8672
# Epoch 00498: loss did not improve from 0.00618
# 9580/9580 [==============================] - 4s 419us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0033 - model_coeff_determination: 0.8845 - model_1_coeff_determination: 0.8671
# Epoch 499/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0061 - model_loss: 0.0029 - model_1_loss: 0.0032 - model_coeff_determination: 0.8852 - model_1_coeff_determination: 0.8686
# Epoch 00499: loss improved from 0.00618 to 0.00614, saving model to AT_LSTM_TP_R.h5
# 9580/9580 [==============================] - 4s 416us/sample - loss: 0.0061 - model_loss: 0.0029 - model_1_loss: 0.0032 - model_coeff_determination: 0.8850 - model_1_coeff_determination: 0.8684
# Epoch 500/500
# 9472/9580 [============================>.] - ETA: 0s - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0032 - model_coeff_determination: 0.8849 - model_1_coeff_determination: 0.8677
# Epoch 00500: loss did not improve from 0.00614
# 9580/9580 [==============================] - 4s 417us/sample - loss: 0.0062 - model_loss: 0.0029 - model_1_loss: 0.0032 - model_coeff_determination: 0.8850 - model_1_coeff_determination: 0.8679

# %%
print('Elapsed time to train:',end_time-start_time)
# Out:
# Elapsed time to train: 2171.460993051529

# %%
import matplotlib.pyplot as plt
# Load model weights first
upper_model.load_weights(weights_filepath)

# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(500,num_modes+2))
test_data[:,:num_modes] = true_pca_evol[:,:]

test_data[:,-2] = -1.0/2.7
test_data[:,-1] = -1.0/4.0

testing_inputs = np.copy(test_data)
num_preds = np.shape(testing_inputs)[0]

viz = False

mse_val = 0.0
num_inference = 1000
pred_mean = np.zeros_like(test_data)[:,:]
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[0],np.shape(test_data)[1]))
num_preds = np.shape(testing_inputs)[0]


from time import time
start_time = time()

for inference in range(num_inference):
   
    predictions = np.zeros_like(testing_inputs)
    predictions[0:seq_num,:] = testing_inputs[0:seq_num,:]

    for t in range(seq_num,num_preds,2):
        input_state = np.expand_dims(predictions[t-seq_num:t,:],0)
        output_state = upper_model.predict(input_state)
        
        predictions[t,:state_len] = output_state[0][0,-1,:-2]
        predictions[t,state_len:] = testing_inputs[t,state_len:]
        
        predictions[t+1,:state_len] = output_state[1][0,-1,:-2]
        predictions[t+1,state_len:] = testing_inputs[t+1,state_len:]
        
    pred_pca_array[inference,:,:] = predictions[:,:]
    pred_mean = pred_mean + predictions[:,:]
    mse_val = mse_val + np.sum((predictions[:,:]-test_data[:,:])**2)
                
    if viz:
        fig,ax = plt.subplots(nrows=2,ncols=2)
        ax[0,0].plot(testing_inputs[:,0],label='True')
        ax[0,0].plot(predictions[:,0],label='Predicted')
        ax[0,0].set_title('Mode 1')


        ax[1,0].plot(testing_inputs[:,1],label='True')
        ax[1,0].plot(predictions[:,1],label='Predicted')
        ax[1,0].set_title('Mode 2')

        ax[0,1].plot(testing_inputs[:,2],label='True')
        ax[0,1].plot(predictions[:,2],label='Predicted')
        ax[0,1].set_title('Mode 3')

        ax[1,1].plot(testing_inputs[:,3],label='True')
        ax[1,1].plot(predictions[:,3],label='Predicted')
        ax[1,1].set_title('Mode 4')

        plt.tight_layout()
        plt.legend()
        plt.show()
        
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

        pred_rb = predictions[:,:-2]
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()        
        
        
end_time = time()

# %%
if train_mode:
    pred_mean = pred_mean/num_inference
    pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[:,:])**2,axis=0)/(num_inference-1))
    np.save('../Figures/AT_LSTM_T_R_Mean.npy',pred_mean)
    np.save('../Figures/AT_LSTM_T_R_SD.npy',pred_sdev)

# %%
print('Elapsed time per inference:',(end_time-start_time)/num_inference)
# Out:
# Elapsed time per inference: 2.8282869911193846
