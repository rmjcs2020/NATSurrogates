# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]
coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = coeff_scaler.fit_transform(np.transpose(pca_coeffs))

# %%
# The total shape is large due to multiple simulations
num_samples_total = np.shape(pca_coeffs_scaled)[0]
num_sims = int(num_samples_total/500)
pca_coeffs_scaled = np.reshape(pca_coeffs_scaled,newshape=(num_sims,500,40))

# %%
state_len = np.shape(pca_coeffs_scaled)[-1]
seq_num = 20

num_samples = 500-seq_num-1
input_data = np.zeros(shape=(num_sims,seq_num,state_len+2))
output_data = np.zeros(shape=(num_sims,500-seq_num,state_len))

for simnum in range(num_sims):            
    sub_data = pca_coeffs_scaled[simnum,:,:]

    input_seq = sub_data[:seq_num,:]
    output_seq = sub_data[seq_num:,:]
    
    input_data[simnum,:,:state_len] = input_seq[None,:,:state_len]
    input_data[simnum,:,-2] = locs[simnum,0]
    input_data[simnum,:,-1] = locs[simnum,1]

    output_data[simnum,:,:] = output_seq[:]
    


# plt.figure()
# plt.plot(input_data[0,:,0])
# plt.plot(output_data[0,:,0])
# plt.show()

output_data = output_data.reshape(num_sims,(500-seq_num)*state_len,order='F')

# output_data = output_data.reshape(num_sims,480,state_len,order='F')
# plt.figure()
# plt.plot(output_data[0,:,0])
# plt.show()

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_LSTM_TP.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(seq_num,state_len+2),name='at_inputs')
h1 = LSTM(145,return_sequences=True)(lstm_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = LSTM(145,return_sequences=False)(h1)
h2 = Dropout(0.2)(h2,training=True)
lstm_outputs = Dense(np.shape(output_data)[1],activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)

# Plot model
# plot_model(lstm_model,to_file='LSTM_Model.png')
   
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 14:44:23.166582 139819305531200 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# at_inputs (InputLayer)       [(None, 20, 42)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 145)           109040
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 145)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 145)               168780
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 145)               0
# _________________________________________________________________
# dense (Dense)                (None, 19200)             2803200
# =================================================================
# Total params: 3,081,020
# Trainable params: 3,081,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = False

if train_mode:
    train_history = lstm_model.fit(x=input_data, y=output_data, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_LSTM_TP.npy',train_history.history['loss'])
# Out:
# W0120 20:19:48.805269 140340613994304 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.2565 - coeff_determination: -2185.5371
# Epoch 00001: loss improved from inf to 0.25423, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 1s 41ms/sample - loss: 0.2542 - coeff_determination: -1956.6250
# Epoch 2/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.2130 - coeff_determination: -518.6913
# Epoch 00002: loss improved from 0.25423 to 0.19562, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.1956 - coeff_determination: -396.0916
# Epoch 3/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.1016 - coeff_determination: -60.0165
# Epoch 00003: loss improved from 0.19562 to 0.09300, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0930 - coeff_determination: -51.7469
# Epoch 4/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0317 - coeff_determination: -12.3673
# Epoch 00004: loss improved from 0.09300 to 0.02510, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0251 - coeff_determination: -9.0200
# Epoch 5/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0196 - coeff_determination: -4.0802
# Epoch 00005: loss improved from 0.02510 to 0.02118, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0212 - coeff_determination: -4.2045
# Epoch 6/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0219 - coeff_determination: -2.7205
# Epoch 00006: loss improved from 0.02118 to 0.02085, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0208 - coeff_determination: -2.1006
# Epoch 7/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0124 - coeff_determination: -0.5755
# Epoch 00007: loss improved from 0.02085 to 0.01248, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0125 - coeff_determination: -0.6166
# Epoch 8/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: -0.5810
# Epoch 00008: loss improved from 0.01248 to 0.01245, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0125 - coeff_determination: -0.6096
# Epoch 9/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: -1.1320
# Epoch 00009: loss improved from 0.01245 to 0.01195, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0120 - coeff_determination: -1.1217
# Epoch 10/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0123 - coeff_determination: -1.4849
# Epoch 00010: loss improved from 0.01195 to 0.01192, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0119 - coeff_determination: -1.4621
# Epoch 11/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.5235
# Epoch 00011: loss improved from 0.01192 to 0.01018, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0102 - coeff_determination: -1.5306
# Epoch 12/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.4996
# Epoch 00012: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0109 - coeff_determination: -1.5126
# Epoch 13/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.4914
# Epoch 00013: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0104 - coeff_determination: -1.5345
# Epoch 14/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: -1.3435
# Epoch 00014: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0114 - coeff_determination: -1.2979
# Epoch 15/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.2208
# Epoch 00015: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0110 - coeff_determination: -1.2158
# Epoch 16/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.1314
# Epoch 00016: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0113 - coeff_determination: -1.1933
# Epoch 17/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.0266
# Epoch 00017: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0118 - coeff_determination: -0.9598
# Epoch 18/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.2588
# Epoch 00018: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0104 - coeff_determination: -1.2307
# Epoch 19/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0110 - coeff_determination: -1.5824
# Epoch 00019: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0107 - coeff_determination: -1.5391
# Epoch 20/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0118 - coeff_determination: -1.3171
# Epoch 00020: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0111 - coeff_determination: -1.1976
# Epoch 21/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.7085
# Epoch 00021: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0109 - coeff_determination: -1.8037
# Epoch 22/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.2594
# Epoch 00022: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0104 - coeff_determination: -1.2565
# Epoch 23/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.2575
# Epoch 00023: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0109 - coeff_determination: -1.1403
# Epoch 24/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.2479
# Epoch 00024: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0104 - coeff_determination: -1.2070
# Epoch 25/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.2709
# Epoch 00025: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0107 - coeff_determination: -1.3102
# Epoch 26/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: -1.1873
# Epoch 00026: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0112 - coeff_determination: -1.2626
# Epoch 27/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.1206
# Epoch 00027: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0109 - coeff_determination: -1.1142
# Epoch 28/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.5239
# Epoch 00028: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0108 - coeff_determination: -1.4927
# Epoch 29/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: -1.1147
# Epoch 00029: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0110 - coeff_determination: -1.1593
# Epoch 30/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0118 - coeff_determination: -1.2105
# Epoch 00030: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0115 - coeff_determination: -1.2237
# Epoch 31/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: -1.4025
# Epoch 00031: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0106 - coeff_determination: -1.4472
# Epoch 32/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.2625
# Epoch 00032: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0106 - coeff_determination: -1.2582
# Epoch 33/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: -1.5522
# Epoch 00033: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0121 - coeff_determination: -1.3779
# Epoch 34/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.2317
# Epoch 00034: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0105 - coeff_determination: -1.3188
# Epoch 35/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: -1.6132
# Epoch 00035: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: -1.5572
# Epoch 36/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.1876
# Epoch 00036: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0111 - coeff_determination: -1.4012
# Epoch 37/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0113 - coeff_determination: -1.1129
# Epoch 00037: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0110 - coeff_determination: -1.2144
# Epoch 38/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.0853
# Epoch 00038: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0103 - coeff_determination: -1.1341
# Epoch 39/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0115 - coeff_determination: -1.1843
# Epoch 00039: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0111 - coeff_determination: -1.1655
# Epoch 40/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.3013
# Epoch 00040: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0106 - coeff_determination: -1.3956
# Epoch 41/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.7401
# Epoch 00041: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0114 - coeff_determination: -1.6941
# Epoch 42/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.3734
# Epoch 00042: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0106 - coeff_determination: -1.4270
# Epoch 43/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.2072
# Epoch 00043: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0113 - coeff_determination: -1.2960
# Epoch 44/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.0829
# Epoch 00044: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: -1.1575
# Epoch 45/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.1946
# Epoch 00045: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0106 - coeff_determination: -1.1935
# Epoch 46/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.2856
# Epoch 00046: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0108 - coeff_determination: -1.4352
# Epoch 47/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.3663
# Epoch 00047: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0104 - coeff_determination: -1.5208
# Epoch 48/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.1798
# Epoch 00048: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0108 - coeff_determination: -1.1939
# Epoch 49/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.3767
# Epoch 00049: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: -1.3811
# Epoch 50/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.3872
# Epoch 00050: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: -1.4464
# Epoch 51/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: -0.9738
# Epoch 00051: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0111 - coeff_determination: -1.0477
# Epoch 52/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.2694
# Epoch 00052: loss did not improve from 0.01018
# 20/20 [==============================] - 0s 6ms/sample - loss: 0.0110 - coeff_determination: -1.2324
# Epoch 53/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.1954
# Epoch 00053: loss improved from 0.01018 to 0.00954, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0095 - coeff_determination: -1.2769
# Epoch 54/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.5382
# Epoch 00054: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0106 - coeff_determination: -1.5117
# Epoch 55/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.2998
# Epoch 00055: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: -1.2950
# Epoch 56/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0092 - coeff_determination: -1.1332
# Epoch 00056: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0097 - coeff_determination: -1.2424
# Epoch 57/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0117 - coeff_determination: -1.4223
# Epoch 00057: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0114 - coeff_determination: -1.4601
# Epoch 58/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.4464
# Epoch 00058: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0102 - coeff_determination: -1.3612
# Epoch 59/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.2754
# Epoch 00059: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0106 - coeff_determination: -1.2229
# Epoch 60/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.1659
# Epoch 00060: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0104 - coeff_determination: -1.1775
# Epoch 61/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0092 - coeff_determination: -1.2105
# Epoch 00061: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: -1.4645
# Epoch 62/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: -1.6222
# Epoch 00062: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0110 - coeff_determination: -1.5844
# Epoch 63/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.4560
# Epoch 00063: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0102 - coeff_determination: -1.4656
# Epoch 64/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.2658
# Epoch 00064: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0108 - coeff_determination: -1.2948
# Epoch 65/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: -1.1506
# Epoch 00065: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: -1.1243
# Epoch 66/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.3790
# Epoch 00066: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0105 - coeff_determination: -1.2809
# Epoch 67/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.5508
# Epoch 00067: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.6296
# Epoch 68/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.5555
# Epoch 00068: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0109 - coeff_determination: -1.4807
# Epoch 69/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.2336
# Epoch 00069: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: -1.2410
# Epoch 70/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.2465
# Epoch 00070: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0102 - coeff_determination: -1.2190
# Epoch 71/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.3100
# Epoch 00071: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0102 - coeff_determination: -1.3020
# Epoch 72/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.3824
# Epoch 00072: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.4129
# Epoch 73/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.0652
# Epoch 00073: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.1834
# Epoch 74/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.3723
# Epoch 00074: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0114 - coeff_determination: -1.1979
# Epoch 75/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: -0.9306
# Epoch 00075: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0122 - coeff_determination: -1.0591
# Epoch 76/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.3105
# Epoch 00076: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0110 - coeff_determination: -1.3296
# Epoch 77/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.4426
# Epoch 00077: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0105 - coeff_determination: -1.4915
# Epoch 78/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: -1.1834
# Epoch 00078: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0102 - coeff_determination: -1.2344
# Epoch 79/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.3263
# Epoch 00079: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: -1.4112
# Epoch 80/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.1185
# Epoch 00080: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: -1.2014
# Epoch 81/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.9752
# Epoch 00081: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.6892
# Epoch 82/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0118 - coeff_determination: -1.6682
# Epoch 00082: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0110 - coeff_determination: -1.6421
# Epoch 83/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.2707
# Epoch 00083: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.2514
# Epoch 84/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.2588
# Epoch 00084: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0103 - coeff_determination: -1.3188
# Epoch 85/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.4517
# Epoch 00085: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0104 - coeff_determination: -1.2970
# Epoch 86/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.3848
# Epoch 00086: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0107 - coeff_determination: -1.3101
# Epoch 87/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.3709
# Epoch 00087: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0099 - coeff_determination: -1.3462
# Epoch 88/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.1916
# Epoch 00088: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0104 - coeff_determination: -1.2541
# Epoch 89/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.4502
# Epoch 00089: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.3715
# Epoch 90/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.4206
# Epoch 00090: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: -1.3682
# Epoch 91/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: -1.2306
# Epoch 00091: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0109 - coeff_determination: -1.1313
# Epoch 92/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.1054
# Epoch 00092: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0106 - coeff_determination: -1.1439
# Epoch 93/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.3831
# Epoch 00093: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0102 - coeff_determination: -1.3549
# Epoch 94/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.0669
# Epoch 00094: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: -1.2997
# Epoch 95/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.1845
# Epoch 00095: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0109 - coeff_determination: -1.4689
# Epoch 96/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.3172
# Epoch 00096: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: -1.3805
# Epoch 97/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.2347
# Epoch 00097: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0107 - coeff_determination: -1.2804
# Epoch 98/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0112 - coeff_determination: -1.6166
# Epoch 00098: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0110 - coeff_determination: -1.5166
# Epoch 99/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.1784
# Epoch 00099: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: -1.3310
# Epoch 100/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.0944
# Epoch 00100: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0103 - coeff_determination: -1.2090
# Epoch 101/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.1966
# Epoch 00101: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0101 - coeff_determination: -1.3487
# Epoch 102/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.4917
# Epoch 00102: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0102 - coeff_determination: -1.4305
# Epoch 103/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.4089
# Epoch 00103: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0100 - coeff_determination: -1.3603
# Epoch 104/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0118 - coeff_determination: -1.2569
# Epoch 00104: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0117 - coeff_determination: -1.4361
# Epoch 105/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: -1.4562
# Epoch 00105: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0100 - coeff_determination: -1.2856
# Epoch 106/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.3165
# Epoch 00106: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0099 - coeff_determination: -1.2195
# Epoch 107/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.4824
# Epoch 00107: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0100 - coeff_determination: -1.3167
# Epoch 108/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.4419
# Epoch 00108: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0102 - coeff_determination: -1.4310
# Epoch 109/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.4686
# Epoch 00109: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0099 - coeff_determination: -1.4060
# Epoch 110/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.2344
# Epoch 00110: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0101 - coeff_determination: -1.2169
# Epoch 111/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.2686
# Epoch 00111: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0100 - coeff_determination: -1.2551
# Epoch 112/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.8752
# Epoch 00112: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.6574
# Epoch 113/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.5890
# Epoch 00113: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.4497
# Epoch 114/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.5199
# Epoch 00114: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.3583
# Epoch 115/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: -1.1597
# Epoch 00115: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0111 - coeff_determination: -1.1996
# Epoch 116/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.1738
# Epoch 00116: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0109 - coeff_determination: -1.1553
# Epoch 117/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: -0.9887
# Epoch 00117: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0111 - coeff_determination: -1.1231
# Epoch 118/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: -1.3941
# Epoch 00118: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: -1.2958
# Epoch 119/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: -1.4072
# Epoch 00119: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0106 - coeff_determination: -1.4089
# Epoch 120/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.8183
# Epoch 00120: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0103 - coeff_determination: -1.5940
# Epoch 121/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.2746
# Epoch 00121: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0098 - coeff_determination: -1.3178
# Epoch 122/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.1536
# Epoch 00122: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0103 - coeff_determination: -1.3585
# Epoch 123/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -1.3958
# Epoch 00123: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0103 - coeff_determination: -1.5264
# Epoch 124/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.5035
# Epoch 00124: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.3530
# Epoch 125/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.3505
# Epoch 00125: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0103 - coeff_determination: -1.3509
# Epoch 126/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -1.4709
# Epoch 00126: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0100 - coeff_determination: -1.4133
# Epoch 127/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0090 - coeff_determination: -1.2973
# Epoch 00127: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0096 - coeff_determination: -1.3951
# Epoch 128/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.5219
# Epoch 00128: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0102 - coeff_determination: -1.3035
# Epoch 129/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.2440
# Epoch 00129: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.2033
# Epoch 130/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.1318
# Epoch 00130: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0103 - coeff_determination: -1.2012
# Epoch 131/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0113 - coeff_determination: -1.0554
# Epoch 00131: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0110 - coeff_determination: -1.1907
# Epoch 132/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -1.3820
# Epoch 00132: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0100 - coeff_determination: -1.3379
# Epoch 133/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.5053
# Epoch 00133: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.5374
# Epoch 134/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.3349
# Epoch 00134: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0103 - coeff_determination: -1.4701
# Epoch 135/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.3082
# Epoch 00135: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0098 - coeff_determination: -1.2884
# Epoch 136/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: -0.9780
# Epoch 00136: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0103 - coeff_determination: -1.0999
# Epoch 137/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0109 - coeff_determination: -1.8129
# Epoch 00137: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0106 - coeff_determination: -1.7699
# Epoch 138/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.3388
# Epoch 00138: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0105 - coeff_determination: -1.7049
# Epoch 139/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.0215
# Epoch 00139: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0105 - coeff_determination: -1.1453
# Epoch 140/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.1489
# Epoch 00140: loss did not improve from 0.00954
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0097 - coeff_determination: -1.1318
# Epoch 141/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0091 - coeff_determination: -1.2191
# Epoch 00141: loss improved from 0.00954 to 0.00944, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0094 - coeff_determination: -1.3477
# Epoch 142/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.5209
# Epoch 00142: loss did not improve from 0.00944
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0095 - coeff_determination: -1.3943
# Epoch 143/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.0522
# Epoch 00143: loss did not improve from 0.00944
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0098 - coeff_determination: -1.0701
# Epoch 144/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0091 - coeff_determination: -1.1921
# Epoch 00144: loss did not improve from 0.00944
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0095 - coeff_determination: -1.1732
# Epoch 145/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0111 - coeff_determination: -0.9150
# Epoch 00145: loss did not improve from 0.00944
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0108 - coeff_determination: -0.9835
# Epoch 146/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.0040
# Epoch 00146: loss improved from 0.00944 to 0.00935, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0093 - coeff_determination: -1.0393
# Epoch 147/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: -0.9833
# Epoch 00147: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0106 - coeff_determination: -0.9598
# Epoch 148/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: -0.8803
# Epoch 00148: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: -0.8148
# Epoch 149/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.9639
# Epoch 00149: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0095 - coeff_determination: -0.9392
# Epoch 150/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.8049
# Epoch 00150: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0094 - coeff_determination: -0.9234
# Epoch 151/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.9219
# Epoch 00151: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0103 - coeff_determination: -0.8286
# Epoch 152/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: -0.7010
# Epoch 00152: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0097 - coeff_determination: -0.8144
# Epoch 153/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.1880
# Epoch 00153: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0095 - coeff_determination: -1.1106
# Epoch 154/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0100 - coeff_determination: -0.9746
# Epoch 00154: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0100 - coeff_determination: -0.8325
# Epoch 155/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.9719
# Epoch 00155: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0099 - coeff_determination: -0.9259
# Epoch 156/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.0508
# Epoch 00156: loss did not improve from 0.00935
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0101 - coeff_determination: -1.0867
# Epoch 157/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.0623
# Epoch 00157: loss improved from 0.00935 to 0.00909, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0091 - coeff_determination: -1.1541
# Epoch 158/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.7335
# Epoch 00158: loss did not improve from 0.00909
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0092 - coeff_determination: -1.0156
# Epoch 159/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0084 - coeff_determination: -0.5324
# Epoch 00159: loss improved from 0.00909 to 0.00873, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0087 - coeff_determination: -0.5943
# Epoch 160/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0094 - coeff_determination: -0.8210
# Epoch 00160: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0091 - coeff_determination: -0.7917
# Epoch 161/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: -0.7587
# Epoch 00161: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0099 - coeff_determination: -0.6719
# Epoch 162/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0089 - coeff_determination: -0.5039
# Epoch 00162: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0089 - coeff_determination: -0.6938
# Epoch 163/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: -0.7101
# Epoch 00163: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0093 - coeff_determination: -0.8281
# Epoch 164/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.8658
# Epoch 00164: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0095 - coeff_determination: -0.7977
# Epoch 165/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.9470
# Epoch 00165: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0094 - coeff_determination: -1.0799
# Epoch 166/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: -1.1360
# Epoch 00166: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: -0.8961
# Epoch 167/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: -0.6878
# Epoch 00167: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0091 - coeff_determination: -0.7148
# Epoch 168/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.5196
# Epoch 00168: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0096 - coeff_determination: -0.7339
# Epoch 169/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0093 - coeff_determination: -0.8777
# Epoch 00169: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0095 - coeff_determination: -0.9698
# Epoch 170/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.7852
# Epoch 00170: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0091 - coeff_determination: -0.9644
# Epoch 171/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0088 - coeff_determination: -0.6231
# Epoch 00171: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0090 - coeff_determination: -0.6137
# Epoch 172/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: -0.8207
# Epoch 00172: loss did not improve from 0.00873
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0099 - coeff_determination: -0.7040
# Epoch 173/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0087 - coeff_determination: -0.5300
# Epoch 00173: loss improved from 0.00873 to 0.00867, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0087 - coeff_determination: -0.6140
# Epoch 174/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0092 - coeff_determination: -0.6523
# Epoch 00174: loss did not improve from 0.00867
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0091 - coeff_determination: -0.7717
# Epoch 175/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: -0.6201
# Epoch 00175: loss did not improve from 0.00867
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0089 - coeff_determination: -0.5821
# Epoch 176/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.5256
# Epoch 00176: loss did not improve from 0.00867
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0092 - coeff_determination: -0.5360
# Epoch 177/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0091 - coeff_determination: -0.5371
# Epoch 00177: loss did not improve from 0.00867
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0091 - coeff_determination: -0.6177
# Epoch 178/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0084 - coeff_determination: -0.7264
# Epoch 00178: loss improved from 0.00867 to 0.00863, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0086 - coeff_determination: -0.7209
# Epoch 179/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.4728
# Epoch 00179: loss did not improve from 0.00863
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0093 - coeff_determination: -0.6234
# Epoch 180/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.1075
# Epoch 00180: loss did not improve from 0.00863
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0088 - coeff_determination: -0.7503
# Epoch 181/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0086 - coeff_determination: -0.6759
# Epoch 00181: loss improved from 0.00863 to 0.00854, saving model to NAT_LSTM_TP.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0085 - coeff_determination: -0.5487
# Epoch 182/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0090 - coeff_determination: -0.8682
# Epoch 00182: loss did not improve from 0.00854
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0086 - coeff_determination: -0.7449
# ...
# Epoch 4941/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.9871e-04 - coeff_determination: 0.9570
# Epoch 04941: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 16ms/sample - loss: 5.2199e-04 - coeff_determination: 0.9542
# Epoch 4942/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 8.1403e-04 - coeff_determination: 0.9214
# Epoch 04942: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 17ms/sample - loss: 7.1032e-04 - coeff_determination: 0.9326
# Epoch 4943/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.4739e-04 - coeff_determination: 0.9452
# Epoch 04943: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.9074e-04 - coeff_determination: 0.9504
# Epoch 4944/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 7.5837e-04 - coeff_determination: 0.9298
# Epoch 04944: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 9.7647e-04 - coeff_determination: 0.9092
# Epoch 4945/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.4101e-04 - coeff_determination: 0.9444
# Epoch 04945: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 11ms/sample - loss: 6.5592e-04 - coeff_determination: 0.9435
# Epoch 4946/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.8266e-04 - coeff_determination: 0.9577
# Epoch 04946: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.1427e-04 - coeff_determination: 0.9550
# Epoch 4947/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.3285e-04 - coeff_determination: 0.9556
# Epoch 04947: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 4.9325e-04 - coeff_determination: 0.9593
# Epoch 4948/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 7.0282e-04 - coeff_determination: 0.9385
# Epoch 04948: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 7.3170e-04 - coeff_determination: 0.9349
# Epoch 4949/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.0344e-04 - coeff_determination: 0.9485
# Epoch 04949: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 11ms/sample - loss: 6.1495e-04 - coeff_determination: 0.9489
# Epoch 4950/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.7843e-04 - coeff_determination: 0.9310
# Epoch 04950: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 11ms/sample - loss: 7.1206e-04 - coeff_determination: 0.9377
# Epoch 4951/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.0442e-04 - coeff_determination: 0.9575
# Epoch 04951: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 11ms/sample - loss: 6.0946e-04 - coeff_determination: 0.9465
# Epoch 4952/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.0230e-04 - coeff_determination: 0.9577
# Epoch 04952: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.4400e-04 - coeff_determination: 0.9541
# Epoch 4953/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 8.3907e-04 - coeff_determination: 0.9229
# Epoch 04953: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 8.5176e-04 - coeff_determination: 0.9237
# Epoch 4954/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.4412e-04 - coeff_determination: 0.9535
# Epoch 04954: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.8834e-04 - coeff_determination: 0.9505
# Epoch 4955/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.1524e-04 - coeff_determination: 0.9566
# Epoch 04955: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.1862e-04 - coeff_determination: 0.9574
# Epoch 4956/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.1540e-04 - coeff_determination: 0.9497
# Epoch 04956: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.7187e-04 - coeff_determination: 0.9531
# Epoch 4957/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.8719e-04 - coeff_determination: 0.9510
# Epoch 04957: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 14ms/sample - loss: 6.7403e-04 - coeff_determination: 0.9411
# Epoch 4958/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 8.0939e-04 - coeff_determination: 0.9248
# Epoch 04958: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 8.7514e-04 - coeff_determination: 0.9202
# Epoch 4959/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.5821e-04 - coeff_determination: 0.9534
# Epoch 04959: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 16ms/sample - loss: 5.8187e-04 - coeff_determination: 0.9513
# Epoch 4960/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.1136e-04 - coeff_determination: 0.9480
# Epoch 04960: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 6.0041e-04 - coeff_determination: 0.9489
# Epoch 4961/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.5439e-04 - coeff_determination: 0.9628
# Epoch 04961: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 5.3189e-04 - coeff_determination: 0.9532
# Epoch 4962/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2085e-04 - coeff_determination: 0.9545
# Epoch 04962: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.0827e-04 - coeff_determination: 0.9566
# Epoch 4963/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.6608e-04 - coeff_determination: 0.9518
# Epoch 04963: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 6.7562e-04 - coeff_determination: 0.9374
# Epoch 4964/5000
# 12/20 [=================>............] - ETA: 0s - loss: 9.7451e-04 - coeff_determination: 0.9027
# Epoch 04964: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 7.5093e-04 - coeff_determination: 0.9288
# Epoch 4965/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.9419e-04 - coeff_determination: 0.9495
# Epoch 04965: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 5.9941e-04 - coeff_determination: 0.9485
# Epoch 4966/5000
# 12/20 [=================>............] - ETA: 0s - loss: 8.8826e-04 - coeff_determination: 0.9210
# Epoch 04966: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 8.5678e-04 - coeff_determination: 0.9214
# Epoch 4967/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.6365e-04 - coeff_determination: 0.9540
# Epoch 04967: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 6.0034e-04 - coeff_determination: 0.9495
# Epoch 4968/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.3366e-04 - coeff_determination: 0.9638
# Epoch 04968: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 6.7893e-04 - coeff_determination: 0.9387
# Epoch 4969/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.5037e-04 - coeff_determination: 0.9458
# Epoch 04969: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 5.8290e-04 - coeff_determination: 0.9508
# Epoch 4970/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.0257e-04 - coeff_determination: 0.9366
# Epoch 04970: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 7.3424e-04 - coeff_determination: 0.9351
# Epoch 4971/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.2356e-04 - coeff_determination: 0.9433
# Epoch 04971: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 5.9589e-04 - coeff_determination: 0.9487
# Epoch 4972/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.2782e-04 - coeff_determination: 0.9500
# Epoch 04972: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 6.3874e-04 - coeff_determination: 0.9481
# Epoch 4973/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.2693e-04 - coeff_determination: 0.9369
# Epoch 04973: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 10ms/sample - loss: 7.8620e-04 - coeff_determination: 0.9307
# Epoch 4974/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.8742e-04 - coeff_determination: 0.9485
# Epoch 04974: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 6.2827e-04 - coeff_determination: 0.9445
# Epoch 4975/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1136e-04 - coeff_determination: 0.9587
# Epoch 04975: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 8.0155e-04 - coeff_determination: 0.9223
# Epoch 4976/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.9361e-04 - coeff_determination: 0.9250
# Epoch 04976: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 8.7785e-04 - coeff_determination: 0.9174
# Epoch 4977/5000
# 12/20 [=================>............] - ETA: 0s - loss: 9.5902e-04 - coeff_determination: 0.9032
# Epoch 04977: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 9.2955e-04 - coeff_determination: 0.9086
# Epoch 4978/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.7358e-04 - coeff_determination: 0.9331
# Epoch 04978: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.2875e-04 - coeff_determination: 0.9378
# Epoch 4979/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.2272e-04 - coeff_determination: 0.9509
# Epoch 04979: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 6.8731e-04 - coeff_determination: 0.9416
# Epoch 4980/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.6767e-04 - coeff_determination: 0.9456
# Epoch 04980: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 10ms/sample - loss: 8.0509e-04 - coeff_determination: 0.9314
# Epoch 4981/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.3468e-04 - coeff_determination: 0.9368
# Epoch 04981: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 6.6206e-04 - coeff_determination: 0.9433
# Epoch 4982/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.6501e-04 - coeff_determination: 0.9412
# Epoch 04982: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 8.3483e-04 - coeff_determination: 0.9318
# Epoch 4983/5000
# 12/20 [=================>............] - ETA: 0s - loss: 9.5190e-04 - coeff_determination: 0.9138
# Epoch 04983: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 9.6548e-04 - coeff_determination: 0.9101
# Epoch 4984/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.8876e-04 - coeff_determination: 0.9392
# Epoch 04984: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 7.2210e-04 - coeff_determination: 0.9365
# Epoch 4985/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.8143e-04 - coeff_determination: 0.9387
# Epoch 04985: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 5.7351e-04 - coeff_determination: 0.9514
# Epoch 4986/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.6731e-04 - coeff_determination: 0.9279
# Epoch 04986: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.6758e-04 - coeff_determination: 0.9322
# Epoch 4987/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.3279e-04 - coeff_determination: 0.9328
# Epoch 04987: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 6.6514e-04 - coeff_determination: 0.9418
# Epoch 4988/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.8631e-04 - coeff_determination: 0.9602
# Epoch 04988: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 5.0860e-04 - coeff_determination: 0.9571
# Epoch 4989/5000
# 12/20 [=================>............] - ETA: 0s - loss: 9.1659e-04 - coeff_determination: 0.9137
# Epoch 04989: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 7.7498e-04 - coeff_determination: 0.9297
# Epoch 4990/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.7821e-04 - coeff_determination: 0.9507
# Epoch 04990: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 8ms/sample - loss: 7.5762e-04 - coeff_determination: 0.9332
# Epoch 4991/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.6788e-04 - coeff_determination: 0.9302
# Epoch 04991: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.1795e-04 - coeff_determination: 0.9377
# Epoch 4992/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.7339e-04 - coeff_determination: 0.9396
# Epoch 04992: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 16ms/sample - loss: 7.4483e-04 - coeff_determination: 0.9326
# Epoch 4993/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.9619e-04 - coeff_determination: 0.9385
# Epoch 04993: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 12ms/sample - loss: 7.3882e-04 - coeff_determination: 0.9355
# Epoch 4994/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 7.5880e-04 - coeff_determination: 0.9362
# Epoch 04994: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 13ms/sample - loss: 7.5549e-04 - coeff_determination: 0.9369
# Epoch 4995/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.2563e-04 - coeff_determination: 0.9482
# Epoch 04995: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 11ms/sample - loss: 6.9204e-04 - coeff_determination: 0.9412
# Epoch 4996/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.6297e-04 - coeff_determination: 0.9400
# Epoch 04996: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 10ms/sample - loss: 6.0461e-04 - coeff_determination: 0.9467
# Epoch 4997/5000
# 12/20 [=================>............] - ETA: 0s - loss: 7.5370e-04 - coeff_determination: 0.9312
# Epoch 04997: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.0505e-04 - coeff_determination: 0.9368
# Epoch 4998/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.6899e-04 - coeff_determination: 0.9575
# Epoch 04998: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 9ms/sample - loss: 6.8219e-04 - coeff_determination: 0.9352
# Epoch 4999/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.9823e-04 - coeff_determination: 0.9384
# Epoch 04999: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 16ms/sample - loss: 6.8101e-04 - coeff_determination: 0.9411
# Epoch 5000/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 6.2164e-04 - coeff_determination: 0.9472
# Epoch 05000: loss did not improve from 0.00038
# 20/20 [==============================] - 0s 16ms/sample - loss: 6.1426e-04 - coeff_determination: 0.9472

# %%
import matplotlib.pyplot as plt
# Load model weights first
lstm_model.load_weights(weights_filepath)

# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(500,num_modes+2))
test_data[:,:num_modes] = true_pca_evol[:,:]

test_data[:,-2] = -1.0/2.7
test_data[:,-1] = -1.0/4.0

viz = False

mse_val = 0.0
num_inference = 1000
pred_mean = np.zeros_like(test_data)[:,:-2]
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[0],np.shape(test_data)[1]-2))

from time import time

start_time = time()

for inference in range(num_inference):

    testing_inputs = np.copy(test_data[:seq_num,:]).reshape(1,seq_num,state_len+2,order='F')
    true_outputs = np.copy(test_data[seq_num:,:state_len]).reshape(1,500-seq_num,state_len,order='F')
    predicted_outputs = lstm_model.predict(testing_inputs).reshape(1,500-seq_num,state_len,order='F')
    
    true_plot_array = np.concatenate((testing_inputs[:,:,:state_len],true_outputs),axis=1)
    pred_plot_array = np.concatenate((testing_inputs[:,:,:state_len],predicted_outputs),axis=1)
    
    pred_pca_array[inference,:,:] = pred_plot_array[0,:,:]
    
    mse_val = mse_val + np.sum((pred_plot_array[0,:,:]-test_data[:,:-2])**2)
    pred_mean = pred_mean + pred_plot_array[0,:,:]
    
    if viz:

        fig,ax = plt.subplots(nrows=2,ncols=2)
        ax[0,0].plot(true_plot_array[0,:,0],label='True')
        ax[0,0].plot(pred_plot_array[0,:,0],label='Predicted')
        ax[0,0].set_title('Mode 1')


        ax[1,0].plot(true_plot_array[0,:,1],label='True')
        ax[1,0].plot(pred_plot_array[0,:,1],label='Predicted')
        ax[1,0].set_title('Mode 2')

        ax[0,1].plot(true_plot_array[0,:,2],label='True')
        ax[0,1].plot(pred_plot_array[0,:,2],label='Predicted')
        ax[0,1].set_title('Mode 3')

        ax[1,1].plot(true_plot_array[0,:,3],label='True')
        ax[1,1].plot(pred_plot_array[0,:,3],label='Predicted')
        ax[1,1].set_title('Mode 4')

        plt.tight_layout()
        plt.legend()
        plt.show()

        # Plotting some contours
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

        pred_rb = pred_plot_array[0,:,:]
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()
        
end_time = time()

# %%
print('Time elapsed per inference',(end_time-start_time)/num_inference)
# Out:
# Time elapsed per inference 0.007647573947906494

# %%
pred_mean = pred_mean/num_inference

# Calculate standard deviation
pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[:,:])**2,axis=0)/(num_inference-1))
        
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[:,0],label='True')
ax[0,0].plot(pred_mean[:,0],label='Predicted mean')
ax[0,0].fill_between(np.arange(500),pred_mean[:,0]+pred_sdev[:,0],pred_mean[:,0]-pred_sdev[:,0],label='1 std')
ax[0,0].set_title('Mode 1')



ax[1,0].plot(test_data[:,1],label='True')
ax[1,0].plot(pred_mean[:,1],label='Predicted mean')
ax[1,0].fill_between(np.arange(500),pred_mean[:,1]+pred_sdev[:,1],pred_mean[:,1]-pred_sdev[:,1],label='1 std')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[:,2],label='True')
ax[0,1].plot(pred_mean[:,2],label='Predicted mean')
ax[0,1].fill_between(np.arange(500),pred_mean[:,2]+pred_sdev[:,2],pred_mean[:,2]-pred_sdev[:,2],label='1 std')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[:,3],label='True')
ax[1,1].plot(pred_mean[:,3],label='Predicted mean')
ax[1,1].fill_between(np.arange(500),pred_mean[:,3]+pred_sdev[:,3],pred_mean[:,3]-pred_sdev[:,3],label='1 std')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
np.save('../Figures/NAT_LSTM_TP_Mean.npy',pred_mean)
np.save('../Figures/NAT_LSTM_TP_SD.npy',pred_sdev)
