# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]

coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = np.transpose(coeff_scaler.fit_transform(np.transpose(pca_coeffs)))

# %%
num_sims = np.shape(locs)[0]
num_ivs = np.shape(locs)[1]
num_coeffs = np.shape(pca_coeffs)[0]
burn_in = 20

# %%
# Reshape
training_data_ip = np.zeros(shape=(num_sims,num_coeffs+num_ivs,burn_in),dtype='double')
training_data_op = np.zeros(shape=(num_sims,num_coeffs+num_ivs,500-burn_in),dtype='double')

for sim in range(num_sims):
    training_data_ip[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim:500*sim+burn_in]
    training_data_ip[sim,-num_ivs:,:] = locs[sim,:,None]
    training_data_op[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim+burn_in:500*(sim+1)]
    training_data_op[sim,-num_ivs:,:] = locs[sim,:,None]

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_LSTM_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(num_coeffs+num_ivs,burn_in),name='nat_inputs')
h1 = LSTM(195,return_sequences=True)(lstm_inputs)
h1 = Dropout(0.2)(h1,training=True)
h2 = LSTM(195,return_sequences=True)(h1)
h2 = Dropout(0.2)(h2,training=True)
lstm_outputs = Dense(500-burn_in,activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0127 14:40:33.884612 140466813642560 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# nat_inputs (InputLayer)      [(None, 42, 20)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 42, 195)           168480
# _________________________________________________________________
# dropout (Dropout)            (None, 42, 195)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 42, 195)           304980
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 195)           0
# _________________________________________________________________
# dense (Dense)                (None, 42, 480)           94080
# =================================================================
# Total params: 567,540
# Trainable params: 567,540
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = True

if train_mode:
    train_history = lstm_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_LSTM_PT.npy',train_history.history['loss'])
# Out:
# W0121 19:42:51.270466 139773456013120 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.2528 - coeff_determination: -134.6705
# Epoch 00001: loss improved from inf to 0.24896, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 1s 50ms/sample - loss: 0.2490 - coeff_determination: -123.0971
# Epoch 2/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.2206 - coeff_determination: -47.8942
# Epoch 00002: loss improved from 0.24896 to 0.21088, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.2109 - coeff_determination: -36.3195
# Epoch 3/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.1600 - coeff_determination: -7.4376
# Epoch 00003: loss improved from 0.21088 to 0.14780, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.1478 - coeff_determination: -5.6305
# Epoch 4/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.1008 - coeff_determination: -1.0994
# Epoch 00004: loss improved from 0.14780 to 0.09633, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0963 - coeff_determination: -0.9664
# Epoch 5/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0738 - coeff_determination: -0.5936
# Epoch 00005: loss improved from 0.09633 to 0.07138, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0714 - coeff_determination: -0.6093
# Epoch 6/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0544 - coeff_determination: -0.8801
# Epoch 00006: loss improved from 0.07138 to 0.05403, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0540 - coeff_determination: -0.9374
# Epoch 7/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0467 - coeff_determination: -1.2627
# Epoch 00007: loss improved from 0.05403 to 0.04750, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0475 - coeff_determination: -1.3866
# Epoch 8/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0439 - coeff_determination: -1.4898
# Epoch 00008: loss improved from 0.04750 to 0.04535, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0453 - coeff_determination: -1.6062
# Epoch 9/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0423 - coeff_determination: -1.5515
# Epoch 00009: loss improved from 0.04535 to 0.04248, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0425 - coeff_determination: -1.5759
# Epoch 10/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0407 - coeff_determination: -1.6047
# Epoch 00010: loss improved from 0.04248 to 0.04060, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0406 - coeff_determination: -1.6158
# Epoch 11/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0409 - coeff_determination: -1.8958
# Epoch 00011: loss improved from 0.04060 to 0.03895, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0390 - coeff_determination: -1.7665
# Epoch 12/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0384 - coeff_determination: -1.9882
# Epoch 00012: loss improved from 0.03895 to 0.03727, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0373 - coeff_determination: -1.9032
# Epoch 13/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0369 - coeff_determination: -2.0540
# Epoch 00013: loss improved from 0.03727 to 0.03537, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0354 - coeff_determination: -1.9339
# Epoch 14/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0364 - coeff_determination: -2.1549
# Epoch 00014: loss improved from 0.03537 to 0.03429, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0343 - coeff_determination: -1.9495
# Epoch 15/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0347 - coeff_determination: -2.1530
# Epoch 00015: loss improved from 0.03429 to 0.03311, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0331 - coeff_determination: -2.0270
# Epoch 16/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0324 - coeff_determination: -1.8748
# Epoch 00016: loss improved from 0.03311 to 0.03242, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0324 - coeff_determination: -1.9464
# Epoch 17/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0317 - coeff_determination: -1.9461
# Epoch 00017: loss improved from 0.03242 to 0.03118, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0312 - coeff_determination: -1.9032
# Epoch 18/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0306 - coeff_determination: -1.9382
# Epoch 00018: loss improved from 0.03118 to 0.03058, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0306 - coeff_determination: -1.9175
# Epoch 19/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0298 - coeff_determination: -1.8612
# Epoch 00019: loss improved from 0.03058 to 0.02957, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0296 - coeff_determination: -1.7743
# Epoch 20/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0288 - coeff_determination: -1.6566
# Epoch 00020: loss improved from 0.02957 to 0.02866, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0287 - coeff_determination: -1.6187
# Epoch 21/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0257 - coeff_determination: -1.3058
# Epoch 00021: loss improved from 0.02866 to 0.02783, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0278 - coeff_determination: -1.5069
# Epoch 22/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0275 - coeff_determination: -1.4463
# Epoch 00022: loss improved from 0.02783 to 0.02696, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0270 - coeff_determination: -1.3470
# Epoch 23/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0271 - coeff_determination: -1.4685
# Epoch 00023: loss improved from 0.02696 to 0.02607, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0261 - coeff_determination: -1.4178
# Epoch 24/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0240 - coeff_determination: -1.0685
# Epoch 00024: loss improved from 0.02607 to 0.02506, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0251 - coeff_determination: -1.1406
# Epoch 25/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0237 - coeff_determination: -0.9894
# Epoch 00025: loss improved from 0.02506 to 0.02450, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0245 - coeff_determination: -1.0699
# Epoch 26/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0234 - coeff_determination: -0.9000
# Epoch 00026: loss improved from 0.02450 to 0.02355, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0235 - coeff_determination: -0.9406
# Epoch 27/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0227 - coeff_determination: -0.8327
# Epoch 00027: loss did not improve from 0.02355
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0236 - coeff_determination: -0.9341
# Epoch 28/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0230 - coeff_determination: -0.7868
# Epoch 00028: loss improved from 0.02355 to 0.02319, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0232 - coeff_determination: -0.8206
# Epoch 29/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0222 - coeff_determination: -0.6568
# Epoch 00029: loss improved from 0.02319 to 0.02206, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0221 - coeff_determination: -0.6751
# Epoch 30/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0208 - coeff_determination: -0.5053
# Epoch 00030: loss improved from 0.02206 to 0.02142, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0214 - coeff_determination: -0.6240
# Epoch 31/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0212 - coeff_determination: -0.6849
# Epoch 00031: loss improved from 0.02142 to 0.02081, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0208 - coeff_determination: -0.6614
# Epoch 32/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0210 - coeff_determination: -0.7093
# Epoch 00032: loss improved from 0.02081 to 0.02074, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0207 - coeff_determination: -0.5929
# Epoch 33/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0201 - coeff_determination: -0.4817
# Epoch 00033: loss improved from 0.02074 to 0.01976, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0198 - coeff_determination: -0.4543
# Epoch 34/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0202 - coeff_determination: -0.3538
# Epoch 00034: loss improved from 0.01976 to 0.01945, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0195 - coeff_determination: -0.3355
# Epoch 35/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0198 - coeff_determination: -0.4385
# Epoch 00035: loss improved from 0.01945 to 0.01912, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0191 - coeff_determination: -0.3535
# Epoch 36/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0185 - coeff_determination: -0.4491
# Epoch 00036: loss did not improve from 0.01912
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0191 - coeff_determination: -0.3945
# Epoch 37/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0186 - coeff_determination: -0.3481
# Epoch 00037: loss improved from 0.01912 to 0.01834, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0183 - coeff_determination: -0.3153
# Epoch 38/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0179 - coeff_determination: -0.1530
# Epoch 00038: loss improved from 0.01834 to 0.01768, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0177 - coeff_determination: -0.1711
# Epoch 39/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0173 - coeff_determination: -0.1143
# Epoch 00039: loss improved from 0.01768 to 0.01727, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0173 - coeff_determination: -0.2157
# Epoch 40/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0175 - coeff_determination: -0.2508
# Epoch 00040: loss improved from 0.01727 to 0.01718, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0172 - coeff_determination: -0.1046
# Epoch 41/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0166 - coeff_determination: -0.1099
# Epoch 00041: loss did not improve from 0.01718
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0173 - coeff_determination: -0.1292
# Epoch 42/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0165 - coeff_determination: 0.1033
# Epoch 00042: loss improved from 0.01718 to 0.01660, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0166 - coeff_determination: -0.0615
# Epoch 43/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0169 - coeff_determination: 0.0030
# Epoch 00043: loss improved from 0.01660 to 0.01647, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0165 - coeff_determination: -0.1179
# Epoch 44/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0158 - coeff_determination: -0.0774
# Epoch 00044: loss improved from 0.01647 to 0.01571, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0157 - coeff_determination: 0.0144
# Epoch 45/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0158 - coeff_determination: -0.0721
# Epoch 00045: loss did not improve from 0.01571
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0163 - coeff_determination: -0.0308
# Epoch 46/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0157 - coeff_determination: 0.0955
# Epoch 00046: loss did not improve from 0.01571
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0158 - coeff_determination: 0.0570
# Epoch 47/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0157 - coeff_determination: -0.0352
# Epoch 00047: loss improved from 0.01571 to 0.01526, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0153 - coeff_determination: 0.0643
# Epoch 48/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0156 - coeff_determination: -0.1734
# Epoch 00048: loss did not improve from 0.01526
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0154 - coeff_determination: -0.0163
# Epoch 49/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0149 - coeff_determination: 0.0283
# Epoch 00049: loss improved from 0.01526 to 0.01514, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0151 - coeff_determination: 0.0544
# Epoch 50/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0150 - coeff_determination: 0.0369
# Epoch 00050: loss improved from 0.01514 to 0.01501, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0150 - coeff_determination: 0.0353
# Epoch 51/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0149 - coeff_determination: 0.0881
# Epoch 00051: loss improved from 0.01501 to 0.01499, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0150 - coeff_determination: 0.1358
# Epoch 52/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0146 - coeff_determination: -0.0545
# Epoch 00052: loss improved from 0.01499 to 0.01466, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0147 - coeff_determination: 0.0806
# Epoch 53/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0152 - coeff_determination: 0.1929
# Epoch 00053: loss did not improve from 0.01466
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0150 - coeff_determination: 0.1000
# Epoch 54/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0144 - coeff_determination: 0.1099
# Epoch 00054: loss did not improve from 0.01466
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0148 - coeff_determination: 0.1160
# Epoch 55/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0142 - coeff_determination: 0.0757
# Epoch 00055: loss improved from 0.01466 to 0.01438, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0144 - coeff_determination: 0.1423
# Epoch 56/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0145 - coeff_determination: 0.0771
# Epoch 00056: loss improved from 0.01438 to 0.01427, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0143 - coeff_determination: 0.1658
# Epoch 57/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0145 - coeff_determination: 0.0441
# Epoch 00057: loss did not improve from 0.01427
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0146 - coeff_determination: 0.0873
# Epoch 58/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0145 - coeff_determination: 0.1761
# Epoch 00058: loss did not improve from 0.01427
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0143 - coeff_determination: 0.1660
# Epoch 59/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0137 - coeff_determination: 0.2541
# Epoch 00059: loss improved from 0.01427 to 0.01403, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0140 - coeff_determination: 0.2149
# Epoch 60/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0140 - coeff_determination: 0.1466
# Epoch 00060: loss improved from 0.01403 to 0.01395, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0140 - coeff_determination: 0.1105
# Epoch 61/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0135 - coeff_determination: 0.3005
# Epoch 00061: loss improved from 0.01395 to 0.01357, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0136 - coeff_determination: 0.2904
# Epoch 62/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0143 - coeff_determination: 0.0752
# Epoch 00062: loss did not improve from 0.01357
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0142 - coeff_determination: 0.0680
# Epoch 63/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0141 - coeff_determination: 0.2103
# Epoch 00063: loss did not improve from 0.01357
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0142 - coeff_determination: 0.1735
# Epoch 64/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0135 - coeff_determination: 0.1942
# Epoch 00064: loss improved from 0.01357 to 0.01350, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0135 - coeff_determination: 0.2328
# Epoch 65/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0140 - coeff_determination: 0.2231
# Epoch 00065: loss did not improve from 0.01350
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0138 - coeff_determination: 0.2246
# Epoch 66/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0137 - coeff_determination: -0.1101
# Epoch 00066: loss did not improve from 0.01350
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0139 - coeff_determination: 0.0891
# Epoch 67/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0135 - coeff_determination: 0.1701
# Epoch 00067: loss improved from 0.01350 to 0.01345, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0135 - coeff_determination: 0.1686
# Epoch 68/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0136 - coeff_determination: 0.2896
# Epoch 00068: loss did not improve from 0.01345
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0136 - coeff_determination: 0.2756
# Epoch 69/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0134 - coeff_determination: 0.3861
# Epoch 00069: loss did not improve from 0.01345
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0136 - coeff_determination: 0.0912
# Epoch 70/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.1708
# Epoch 00070: loss improved from 0.01345 to 0.01334, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0133 - coeff_determination: 0.2219
# Epoch 71/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0141 - coeff_determination: 0.0348
# Epoch 00071: loss did not improve from 0.01334
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0136 - coeff_determination: 0.1618
# Epoch 72/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0137 - coeff_determination: 0.2476
# Epoch 00072: loss did not improve from 0.01334
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0134 - coeff_determination: 0.2100
# Epoch 73/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: 0.1384
# Epoch 00073: loss did not improve from 0.01334
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0135 - coeff_determination: 0.1994
# Epoch 74/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0137 - coeff_determination: 0.1344
# Epoch 00074: loss did not improve from 0.01334
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0137 - coeff_determination: 0.1305
# Epoch 75/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: 0.3562
# Epoch 00075: loss improved from 0.01334 to 0.01320, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0132 - coeff_determination: 0.1303
# Epoch 76/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: 0.3109
# Epoch 00076: loss did not improve from 0.01320
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0134 - coeff_determination: 0.3092
# Epoch 77/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0136 - coeff_determination: 0.1871
# Epoch 00077: loss did not improve from 0.01320
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0135 - coeff_determination: 0.2514
# Epoch 78/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0131 - coeff_determination: 0.1291
# Epoch 00078: loss did not improve from 0.01320
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0135 - coeff_determination: 0.0799
# Epoch 79/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0136 - coeff_determination: 0.0863
# Epoch 00079: loss did not improve from 0.01320
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0138 - coeff_determination: 0.1782
# Epoch 80/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.3376
# Epoch 00080: loss improved from 0.01320 to 0.01298, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0130 - coeff_determination: 0.3035
# Epoch 81/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2426
# Epoch 00081: loss improved from 0.01298 to 0.01276, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0128 - coeff_determination: 0.2759
# Epoch 82/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0138 - coeff_determination: -0.0394
# Epoch 00082: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0134 - coeff_determination: 0.1236
# Epoch 83/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.2799
# Epoch 00083: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0129 - coeff_determination: 0.2130
# Epoch 84/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0132 - coeff_determination: 0.2903
# Epoch 00084: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0130 - coeff_determination: 0.2579
# Epoch 85/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0130 - coeff_determination: 0.3207
# Epoch 00085: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0131 - coeff_determination: 0.1939
# Epoch 86/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0134 - coeff_determination: -0.0625
# Epoch 00086: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0134 - coeff_determination: 0.0562
# Epoch 87/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0135 - coeff_determination: 0.1422
# Epoch 00087: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0134 - coeff_determination: 0.2114
# Epoch 88/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0128 - coeff_determination: -0.0028
# Epoch 00088: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0130 - coeff_determination: 0.1816
# Epoch 89/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.3399
# Epoch 00089: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0128 - coeff_determination: 0.2577
# Epoch 90/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: 0.2034
# Epoch 00090: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0132 - coeff_determination: 0.2176
# Epoch 91/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.2563
# Epoch 00091: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0130 - coeff_determination: 0.2651
# Epoch 92/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.1531
# Epoch 00092: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0129 - coeff_determination: 0.2207
# Epoch 93/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.1837
# Epoch 00093: loss did not improve from 0.01276
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0129 - coeff_determination: 0.2776
# Epoch 94/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.2138
# Epoch 00094: loss improved from 0.01276 to 0.01247, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0125 - coeff_determination: 0.2526
# Epoch 95/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.1976
# Epoch 00095: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0130 - coeff_determination: 0.2116
# Epoch 96/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.3744
# Epoch 00096: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0129 - coeff_determination: 0.2754
# Epoch 97/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2394
# Epoch 00097: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0126 - coeff_determination: 0.2799
# Epoch 98/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.2269
# Epoch 00098: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0127 - coeff_determination: 0.2653
# Epoch 99/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0130 - coeff_determination: 0.2396
# Epoch 00099: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0128 - coeff_determination: 0.2559
# Epoch 100/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.2371
# Epoch 00100: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0128 - coeff_determination: 0.2484
# Epoch 101/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.3052
# Epoch 00101: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0125 - coeff_determination: 0.2656
# Epoch 102/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.2515
# Epoch 00102: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0129 - coeff_determination: 0.2275
# Epoch 103/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: 0.1898
# Epoch 00103: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0129 - coeff_determination: 0.1829
# Epoch 104/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.1458
# Epoch 00104: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0128 - coeff_determination: 0.1920
# Epoch 105/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.2905
# Epoch 00105: loss did not improve from 0.01247
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0125 - coeff_determination: 0.2964
# Epoch 106/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0131 - coeff_determination: 0.0935
# Epoch 00106: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0129 - coeff_determination: 0.1675
# Epoch 107/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.3530
# Epoch 00107: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0125 - coeff_determination: 0.3019
# Epoch 108/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.3985
# Epoch 00108: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0125 - coeff_determination: 0.2586
# Epoch 109/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.2379
# Epoch 00109: loss did not improve from 0.01247
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0125 - coeff_determination: 0.2367
# Epoch 110/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.1990
# Epoch 00110: loss improved from 0.01247 to 0.01242, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0124 - coeff_determination: 0.2477
# Epoch 111/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.1931
# Epoch 00111: loss did not improve from 0.01242
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0127 - coeff_determination: 0.2468
# Epoch 112/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.3375
# Epoch 00112: loss did not improve from 0.01242
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0126 - coeff_determination: 0.2990
# Epoch 113/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.3976
# Epoch 00113: loss improved from 0.01242 to 0.01234, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0123 - coeff_determination: 0.3325
# Epoch 114/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.1800
# Epoch 00114: loss did not improve from 0.01234
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0125 - coeff_determination: 0.2278
# Epoch 115/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.3767
# Epoch 00115: loss did not improve from 0.01234
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0127 - coeff_determination: 0.3520
# Epoch 116/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.1561
# Epoch 00116: loss did not improve from 0.01234
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0126 - coeff_determination: 0.2029
# Epoch 117/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.2513
# Epoch 00117: loss improved from 0.01234 to 0.01226, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0123 - coeff_determination: 0.2783
# Epoch 118/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.3619
# Epoch 00118: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0123 - coeff_determination: 0.2151
# Epoch 119/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.3294
# Epoch 00119: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0123 - coeff_determination: 0.2634
# Epoch 120/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0127 - coeff_determination: 0.2410
# Epoch 00120: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0126 - coeff_determination: 0.2405
# Epoch 121/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.0053
# Epoch 00121: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0123 - coeff_determination: 0.0922
# Epoch 122/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.0900
# Epoch 00122: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0124 - coeff_determination: 0.1853
# Epoch 123/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2853
# Epoch 00123: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0124 - coeff_determination: 0.2011
# Epoch 124/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.3942
# Epoch 00124: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0123 - coeff_determination: 0.1624
# Epoch 125/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.1339
# Epoch 00125: loss did not improve from 0.01226
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0123 - coeff_determination: 0.2019
# Epoch 126/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2968
# Epoch 00126: loss improved from 0.01226 to 0.01218, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0122 - coeff_determination: 0.2935
# Epoch 127/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.3327
# Epoch 00127: loss improved from 0.01218 to 0.01212, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0121 - coeff_determination: 0.2931
# Epoch 128/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.3036
# Epoch 00128: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0122 - coeff_determination: 0.3068
# Epoch 129/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0128 - coeff_determination: 0.3545
# Epoch 00129: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0126 - coeff_determination: 0.3015
# Epoch 130/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.3349
# Epoch 00130: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0122 - coeff_determination: 0.2772
# Epoch 131/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.1643
# Epoch 00131: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0124 - coeff_determination: 0.2765
# Epoch 132/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.2110
# Epoch 00132: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0124 - coeff_determination: 0.2574
# Epoch 133/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.2935
# Epoch 00133: loss did not improve from 0.01212
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0125 - coeff_determination: 0.1774
# Epoch 134/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.1454
# Epoch 00134: loss improved from 0.01212 to 0.01210, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0121 - coeff_determination: 0.2174
# Epoch 135/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.0493
# Epoch 00135: loss improved from 0.01210 to 0.01207, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0121 - coeff_determination: 0.1330
# Epoch 136/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.3769
# Epoch 00136: loss improved from 0.01207 to 0.01189, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0119 - coeff_determination: 0.3408
# Epoch 137/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.2547
# Epoch 00137: loss did not improve from 0.01189
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0121 - coeff_determination: 0.2405
# Epoch 138/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.1305
# Epoch 00138: loss improved from 0.01189 to 0.01176, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0118 - coeff_determination: 0.2769
# Epoch 139/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.3396
# Epoch 00139: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0121 - coeff_determination: 0.2904
# Epoch 140/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.3511
# Epoch 00140: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0120 - coeff_determination: 0.3113
# Epoch 141/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2548
# Epoch 00141: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0119 - coeff_determination: 0.2783
# Epoch 142/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.3074
# Epoch 00142: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0123 - coeff_determination: 0.2803
# Epoch 143/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.2382
# Epoch 00143: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0122 - coeff_determination: 0.2359
# Epoch 144/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.3446
# Epoch 00144: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0123 - coeff_determination: 0.2762
# Epoch 145/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.2308
# Epoch 00145: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0125 - coeff_determination: 0.3165
# Epoch 146/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0125 - coeff_determination: 0.1888
# Epoch 00146: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0123 - coeff_determination: 0.2302
# Epoch 147/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.1913
# Epoch 00147: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0118 - coeff_determination: 0.2103
# Epoch 148/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.2521
# Epoch 00148: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0119 - coeff_determination: 0.2748
# Epoch 149/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.3470
# Epoch 00149: loss did not improve from 0.01176
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0121 - coeff_determination: 0.2413
# Epoch 150/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.3674
# Epoch 00150: loss improved from 0.01176 to 0.01156, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0116 - coeff_determination: 0.3773
# Epoch 151/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.2515
# Epoch 00151: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0121 - coeff_determination: 0.2467
# Epoch 152/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.2036
# Epoch 00152: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0119 - coeff_determination: 0.2751
# Epoch 153/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.3156
# Epoch 00153: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0118 - coeff_determination: 0.2882
# Epoch 154/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.3690
# Epoch 00154: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0122 - coeff_determination: 0.1655
# Epoch 155/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.2906
# Epoch 00155: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0121 - coeff_determination: 0.3226
# Epoch 156/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.3891
# Epoch 00156: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0117 - coeff_determination: 0.2529
# Epoch 157/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0122 - coeff_determination: 0.2717
# Epoch 00157: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0121 - coeff_determination: 0.2867
# Epoch 158/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: -0.0100
# Epoch 00158: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0119 - coeff_determination: 0.1235
# Epoch 159/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.2351
# Epoch 00159: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0118 - coeff_determination: 0.1982
# Epoch 160/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.3058
# Epoch 00160: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0122 - coeff_determination: 0.3131
# Epoch 161/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.3985
# Epoch 00161: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0117 - coeff_determination: 0.3158
# Epoch 162/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.3801
# Epoch 00162: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0117 - coeff_determination: 0.3215
# Epoch 163/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.2090
# Epoch 00163: loss did not improve from 0.01156
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0118 - coeff_determination: 0.2501
# Epoch 164/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.2876
# Epoch 00164: loss improved from 0.01156 to 0.01147, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0115 - coeff_determination: 0.3140
# Epoch 165/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.3851
# Epoch 00165: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0118 - coeff_determination: 0.3455
# Epoch 166/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.4429
# Epoch 00166: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0117 - coeff_determination: 0.2123
# Epoch 167/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.2986
# Epoch 00167: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0119 - coeff_determination: 0.3026
# Epoch 168/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.2382
# Epoch 00168: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0117 - coeff_determination: 0.2990
# Epoch 169/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.2383
# Epoch 00169: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0118 - coeff_determination: 0.2334
# Epoch 170/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2124
# Epoch 00170: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0117 - coeff_determination: 0.2882
# Epoch 171/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.1385
# Epoch 00171: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0118 - coeff_determination: 0.2309
# Epoch 172/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.3768
# Epoch 00172: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0116 - coeff_determination: 0.3341
# Epoch 173/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.3268
# Epoch 00173: loss did not improve from 0.01147
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0117 - coeff_determination: 0.3167
# Epoch 174/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.2456
# Epoch 00174: loss improved from 0.01147 to 0.01146, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0115 - coeff_determination: 0.2136
# Epoch 175/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.2985
# Epoch 00175: loss did not improve from 0.01146
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0117 - coeff_determination: 0.3180
# Epoch 176/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.3343
# ...
# Epoch 4939/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9090
# Epoch 04939: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0024 - coeff_determination: 0.9049
# Epoch 4940/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9072
# Epoch 04940: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0023 - coeff_determination: 0.9016
# Epoch 4941/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9020
# Epoch 04941: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9023
# Epoch 4942/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8769
# Epoch 04942: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0024 - coeff_determination: 0.8948
# Epoch 4943/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9108
# Epoch 04943: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0025 - coeff_determination: 0.9059
# Epoch 4944/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9041
# Epoch 04944: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9059
# Epoch 4945/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.8917
# Epoch 04945: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0025 - coeff_determination: 0.8935
# Epoch 4946/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8956
# Epoch 04946: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0024 - coeff_determination: 0.8951
# Epoch 4947/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9244
# Epoch 04947: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0023 - coeff_determination: 0.9056
# Epoch 4948/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.8997
# Epoch 04948: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0022 - coeff_determination: 0.9085
# Epoch 4949/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8977
# Epoch 04949: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0022 - coeff_determination: 0.9041
# Epoch 4950/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0026 - coeff_determination: 0.8922
# Epoch 04950: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0025 - coeff_determination: 0.8957
# Epoch 4951/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0021 - coeff_determination: 0.9103
# Epoch 04951: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0022 - coeff_determination: 0.9092
# Epoch 4952/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9106
# Epoch 04952: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0023 - coeff_determination: 0.9131
# Epoch 4953/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9108
# Epoch 04953: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0022 - coeff_determination: 0.9088
# Epoch 4954/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9046
# Epoch 04954: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0023 - coeff_determination: 0.9045
# Epoch 4955/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8946
# Epoch 04955: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0023 - coeff_determination: 0.9053
# Epoch 4956/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9061
# Epoch 04956: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0022 - coeff_determination: 0.9094
# Epoch 4957/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9094
# Epoch 04957: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0024 - coeff_determination: 0.9075
# Epoch 4958/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9016
# Epoch 04958: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0023 - coeff_determination: 0.9038
# Epoch 4959/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9069
# Epoch 04959: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0023 - coeff_determination: 0.9011
# Epoch 4960/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8986
# Epoch 04960: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0023 - coeff_determination: 0.9042
# Epoch 4961/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.8922
# Epoch 04961: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0024 - coeff_determination: 0.8989
# Epoch 4962/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9162
# Epoch 04962: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0022 - coeff_determination: 0.9084
# Epoch 4963/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8982
# Epoch 04963: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9050
# Epoch 4964/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9073
# Epoch 04964: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9049
# Epoch 4965/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8894
# Epoch 04965: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0024 - coeff_determination: 0.8968
# Epoch 4966/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9181
# Epoch 04966: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0023 - coeff_determination: 0.9010
# Epoch 4967/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.9031
# Epoch 04967: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0024 - coeff_determination: 0.9025
# Epoch 4968/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9056
# Epoch 04968: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0024 - coeff_determination: 0.9041
# Epoch 4969/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8967
# Epoch 04969: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0024 - coeff_determination: 0.9039
# Epoch 4970/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8982
# Epoch 04970: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0023 - coeff_determination: 0.9011
# Epoch 4971/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0021 - coeff_determination: 0.9105
# Epoch 04971: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9056
# Epoch 4972/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.9009
# Epoch 04972: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0024 - coeff_determination: 0.9002
# Epoch 4973/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9135
# Epoch 04973: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0022 - coeff_determination: 0.9113
# Epoch 4974/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9117
# Epoch 04974: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0022 - coeff_determination: 0.9141
# Epoch 4975/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.8979
# Epoch 04975: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0023 - coeff_determination: 0.9034
# Epoch 4976/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.8991
# Epoch 04976: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0023 - coeff_determination: 0.8913
# Epoch 4977/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9041
# Epoch 04977: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0023 - coeff_determination: 0.9068
# Epoch 4978/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9070
# Epoch 04978: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9086
# Epoch 4979/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.9001
# Epoch 04979: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0023 - coeff_determination: 0.9051
# Epoch 4980/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9100
# Epoch 04980: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9067
# Epoch 4981/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9094
# Epoch 04981: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0022 - coeff_determination: 0.9102
# Epoch 4982/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.8971
# Epoch 04982: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0024 - coeff_determination: 0.8964
# Epoch 4983/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9025
# Epoch 04983: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9048
# Epoch 4984/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9070
# Epoch 04984: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0023 - coeff_determination: 0.9046
# Epoch 4985/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9033
# Epoch 04985: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9049
# Epoch 4986/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.8793
# Epoch 04986: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0025 - coeff_determination: 0.8914
# Epoch 4987/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9109
# Epoch 04987: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0024 - coeff_determination: 0.9075
# Epoch 4988/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9121
# Epoch 04988: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0022 - coeff_determination: 0.9110
# Epoch 4989/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9111
# Epoch 04989: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9069
# Epoch 4990/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0026 - coeff_determination: 0.8889
# Epoch 04990: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0025 - coeff_determination: 0.8896
# Epoch 4991/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.8994
# Epoch 04991: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0024 - coeff_determination: 0.8952
# Epoch 4992/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.9039
# Epoch 04992: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0024 - coeff_determination: 0.9054
# Epoch 4993/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9152
# Epoch 04993: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0022 - coeff_determination: 0.9153
# Epoch 4994/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9099
# Epoch 04994: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0024 - coeff_determination: 0.9045
# Epoch 4995/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8967
# Epoch 04995: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0024 - coeff_determination: 0.8977
# Epoch 4996/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.8935
# Epoch 04996: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9020
# Epoch 4997/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0025 - coeff_determination: 0.9029
# Epoch 04997: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0025 - coeff_determination: 0.8906
# Epoch 4998/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0023 - coeff_determination: 0.9055
# Epoch 04998: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0023 - coeff_determination: 0.9097
# Epoch 4999/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0022 - coeff_determination: 0.9077
# Epoch 04999: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0022 - coeff_determination: 0.9101
# Epoch 5000/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0024 - coeff_determination: 0.9004
# Epoch 05000: loss did not improve from 0.00214
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0024 - coeff_determination: 0.8981

# %%
import matplotlib.pyplot as plt
lstm_model.load_weights(weights_filepath)

# Testing
filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(1,num_coeffs+num_ivs,500))
test_data[0,0:num_coeffs,:] = np.transpose(true_pca_evol[:,:])

test_data[0,-2,:] = -1.0/2.7
test_data[0,-1,:] = -1.0/4.0
viz = False

mse_val = 0.0
num_inference = 1000
pred_mean = np.zeros_like(test_data)
pred_pca_array = np.zeros(shape=(num_inference,np.shape(test_data)[1],np.shape(test_data)[2]))

from time import time

start_time = time()

for inference in range(num_inference):
    pred_pca = lstm_model.predict(test_data[:,:,:burn_in])
    pred_pca = np.concatenate((test_data[:,:,:burn_in],pred_pca),axis=-1)
    pred_pca_array[inference,:,:] = pred_pca[0,:,:]
    
    pred_mean = pred_mean + pred_pca
    mse_val = mse_val + np.sum((pred_pca-test_data)**2)
    
    if viz:
        
        fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
        ax[0,0].plot(test_data[0,0,:],label='True')
        ax[0,0].plot(pred_pca[0,0,:],label='Predicted')
        ax[0,0].set_title('Mode 1')


        ax[1,0].plot(test_data[0,1,:],label='True')
        ax[1,0].plot(pred_pca[0,1,:],label='Predicted')
        ax[1,0].set_title('Mode 2')

        ax[0,1].plot(test_data[0,2,:],label='True')
        ax[0,1].plot(pred_pca[0,2,:],label='Predicted')
        ax[0,1].set_title('Mode 3')

        ax[1,1].plot(test_data[0,3,:],label='True')
        ax[1,1].plot(pred_pca[0,3,:],label='Predicted')
        ax[1,1].set_title('Mode 4')

        plt.tight_layout()
        plt.legend()
        plt.show()
        
        # Plotting some contours
        true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
        true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

        pred_rb = np.transpose(pred_pca[0,:num_modes,:])
        pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
        pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


        fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
        cx = ax[0].contourf(true_recon)
        ax[1].contourf(pred_recon)

        fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
        fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()    
        
end_time = time()

# %%
pred_mean = pred_mean/num_inference

# Calculate standard deviation
pred_sdev = np.sqrt(np.sum((pred_pca_array - pred_mean[0,:,:])**2,axis=0)/(num_inference-1))
        
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[0,0,:],label='True')
ax[0,0].plot(pred_mean[0,0,:],label='Predicted mean')
ax[0,0].fill_between(np.arange(500),pred_mean[0,0,:]+pred_sdev[0,:],pred_mean[0,0,:]-pred_sdev[0,:],label='1 std')
ax[0,0].set_title('Mode 1')



ax[1,0].plot(test_data[0,1,:],label='True')
ax[1,0].plot(pred_mean[0,1,:],label='Predicted mean')
ax[1,0].fill_between(np.arange(500),pred_mean[0,1,:]+pred_sdev[1,:],pred_mean[0,1,:]-pred_sdev[1,:],label='1 std')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[0,2,:],label='True')
ax[0,1].plot(pred_mean[0,2,:],label='Predicted mean')
ax[0,1].fill_between(np.arange(500),pred_mean[0,2,:]+pred_sdev[2,:],pred_mean[0,2,:]-pred_sdev[2,:],label='1 std')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[0,3,:],label='True')
ax[1,1].plot(pred_mean[0,3,:],label='Predicted mean')
ax[1,1].fill_between(np.arange(500),pred_mean[0,3,:]+pred_sdev[3,:],pred_mean[0,3,:]-pred_sdev[3,:],label='1 std')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
print('Elapsed time per inference:',(end_time-start_time)/num_inference)
# Out:
# Elapsed time per inference: 0.016597886085510254

# %%
np.save('../Figures/NAT_LSTM_PT_Mean.npy',pred_mean)
np.save('../Figures/NAT_LSTM_PT_SD.npy',pred_sdev)
