# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]

coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = np.transpose(coeff_scaler.fit_transform(np.transpose(pca_coeffs)))

# %%
num_sims = np.shape(locs)[0]
num_ivs = np.shape(locs)[1]
num_coeffs = np.shape(pca_coeffs)[0]
burn_in = 20

# %%
# Reshape
training_data_ip = np.zeros(shape=(num_sims,num_coeffs+num_ivs,burn_in),dtype='double')
training_data_op = np.zeros(shape=(num_sims,num_coeffs+num_ivs,500-burn_in),dtype='double')

for sim in range(num_sims):
    training_data_ip[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim:500*sim+burn_in]
    training_data_ip[sim,-num_ivs:,:] = locs[sim,:,None]
    training_data_op[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim+burn_in:500*(sim+1)]
    training_data_op[sim,-num_ivs:,:] = locs[sim,:,None]

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_LSTM_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(num_coeffs+num_ivs,burn_in),name='nat_inputs')
h1 = LSTM(145,return_sequences=True)(lstm_inputs)
h2 = LSTM(145,return_sequences=True)(h1)
lstm_outputs = Dense(500-burn_in,activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# nat_inputs (InputLayer)      [(None, 42, 20)]          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 42, 145)           96280
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 42, 145)           168780
# _________________________________________________________________
# dense_1 (Dense)              (None, 42, 480)           70080
# =================================================================
# Total params: 335,140
# Trainable params: 335,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = True

from time import time
start_time = time()

if train_mode:
    train_history = lstm_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_LSTM_PT.npy',train_history.history['loss'])

end_time = time()
# Out:
# W0121 16:45:26.119290 140065793685312 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.2521 - coeff_determination: -283.7539
# Epoch 00001: loss improved from inf to 0.24929, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 1s 58ms/sample - loss: 0.2493 - coeff_determination: -245.2789
# Epoch 2/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.2226 - coeff_determination: -74.1021
# Epoch 00002: loss improved from 0.24929 to 0.21258, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.2126 - coeff_determination: -55.6262
# Epoch 3/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.1579 - coeff_determination: -10.9918
# Epoch 00003: loss improved from 0.21258 to 0.14443, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.1444 - coeff_determination: -8.3111
# Epoch 4/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0921 - coeff_determination: -1.6031
# Epoch 00004: loss improved from 0.14443 to 0.08428, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0843 - coeff_determination: -1.2579
# Epoch 5/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0641 - coeff_determination: -0.7449
# Epoch 00005: loss improved from 0.08428 to 0.05911, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0591 - coeff_determination: -0.7837
# Epoch 6/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0442 - coeff_determination: -1.2879
# Epoch 00006: loss improved from 0.05911 to 0.04288, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0429 - coeff_determination: -1.4183
# Epoch 7/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0344 - coeff_determination: -1.7284
# Epoch 00007: loss improved from 0.04288 to 0.03721, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0372 - coeff_determination: -2.2311
# Epoch 8/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0343 - coeff_determination: -2.3534
# Epoch 00008: loss improved from 0.03721 to 0.03625, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0363 - coeff_determination: -2.6193
# Epoch 9/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0343 - coeff_determination: -2.7369
# Epoch 00009: loss improved from 0.03625 to 0.03450, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0345 - coeff_determination: -2.7894
# Epoch 10/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0321 - coeff_determination: -2.8855
# Epoch 00010: loss improved from 0.03450 to 0.03250, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0325 - coeff_determination: -2.9224
# Epoch 11/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0330 - coeff_determination: -3.5245
# Epoch 00011: loss improved from 0.03250 to 0.03119, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0312 - coeff_determination: -3.2345
# Epoch 12/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0313 - coeff_determination: -3.7572
# Epoch 00012: loss improved from 0.03119 to 0.03023, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0302 - coeff_determination: -3.5667
# Epoch 13/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0325 - coeff_determination: -4.2662
# Epoch 00013: loss improved from 0.03023 to 0.02945, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0294 - coeff_determination: -3.9052
# Epoch 14/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0318 - coeff_determination: -4.9531
# Epoch 00014: loss improved from 0.02945 to 0.02860, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0286 - coeff_determination: -3.9702
# Epoch 15/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0289 - coeff_determination: -3.7379
# Epoch 00015: loss improved from 0.02860 to 0.02774, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0277 - coeff_determination: -4.0408
# Epoch 16/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0272 - coeff_determination: -3.8342
# Epoch 00016: loss improved from 0.02774 to 0.02686, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0269 - coeff_determination: -3.8937
# Epoch 17/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0260 - coeff_determination: -3.9742
# Epoch 00017: loss improved from 0.02686 to 0.02597, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0260 - coeff_determination: -3.7817
# Epoch 18/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0254 - coeff_determination: -3.6046
# Epoch 00018: loss improved from 0.02597 to 0.02512, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0251 - coeff_determination: -3.6938
# Epoch 19/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0234 - coeff_determination: -3.5508
# Epoch 00019: loss improved from 0.02512 to 0.02422, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0242 - coeff_determination: -3.4910
# Epoch 20/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0227 - coeff_determination: -3.1004
# Epoch 00020: loss improved from 0.02422 to 0.02345, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0234 - coeff_determination: -3.1649
# Epoch 21/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0202 - coeff_determination: -2.6558
# Epoch 00021: loss improved from 0.02345 to 0.02246, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0225 - coeff_determination: -2.9463
# Epoch 22/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0231 - coeff_determination: -2.8700
# Epoch 00022: loss improved from 0.02246 to 0.02170, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0217 - coeff_determination: -2.5266
# Epoch 23/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0238 - coeff_determination: -2.6834
# Epoch 00023: loss improved from 0.02170 to 0.02095, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0209 - coeff_determination: -2.3487
# Epoch 24/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0198 - coeff_determination: -2.0385
# Epoch 00024: loss improved from 0.02095 to 0.02011, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0201 - coeff_determination: -1.9760
# Epoch 25/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0189 - coeff_determination: -1.5809
# Epoch 00025: loss improved from 0.02011 to 0.01943, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0194 - coeff_determination: -1.7731
# Epoch 26/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0195 - coeff_determination: -1.5304
# Epoch 00026: loss improved from 0.01943 to 0.01873, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0187 - coeff_determination: -1.5590
# Epoch 27/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0178 - coeff_determination: -1.3605
# Epoch 00027: loss improved from 0.01873 to 0.01801, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0180 - coeff_determination: -1.4072
# Epoch 28/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0178 - coeff_determination: -1.1291
# Epoch 00028: loss improved from 0.01801 to 0.01745, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0174 - coeff_determination: -1.1631
# Epoch 29/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0172 - coeff_determination: -1.0282
# Epoch 00029: loss improved from 0.01745 to 0.01685, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0169 - coeff_determination: -1.0147
# Epoch 30/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0156 - coeff_determination: -0.7676
# Epoch 00030: loss improved from 0.01685 to 0.01621, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0162 - coeff_determination: -0.9198
# Epoch 31/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0162 - coeff_determination: -0.7579
# Epoch 00031: loss improved from 0.01621 to 0.01567, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0157 - coeff_determination: -0.7542
# Epoch 32/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0154 - coeff_determination: -0.7118
# Epoch 00032: loss improved from 0.01567 to 0.01522, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0152 - coeff_determination: -0.6207
# Epoch 33/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0157 - coeff_determination: -0.6307
# Epoch 00033: loss improved from 0.01522 to 0.01475, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0147 - coeff_determination: -0.5104
# Epoch 34/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0148 - coeff_determination: -0.4196
# Epoch 00034: loss improved from 0.01475 to 0.01427, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0143 - coeff_determination: -0.3946
# Epoch 35/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0140 - coeff_determination: -0.3409
# Epoch 00035: loss improved from 0.01427 to 0.01386, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0139 - coeff_determination: -0.2862
# Epoch 36/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0130 - coeff_determination: -0.2859
# Epoch 00036: loss improved from 0.01386 to 0.01352, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0135 - coeff_determination: -0.2402
# Epoch 37/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: -0.1968
# Epoch 00037: loss improved from 0.01352 to 0.01323, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0132 - coeff_determination: -0.1728
# Epoch 38/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0127 - coeff_determination: -0.1677
# Epoch 00038: loss improved from 0.01323 to 0.01301, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0130 - coeff_determination: -0.1484
# Epoch 39/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0127 - coeff_determination: -0.0211
# Epoch 00039: loss improved from 0.01301 to 0.01273, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0127 - coeff_determination: -0.1017
# Epoch 40/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0127 - coeff_determination: -0.2352
# Epoch 00040: loss improved from 0.01273 to 0.01255, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0125 - coeff_determination: -0.0966
# Epoch 41/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: -0.0186
# Epoch 00041: loss improved from 0.01255 to 0.01237, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0124 - coeff_determination: -0.0106
# Epoch 42/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.1229
# Epoch 00042: loss improved from 0.01237 to 0.01224, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0122 - coeff_determination: -0.0094
# Epoch 43/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0126 - coeff_determination: 0.1353
# Epoch 00043: loss improved from 0.01224 to 0.01211, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0121 - coeff_determination: 0.0314
# Epoch 44/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.0402
# Epoch 00044: loss improved from 0.01211 to 0.01199, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0120 - coeff_determination: 0.0754
# Epoch 45/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.0208
# Epoch 00045: loss improved from 0.01199 to 0.01182, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0118 - coeff_determination: 0.0518
# Epoch 46/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.1527
# Epoch 00046: loss improved from 0.01182 to 0.01175, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0117 - coeff_determination: 0.1211
# Epoch 47/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.0914
# Epoch 00047: loss improved from 0.01175 to 0.01163, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0116 - coeff_determination: 0.1379
# Epoch 48/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: -0.0323
# Epoch 00048: loss improved from 0.01163 to 0.01160, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0116 - coeff_determination: 0.1132
# Epoch 49/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.1255
# Epoch 00049: loss improved from 0.01160 to 0.01147, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0115 - coeff_determination: 0.1552
# Epoch 50/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.0640
# Epoch 00050: loss improved from 0.01147 to 0.01145, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0114 - coeff_determination: 0.1104
# Epoch 51/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.1023
# Epoch 00051: loss improved from 0.01145 to 0.01140, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0114 - coeff_determination: 0.1611
# Epoch 52/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0113 - coeff_determination: 0.1087
# Epoch 00052: loss improved from 0.01140 to 0.01137, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0114 - coeff_determination: 0.1774
# Epoch 53/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.2562
# Epoch 00053: loss improved from 0.01137 to 0.01123, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0112 - coeff_determination: 0.1515
# Epoch 54/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.1928
# Epoch 00054: loss improved from 0.01123 to 0.01118, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0112 - coeff_determination: 0.1921
# Epoch 55/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.0280
# Epoch 00055: loss improved from 0.01118 to 0.01113, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0111 - coeff_determination: 0.1658
# Epoch 56/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.1224
# Epoch 00056: loss improved from 0.01113 to 0.01104, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0110 - coeff_determination: 0.1920
# Epoch 57/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.3820
# Epoch 00057: loss improved from 0.01104 to 0.01103, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0110 - coeff_determination: 0.1142
# Epoch 58/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.2397
# Epoch 00058: loss improved from 0.01103 to 0.01098, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0110 - coeff_determination: 0.2234
# Epoch 59/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.2525
# Epoch 00059: loss improved from 0.01098 to 0.01091, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0109 - coeff_determination: 0.2698
# Epoch 60/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0110 - coeff_determination: 0.2746
# Epoch 00060: loss improved from 0.01091 to 0.01085, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0109 - coeff_determination: 0.2121
# Epoch 61/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.2603
# Epoch 00061: loss improved from 0.01085 to 0.01083, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0108 - coeff_determination: 0.2815
# Epoch 62/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.2997
# Epoch 00062: loss improved from 0.01083 to 0.01083, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0108 - coeff_determination: 0.2300
# Epoch 63/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.2193
# Epoch 00063: loss did not improve from 0.01083
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0109 - coeff_determination: 0.2553
# Epoch 64/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.1168
# Epoch 00064: loss did not improve from 0.01083
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0108 - coeff_determination: 0.2100
# Epoch 65/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.3261
# Epoch 00065: loss improved from 0.01083 to 0.01075, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: 0.2532
# Epoch 66/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: -0.0300
# Epoch 00066: loss improved from 0.01075 to 0.01073, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0107 - coeff_determination: 0.1715
# Epoch 67/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3261
# Epoch 00067: loss improved from 0.01073 to 0.01072, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.0107 - coeff_determination: 0.2293
# Epoch 68/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3355
# Epoch 00068: loss improved from 0.01072 to 0.01065, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: 0.3010
# Epoch 69/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3606
# Epoch 00069: loss improved from 0.01065 to 0.01060, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: 0.2022
# Epoch 70/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.2339
# Epoch 00070: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0107 - coeff_determination: 0.2911
# Epoch 71/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.1501
# Epoch 00071: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: 0.2651
# Epoch 72/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.3523
# Epoch 00072: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0106 - coeff_determination: 0.2997
# Epoch 73/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.1478
# Epoch 00073: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0106 - coeff_determination: 0.2378
# Epoch 74/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.2902
# Epoch 00074: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0106 - coeff_determination: 0.2407
# Epoch 75/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.4420
# Epoch 00075: loss did not improve from 0.01060
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0107 - coeff_determination: 0.2191
# Epoch 76/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3079
# Epoch 00076: loss improved from 0.01060 to 0.01054, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0105 - coeff_determination: 0.3140
# Epoch 77/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.2577
# Epoch 00077: loss improved from 0.01054 to 0.01047, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0105 - coeff_determination: 0.2926
# Epoch 78/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3005
# Epoch 00078: loss improved from 0.01047 to 0.01043, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0104 - coeff_determination: 0.3192
# Epoch 79/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.2577
# Epoch 00079: loss improved from 0.01043 to 0.01043, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0104 - coeff_determination: 0.3186
# Epoch 80/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3247
# Epoch 00080: loss did not improve from 0.01043
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0105 - coeff_determination: 0.2909
# Epoch 81/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.2141
# Epoch 00081: loss did not improve from 0.01043
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0106 - coeff_determination: 0.2713
# Epoch 82/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.2902
# Epoch 00082: loss did not improve from 0.01043
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0105 - coeff_determination: 0.2465
# Epoch 83/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3447
# Epoch 00083: loss improved from 0.01043 to 0.01042, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: 0.2897
# Epoch 84/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3730
# Epoch 00084: loss improved from 0.01042 to 0.01037, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0104 - coeff_determination: 0.3010
# Epoch 85/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.4213
# Epoch 00085: loss did not improve from 0.01037
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0104 - coeff_determination: 0.3551
# Epoch 86/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.2178
# Epoch 00086: loss improved from 0.01037 to 0.01033, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0103 - coeff_determination: 0.2670
# Epoch 87/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3294
# Epoch 00087: loss improved from 0.01033 to 0.01030, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0103 - coeff_determination: 0.3355
# Epoch 88/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.0523
# Epoch 00088: loss did not improve from 0.01030
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0103 - coeff_determination: 0.2372
# Epoch 89/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3944
# Epoch 00089: loss improved from 0.01030 to 0.01028, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0103 - coeff_determination: 0.3435
# Epoch 90/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3036
# Epoch 00090: loss did not improve from 0.01028
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0103 - coeff_determination: 0.3459
# Epoch 91/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3408
# Epoch 00091: loss improved from 0.01028 to 0.01027, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0103 - coeff_determination: 0.3600
# Epoch 92/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2869
# Epoch 00092: loss did not improve from 0.01027
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0103 - coeff_determination: 0.3267
# Epoch 93/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2501
# Epoch 00093: loss improved from 0.01027 to 0.01023, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0102 - coeff_determination: 0.2695
# Epoch 94/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3922
# Epoch 00094: loss improved from 0.01023 to 0.01019, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0102 - coeff_determination: 0.3882
# Epoch 95/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3166
# Epoch 00095: loss did not improve from 0.01019
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0102 - coeff_determination: 0.3520
# Epoch 96/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2273
# Epoch 00096: loss did not improve from 0.01019
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0102 - coeff_determination: 0.2880
# Epoch 97/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.2757
# Epoch 00097: loss improved from 0.01019 to 0.01014, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0101 - coeff_determination: 0.3178
# Epoch 98/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3477
# Epoch 00098: loss improved from 0.01014 to 0.01013, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0101 - coeff_determination: 0.3683
# Epoch 99/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3644
# Epoch 00099: loss improved from 0.01013 to 0.01008, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0101 - coeff_determination: 0.3644
# Epoch 100/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3493
# Epoch 00100: loss did not improve from 0.01008
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0101 - coeff_determination: 0.3855
# Epoch 101/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3736
# Epoch 00101: loss did not improve from 0.01008
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0103 - coeff_determination: 0.3527
# Epoch 102/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3449
# Epoch 00102: loss did not improve from 0.01008
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0102 - coeff_determination: 0.2957
# Epoch 103/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3736
# Epoch 00103: loss did not improve from 0.01008
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0102 - coeff_determination: 0.3665
# Epoch 104/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.2749
# Epoch 00104: loss did not improve from 0.01008
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0101 - coeff_determination: 0.3073
# Epoch 105/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3527
# Epoch 00105: loss improved from 0.01008 to 0.01004, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0100 - coeff_determination: 0.3663
# Epoch 106/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3372
# Epoch 00106: loss improved from 0.01004 to 0.01000, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0100 - coeff_determination: 0.3749
# Epoch 107/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4405
# Epoch 00107: loss did not improve from 0.01000
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0102 - coeff_determination: 0.3373
# Epoch 108/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4270
# Epoch 00108: loss did not improve from 0.01000
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0101 - coeff_determination: 0.3802
# Epoch 109/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2943
# Epoch 00109: loss did not improve from 0.01000
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0102 - coeff_determination: 0.3252
# Epoch 110/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2871
# Epoch 00110: loss did not improve from 0.01000
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0101 - coeff_determination: 0.3370
# Epoch 111/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3310
# Epoch 00111: loss did not improve from 0.01000
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0100 - coeff_determination: 0.3821
# Epoch 112/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4121
# Epoch 00112: loss improved from 0.01000 to 0.00998, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0100 - coeff_determination: 0.3708
# Epoch 113/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3774
# Epoch 00113: loss improved from 0.00998 to 0.00997, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0100 - coeff_determination: 0.3848
# Epoch 114/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3047
# Epoch 00114: loss did not improve from 0.00997
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0100 - coeff_determination: 0.3449
# Epoch 115/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4075
# Epoch 00115: loss did not improve from 0.00997
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0100 - coeff_determination: 0.3955
# Epoch 116/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.2695
# Epoch 00116: loss did not improve from 0.00997
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0100 - coeff_determination: 0.3304
# Epoch 117/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.3879
# Epoch 00117: loss did not improve from 0.00997
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0100 - coeff_determination: 0.4141
# Epoch 118/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4510
# Epoch 00118: loss improved from 0.00997 to 0.00997, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0100 - coeff_determination: 0.3051
# Epoch 119/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.4394
# Epoch 00119: loss improved from 0.00997 to 0.00993, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0099 - coeff_determination: 0.3583
# Epoch 120/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4133
# Epoch 00120: loss improved from 0.00993 to 0.00991, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0099 - coeff_determination: 0.3944
# Epoch 121/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.0391
# Epoch 00121: loss improved from 0.00991 to 0.00989, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.1357
# Epoch 122/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.2717
# Epoch 00122: loss did not improve from 0.00989
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.3369
# Epoch 123/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4130
# Epoch 00123: loss did not improve from 0.00989
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0099 - coeff_determination: 0.2912
# Epoch 124/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4459
# Epoch 00124: loss improved from 0.00989 to 0.00988, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.3407
# Epoch 125/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.2453
# Epoch 00125: loss did not improve from 0.00988
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.3144
# Epoch 126/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.4670
# Epoch 00126: loss improved from 0.00988 to 0.00986, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0099 - coeff_determination: 0.3935
# Epoch 127/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3591
# Epoch 00127: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0099 - coeff_determination: 0.3753
# Epoch 128/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3703
# Epoch 00128: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0099 - coeff_determination: 0.3915
# Epoch 129/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4512
# Epoch 00129: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0100 - coeff_determination: 0.3848
# Epoch 130/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3058
# Epoch 00130: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.3561
# Epoch 131/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3711
# Epoch 00131: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0099 - coeff_determination: 0.3891
# Epoch 132/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3836
# Epoch 00132: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0099 - coeff_determination: 0.3310
# Epoch 133/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3660
# Epoch 00133: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0099 - coeff_determination: 0.3513
# Epoch 134/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3673
# Epoch 00134: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0099 - coeff_determination: 0.4054
# Epoch 135/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.1105
# Epoch 00135: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0099 - coeff_determination: 0.2048
# Epoch 136/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4650
# Epoch 00136: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0099 - coeff_determination: 0.3890
# Epoch 137/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3047
# Epoch 00137: loss did not improve from 0.00986
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0099 - coeff_determination: 0.3474
# Epoch 138/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3035
# Epoch 00138: loss improved from 0.00986 to 0.00983, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0098 - coeff_determination: 0.3529
# Epoch 139/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4066
# Epoch 00139: loss improved from 0.00983 to 0.00978, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0098 - coeff_determination: 0.3741
# Epoch 140/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4246
# Epoch 00140: loss improved from 0.00978 to 0.00976, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0098 - coeff_determination: 0.3923
# Epoch 141/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.2364
# Epoch 00141: loss improved from 0.00976 to 0.00976, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0098 - coeff_determination: 0.2970
# Epoch 142/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.4194
# Epoch 00142: loss did not improve from 0.00976
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0099 - coeff_determination: 0.4239
# Epoch 143/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3856
# Epoch 00143: loss did not improve from 0.00976
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0098 - coeff_determination: 0.4088
# Epoch 144/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.4073
# Epoch 00144: loss did not improve from 0.00976
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0098 - coeff_determination: 0.3945
# Epoch 145/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.3457
# Epoch 00145: loss did not improve from 0.00976
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0098 - coeff_determination: 0.4178
# Epoch 146/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: 0.4815
# Epoch 00146: loss did not improve from 0.00976
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0098 - coeff_determination: 0.3790
# Epoch 147/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3425
# Epoch 00147: loss improved from 0.00976 to 0.00975, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0098 - coeff_determination: 0.3858
# Epoch 148/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3939
# Epoch 00148: loss did not improve from 0.00975
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0098 - coeff_determination: 0.3865
# Epoch 149/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3985
# Epoch 00149: loss improved from 0.00975 to 0.00972, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0097 - coeff_determination: 0.3957
# Epoch 150/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4913
# Epoch 00150: loss did not improve from 0.00972
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0098 - coeff_determination: 0.3433
# Epoch 151/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4888
# Epoch 00151: loss did not improve from 0.00972
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0097 - coeff_determination: 0.4135
# Epoch 152/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3138
# Epoch 00152: loss improved from 0.00972 to 0.00969, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0097 - coeff_determination: 0.3830
# Epoch 153/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4713
# Epoch 00153: loss did not improve from 0.00969
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0097 - coeff_determination: 0.4000
# Epoch 154/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: 0.4978
# Epoch 00154: loss improved from 0.00969 to 0.00968, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0097 - coeff_determination: 0.3954
# Epoch 155/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.3709
# Epoch 00155: loss improved from 0.00968 to 0.00968, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0097 - coeff_determination: 0.4226
# Epoch 156/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.4862
# Epoch 00156: loss improved from 0.00968 to 0.00967, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0097 - coeff_determination: 0.3397
# Epoch 157/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4374
# Epoch 00157: loss did not improve from 0.00967
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0097 - coeff_determination: 0.4341
# Epoch 158/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.1528
# Epoch 00158: loss improved from 0.00967 to 0.00966, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0097 - coeff_determination: 0.2859
# Epoch 159/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3875
# Epoch 00159: loss improved from 0.00966 to 0.00966, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0097 - coeff_determination: 0.3624
# Epoch 160/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.4174
# Epoch 00160: loss improved from 0.00966 to 0.00964, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0096 - coeff_determination: 0.4353
# Epoch 161/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: 0.4926
# Epoch 00161: loss did not improve from 0.00964
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0096 - coeff_determination: 0.3999
# Epoch 162/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4800
# Epoch 00162: loss did not improve from 0.00964
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0097 - coeff_determination: 0.4243
# Epoch 163/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3132
# Epoch 00163: loss improved from 0.00964 to 0.00963, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0096 - coeff_determination: 0.3681
# Epoch 164/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3826
# Epoch 00164: loss did not improve from 0.00963
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0097 - coeff_determination: 0.4138
# Epoch 165/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0095 - coeff_determination: 0.4394
# Epoch 00165: loss improved from 0.00963 to 0.00962, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0096 - coeff_determination: 0.4073
# Epoch 166/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.5415
# Epoch 00166: loss did not improve from 0.00962
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0096 - coeff_determination: 0.3683
# Epoch 167/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3210
# Epoch 00167: loss did not improve from 0.00962
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0096 - coeff_determination: 0.3919
# Epoch 168/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3788
# Epoch 00168: loss did not improve from 0.00962
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0097 - coeff_determination: 0.3802
# Epoch 169/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3906
# Epoch 00169: loss did not improve from 0.00962
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0096 - coeff_determination: 0.3782
# Epoch 170/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3553
# Epoch 00170: loss did not improve from 0.00962
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0098 - coeff_determination: 0.3807
# Epoch 171/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3284
# ...
# Epoch 4942/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.4143e-04 - coeff_determination: 0.9771
# Epoch 04942: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 15ms/sample - loss: 5.3617e-04 - coeff_determination: 0.9788
# Epoch 4943/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2927e-04 - coeff_determination: 0.9802
# Epoch 04943: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 14ms/sample - loss: 5.2844e-04 - coeff_determination: 0.9801
# Epoch 4944/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2391e-04 - coeff_determination: 0.9805
# Epoch 04944: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.2602e-04 - coeff_determination: 0.9797
# Epoch 4945/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.1200e-04 - coeff_determination: 0.9814
# Epoch 04945: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.2575e-04 - coeff_determination: 0.9798
# Epoch 4946/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0006e-04 - coeff_determination: 0.9796
# Epoch 04946: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2559e-04 - coeff_determination: 0.9794
# Epoch 4947/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.1933e-04 - coeff_determination: 0.9812
# Epoch 04947: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.2595e-04 - coeff_determination: 0.9792
# Epoch 4948/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.3993e-04 - coeff_determination: 0.9771
# Epoch 04948: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2753e-04 - coeff_determination: 0.9792
# Epoch 4949/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1520e-04 - coeff_determination: 0.9798
# Epoch 04949: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2597e-04 - coeff_determination: 0.9800
# Epoch 4950/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2952e-04 - coeff_determination: 0.9802
# Epoch 04950: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 13ms/sample - loss: 5.2518e-04 - coeff_determination: 0.9799
# Epoch 4951/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4314e-04 - coeff_determination: 0.9791
# Epoch 04951: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2169e-04 - coeff_determination: 0.9802
# Epoch 4952/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1334e-04 - coeff_determination: 0.9788
# Epoch 04952: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2172e-04 - coeff_determination: 0.9794
# Epoch 4953/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0826e-04 - coeff_determination: 0.9800
# Epoch 04953: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2195e-04 - coeff_determination: 0.9797
# Epoch 4954/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2733e-04 - coeff_determination: 0.9797
# Epoch 04954: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2214e-04 - coeff_determination: 0.9801
# Epoch 4955/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4310e-04 - coeff_determination: 0.9767
# Epoch 04955: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2000e-04 - coeff_determination: 0.9799
# Epoch 4956/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1084e-04 - coeff_determination: 0.9803
# Epoch 04956: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2055e-04 - coeff_determination: 0.9802
# Epoch 4957/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0191e-04 - coeff_determination: 0.9801
# Epoch 04957: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.1936e-04 - coeff_determination: 0.9800
# Epoch 4958/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1217e-04 - coeff_determination: 0.9794
# Epoch 04958: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2242e-04 - coeff_determination: 0.9801
# Epoch 4959/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3721e-04 - coeff_determination: 0.9807
# Epoch 04959: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2910e-04 - coeff_determination: 0.9790
# Epoch 4960/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.9597e-04 - coeff_determination: 0.9788
# Epoch 04960: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2488e-04 - coeff_determination: 0.9799
# Epoch 4961/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.9072e-04 - coeff_determination: 0.9785
# Epoch 04961: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2208e-04 - coeff_determination: 0.9798
# Epoch 4962/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4455e-04 - coeff_determination: 0.9795
# Epoch 04962: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2671e-04 - coeff_determination: 0.9796
# Epoch 4963/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4211e-04 - coeff_determination: 0.9770
# Epoch 04963: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2727e-04 - coeff_determination: 0.9796
# Epoch 4964/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3190e-04 - coeff_determination: 0.9795
# Epoch 04964: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.3009e-04 - coeff_determination: 0.9799
# Epoch 4965/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3353e-04 - coeff_determination: 0.9767
# Epoch 04965: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2593e-04 - coeff_determination: 0.9794
# Epoch 4966/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3914e-04 - coeff_determination: 0.9815
# Epoch 04966: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2544e-04 - coeff_determination: 0.9800
# Epoch 4967/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2821e-04 - coeff_determination: 0.9810
# Epoch 04967: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2295e-04 - coeff_determination: 0.9803
# Epoch 4968/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0030e-04 - coeff_determination: 0.9808
# Epoch 04968: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.1848e-04 - coeff_determination: 0.9806
# Epoch 4969/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2346e-04 - coeff_determination: 0.9777
# Epoch 04969: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2289e-04 - coeff_determination: 0.9797
# Epoch 4970/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0243e-04 - coeff_determination: 0.9797
# Epoch 04970: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.1930e-04 - coeff_determination: 0.9795
# Epoch 4971/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.8422e-04 - coeff_determination: 0.9810
# Epoch 04971: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 19ms/sample - loss: 5.2415e-04 - coeff_determination: 0.9798
# Epoch 4972/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.3892e-04 - coeff_determination: 0.9785
# Epoch 04972: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2484e-04 - coeff_determination: 0.9792
# Epoch 4973/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1189e-04 - coeff_determination: 0.9807
# Epoch 04973: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2361e-04 - coeff_determination: 0.9799
# Epoch 4974/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.9876e-04 - coeff_determination: 0.9805
# Epoch 04974: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2791e-04 - coeff_determination: 0.9799
# Epoch 4975/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.6801e-04 - coeff_determination: 0.9783
# Epoch 04975: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 21ms/sample - loss: 5.2492e-04 - coeff_determination: 0.9799
# Epoch 4976/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.3961e-04 - coeff_determination: 0.9812
# Epoch 04976: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2995e-04 - coeff_determination: 0.9788
# Epoch 4977/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0154e-04 - coeff_determination: 0.9806
# Epoch 04977: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2631e-04 - coeff_determination: 0.9798
# Epoch 4978/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2941e-04 - coeff_determination: 0.9800
# Epoch 04978: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.1930e-04 - coeff_determination: 0.9802
# Epoch 4979/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2427e-04 - coeff_determination: 0.9810
# Epoch 04979: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2302e-04 - coeff_determination: 0.9799
# Epoch 4980/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3406e-04 - coeff_determination: 0.9805
# Epoch 04980: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2303e-04 - coeff_determination: 0.9803
# Epoch 4981/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1930e-04 - coeff_determination: 0.9809
# Epoch 04981: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2032e-04 - coeff_determination: 0.9801
# Epoch 4982/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2914e-04 - coeff_determination: 0.9802
# Epoch 04982: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2019e-04 - coeff_determination: 0.9791
# Epoch 4983/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1832e-04 - coeff_determination: 0.9808
# Epoch 04983: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2015e-04 - coeff_determination: 0.9803
# Epoch 4984/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3620e-04 - coeff_determination: 0.9803
# Epoch 04984: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.1922e-04 - coeff_determination: 0.9801
# Epoch 4985/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.0028e-04 - coeff_determination: 0.9816
# Epoch 04985: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.1702e-04 - coeff_determination: 0.9802
# Epoch 4986/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.2539e-04 - coeff_determination: 0.9777
# Epoch 04986: loss improved from 0.00052 to 0.00052, saving model to NAT_LSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.1618e-04 - coeff_determination: 0.9800
# Epoch 4987/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.8112e-04 - coeff_determination: 0.9806
# Epoch 04987: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.1678e-04 - coeff_determination: 0.9799
# Epoch 4988/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.9896e-04 - coeff_determination: 0.9786
# Epoch 04988: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.1655e-04 - coeff_determination: 0.9793
# Epoch 4989/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.0720e-04 - coeff_determination: 0.9809
# Epoch 04989: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.2124e-04 - coeff_determination: 0.9800
# Epoch 4990/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2712e-04 - coeff_determination: 0.9800
# Epoch 04990: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.3214e-04 - coeff_determination: 0.9794
# Epoch 4991/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3076e-04 - coeff_determination: 0.9781
# Epoch 04991: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2758e-04 - coeff_determination: 0.9790
# Epoch 4992/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.0961e-04 - coeff_determination: 0.9809
# Epoch 04992: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 12ms/sample - loss: 5.2215e-04 - coeff_determination: 0.9801
# Epoch 4993/5000
# 12/20 [=================>............] - ETA: 0s - loss: 4.8735e-04 - coeff_determination: 0.9821
# Epoch 04993: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 11ms/sample - loss: 5.2757e-04 - coeff_determination: 0.9799
# Epoch 4994/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.3167e-04 - coeff_determination: 0.9803
# Epoch 04994: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.3841e-04 - coeff_determination: 0.9798
# Epoch 4995/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.1220e-04 - coeff_determination: 0.9807
# Epoch 04995: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.3921e-04 - coeff_determination: 0.9796
# Epoch 4996/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4496e-04 - coeff_determination: 0.9756
# Epoch 04996: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.4725e-04 - coeff_determination: 0.9775
# Epoch 4997/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.4976e-04 - coeff_determination: 0.9792
# Epoch 04997: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.4401e-04 - coeff_determination: 0.9783
# Epoch 4998/5000
# 12/20 [=================>............] - ETA: 0s - loss: 6.0962e-04 - coeff_determination: 0.9784
# Epoch 04998: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.5002e-04 - coeff_determination: 0.9788
# Epoch 4999/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.5909e-04 - coeff_determination: 0.9786
# Epoch 04999: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.4442e-04 - coeff_determination: 0.9784
# Epoch 5000/5000
# 12/20 [=================>............] - ETA: 0s - loss: 5.7318e-04 - coeff_determination: 0.9780
# Epoch 05000: loss did not improve from 0.00052
# 20/20 [==============================] - 0s 10ms/sample - loss: 5.4483e-04 - coeff_determination: 0.9791

# %%
print('Time elapsed:',end_time-start_time)
# Out:
# Time elapsed: 1182.7716064453125

# %%
# Testing
import matplotlib.pyplot as plt
lstm_model.load_weights(weights_filepath)

filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(1,num_coeffs+num_ivs,500))
test_data[0,0:num_coeffs,:] = np.transpose(true_pca_evol[:,:])

test_data[0,-2,:] = -1.0/2.7
test_data[0,-1,:] = -1.0/4.0

# %%
pred_pca = lstm_model.predict(test_data[:,:,:burn_in])
pred_pca = np.concatenate((test_data[:,:,:burn_in],pred_pca),axis=-1)

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[0,0,:],label='True')
ax[0,0].plot(pred_pca[0,0,:],label='Predicted')
ax[0,0].set_title('Mode 1')


ax[1,0].plot(test_data[0,1,:],label='True')
ax[1,0].plot(pred_pca[0,1,:],label='Predicted')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[0,2,:],label='True')
ax[0,1].plot(pred_pca[0,2,:],label='Predicted')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[0,3,:],label='True')
ax[1,1].plot(pred_pca[0,3,:],label='Predicted')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
# Plotting some contours
# True field
true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

pred_rb = np.transpose(pred_pca[0,:num_modes,:])
pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
cx = ax[0].contourf(true_recon)
ax[1].contourf(pred_recon)

fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %%
np.save('Figures/NAT_LSTM_PT_Preds.npy',pred_pca)
np.save('Figures/NAT_LSTM_PT_Fields.npy',pred_recon)
