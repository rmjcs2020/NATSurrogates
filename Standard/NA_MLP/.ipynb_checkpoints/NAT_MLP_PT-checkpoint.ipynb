# %%
import numpy as np
np.random.seed(5)
import tensorflow as tf
tf.set_random_seed(15)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]
coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = coeff_scaler.fit_transform(np.transpose(pca_coeffs))

# %%
# The total shape is large due to multiple simulations
num_samples_total = np.shape(pca_coeffs_scaled)[0]
num_sims = int(num_samples_total/500)
pca_coeffs_scaled = np.reshape(pca_coeffs_scaled,newshape=(num_sims,500*40))

# %%
seq_num = 20
training_data_ip = np.copy(pca_coeffs_scaled[:,:40*(seq_num)])
training_data_ip = np.concatenate((training_data_ip,locs),axis=-1)
training_data_op = np.copy(pca_coeffs_scaled[:,40*(seq_num):])

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_MLP_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
mlp_inputs = Input(shape=(40*seq_num+2),name='mlp_inputs')
h1 = Dense(148,activation='tanh')(mlp_inputs)
h2 = Dense(148,activation='tanh')(h1)
mlp_outputs = Dense((500-seq_num)*(40),activation=None)(h2)

mlp_model = Model(inputs=mlp_inputs,outputs=mlp_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
mlp_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
mlp_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0126 18:25:34.698915 140564472837952 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mlp_inputs (InputLayer)      [(None, 802)]             0
# _________________________________________________________________
# dense (Dense)                (None, 148)               118844
# _________________________________________________________________
# dense_1 (Dense)              (None, 148)               22052
# _________________________________________________________________
# dense_2 (Dense)              (None, 19200)             2860800
# =================================================================
# Total params: 3,001,696
# Trainable params: 3,001,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 1000
batch_size = 4
train_mode = True

from time import time

start_time = time()
if train_mode:
    train_history = mlp_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_MLP_PT.npy',train_history.history['loss'])
    
end_time = time()
# Out:
# Epoch 1/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.2669 - coeff_determination: -307.0498
# Epoch 00001: loss improved from inf to 0.23450, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 7ms/sample - loss: 0.2345 - coeff_determination: -230.1008
# Epoch 2/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.1609 - coeff_determination: -70.8842
# Epoch 00002: loss improved from 0.23450 to 0.11563, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.1156 - coeff_determination: -46.1220
# Epoch 3/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0552 - coeff_determination: -19.0383
# Epoch 00003: loss improved from 0.11563 to 0.03131, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0313 - coeff_determination: -10.4686
# Epoch 4/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0123 - coeff_determination: -3.8092
# Epoch 00004: loss improved from 0.03131 to 0.01476, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0148 - coeff_determination: -4.8045
# Epoch 5/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0206 - coeff_determination: -5.8214
# Epoch 00005: loss did not improve from 0.01476
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0211 - coeff_determination: -4.4401
# Epoch 6/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0171 - coeff_determination: -2.0288
# Epoch 00006: loss improved from 0.01476 to 0.01386, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0139 - coeff_determination: -1.2008
# Epoch 7/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -0.3585
# Epoch 00007: loss improved from 0.01386 to 0.01037, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0104 - coeff_determination: -0.5488
# Epoch 8/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0102 - coeff_determination: -0.7262
# Epoch 00008: loss did not improve from 0.01037
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0109 - coeff_determination: -1.1396
# Epoch 9/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.3277
# Epoch 00009: loss improved from 0.01037 to 0.00983, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0098 - coeff_determination: -1.6631
# Epoch 10/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -1.8041
# Epoch 00010: loss improved from 0.00983 to 0.00922, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -1.9631
# Epoch 11/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -2.1650
# Epoch 00011: loss did not improve from 0.00922
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0095 - coeff_determination: -2.1248
# Epoch 12/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -1.9250
# Epoch 00012: loss improved from 0.00922 to 0.00919, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0092 - coeff_determination: -1.8460
# Epoch 13/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.4654
# Epoch 00013: loss improved from 0.00919 to 0.00906, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5868
# Epoch 14/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.3424
# Epoch 00014: loss did not improve from 0.00906
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.5193
# Epoch 15/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.6506
# Epoch 00015: loss improved from 0.00906 to 0.00903, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0090 - coeff_determination: -1.5038
# Epoch 16/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.7099
# Epoch 00016: loss did not improve from 0.00903
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5334
# Epoch 17/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0089 - coeff_determination: -1.5181
# Epoch 00017: loss did not improve from 0.00903
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5412
# Epoch 18/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.7992
# Epoch 00018: loss did not improve from 0.00903
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6009
# Epoch 19/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0089 - coeff_determination: -1.5558
# Epoch 00019: loss improved from 0.00903 to 0.00902, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0090 - coeff_determination: -1.5529
# Epoch 20/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0081 - coeff_determination: -1.2867
# Epoch 00020: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.4965
# Epoch 21/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.7923
# Epoch 00021: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6218
# Epoch 22/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.5627
# Epoch 00022: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6339
# Epoch 23/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0101 - coeff_determination: -1.9064
# Epoch 00023: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.6646
# Epoch 24/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -1.7903
# Epoch 00024: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6596
# Epoch 25/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.4905
# Epoch 00025: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5559
# Epoch 26/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0107 - coeff_determination: -2.0067
# Epoch 00026: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5435
# Epoch 27/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3295
# Epoch 00027: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.4428
# Epoch 28/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.5319
# Epoch 00028: loss improved from 0.00902 to 0.00902, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0090 - coeff_determination: -1.4469
# Epoch 29/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.3940
# Epoch 00029: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5581
# Epoch 30/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.7463
# Epoch 00030: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6881
# Epoch 31/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.6439
# Epoch 00031: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.7084
# Epoch 32/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.6091
# Epoch 00032: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6577
# Epoch 33/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0081 - coeff_determination: -1.3532
# Epoch 00033: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5917
# Epoch 34/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3799
# Epoch 00034: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5345
# Epoch 35/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3414
# Epoch 00035: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5393
# Epoch 36/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.4617
# Epoch 00036: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5065
# Epoch 37/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.6105
# Epoch 00037: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5347
# Epoch 38/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.6551
# Epoch 00038: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6285
# Epoch 39/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -1.6666
# Epoch 00039: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6127
# Epoch 40/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.3858
# Epoch 00040: loss improved from 0.00902 to 0.00902, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5216
# Epoch 41/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.4411
# Epoch 00041: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5361
# Epoch 42/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.3901
# Epoch 00042: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5253
# Epoch 43/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -1.2433
# Epoch 00043: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.6125
# Epoch 44/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0092 - coeff_determination: -1.6961
# Epoch 00044: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6349
# Epoch 45/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.4742
# Epoch 00045: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5931
# Epoch 46/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -1.6021
# Epoch 00046: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6453
# Epoch 47/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.5064
# Epoch 00047: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5836
# Epoch 48/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.4774
# Epoch 00048: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5891
# Epoch 49/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -1.5990
# Epoch 00049: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5909
# Epoch 50/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3928
# Epoch 00050: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5684
# Epoch 51/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.6542
# Epoch 00051: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5557
# Epoch 52/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.4296
# Epoch 00052: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.4873
# Epoch 53/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0098 - coeff_determination: -1.6737
# Epoch 00053: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5848
# Epoch 54/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.4962
# Epoch 00054: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.6571
# Epoch 55/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.8322
# Epoch 00055: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6999
# Epoch 56/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -1.7865
# Epoch 00056: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6622
# Epoch 57/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -1.2628
# Epoch 00057: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.4872
# Epoch 58/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0105 - coeff_determination: -1.7987
# Epoch 00058: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5166
# Epoch 59/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0095 - coeff_determination: -1.7140
# Epoch 00059: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.6002
# Epoch 60/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0099 - coeff_determination: -1.8480
# Epoch 00060: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.6427
# Epoch 61/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.7725
# Epoch 00061: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6352
# Epoch 62/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0106 - coeff_determination: -1.9741
# Epoch 00062: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5640
# Epoch 63/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3467
# Epoch 00063: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0092 - coeff_determination: -1.4642
# Epoch 64/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.1811
# Epoch 00064: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.3847
# Epoch 65/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.3373
# Epoch 00065: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5506
# Epoch 66/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0090 - coeff_determination: -1.6402
# Epoch 00066: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6916
# Epoch 67/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.6407
# Epoch 00067: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6673
# Epoch 68/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -1.6248
# Epoch 00068: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5902
# Epoch 69/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.7274
# Epoch 00069: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.6224
# Epoch 70/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -1.7268
# Epoch 00070: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.5980
# Epoch 71/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3661
# Epoch 00071: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5035
# Epoch 72/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0103 - coeff_determination: -1.7852
# Epoch 00072: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.5666
# Epoch 73/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.5465
# Epoch 00073: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5712
# Epoch 74/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.3699
# Epoch 00074: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5434
# Epoch 75/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -1.3228
# Epoch 00075: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5709
# Epoch 76/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.6846
# Epoch 00076: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6566
# Epoch 77/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0091 - coeff_determination: -1.7105
# Epoch 00077: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.6757
# Epoch 78/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0100 - coeff_determination: -1.8928
# Epoch 00078: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.6455
# Epoch 79/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -1.3637
# Epoch 00079: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5565
# Epoch 80/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.4245
# Epoch 00080: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.4854
# Epoch 81/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0097 - coeff_determination: -1.6334
# Epoch 00081: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5216
# Epoch 82/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0094 - coeff_determination: -1.6898
# Epoch 00082: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5490
# Epoch 83/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.3898
# Epoch 00083: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5551
# Epoch 84/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0083 - coeff_determination: -1.4002
# Epoch 00084: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 1ms/sample - loss: 0.0091 - coeff_determination: -1.5848
# Epoch 85/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0093 - coeff_determination: -1.6639
# Epoch 00085: loss improved from 0.00902 to 0.00902, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5904
# Epoch 86/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.4433
# Epoch 00086: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0091 - coeff_determination: -1.5829
# Epoch 87/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.3660
# Epoch 00087: loss did not improve from 0.00902
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.4583
# Epoch 88/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0089 - coeff_determination: -1.4159
# Epoch 00088: loss improved from 0.00902 to 0.00898, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.4956
# Epoch 89/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -1.2829
# Epoch 00089: loss improved from 0.00898 to 0.00897, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0090 - coeff_determination: -1.5464
# Epoch 90/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0083 - coeff_determination: -1.4013
# Epoch 00090: loss improved from 0.00897 to 0.00892, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -1.5723
# Epoch 91/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0087 - coeff_determination: -1.5020
# Epoch 00091: loss did not improve from 0.00892
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -1.5490
# Epoch 92/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.3725
# Epoch 00092: loss improved from 0.00892 to 0.00883, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0088 - coeff_determination: -1.4918
# Epoch 93/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0096 - coeff_determination: -1.7193
# Epoch 00093: loss did not improve from 0.00883
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0089 - coeff_determination: -1.5289
# Epoch 94/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0088 - coeff_determination: -1.5213
# Epoch 00094: loss improved from 0.00883 to 0.00877, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0088 - coeff_determination: -1.5230
# Epoch 95/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0078 - coeff_determination: -1.2198
# Epoch 00095: loss improved from 0.00877 to 0.00870, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -1.4797
# Epoch 96/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -1.3608
# Epoch 00096: loss improved from 0.00870 to 0.00865, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0087 - coeff_determination: -1.4085
# Epoch 97/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.2494
# Epoch 00097: loss improved from 0.00865 to 0.00858, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0086 - coeff_determination: -1.2994
# Epoch 98/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.3739
# Epoch 00098: loss did not improve from 0.00858
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0086 - coeff_determination: -1.3363
# Epoch 99/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -1.0440
# Epoch 00099: loss improved from 0.00858 to 0.00846, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0085 - coeff_determination: -1.1222
# Epoch 100/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0080 - coeff_determination: -0.9594
# Epoch 00100: loss improved from 0.00846 to 0.00833, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0083 - coeff_determination: -1.1932
# Epoch 101/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0084 - coeff_determination: -1.2621
# Epoch 00101: loss improved from 0.00833 to 0.00816, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0082 - coeff_determination: -1.1227
# Epoch 102/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0085 - coeff_determination: -1.1330
# Epoch 00102: loss improved from 0.00816 to 0.00810, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0081 - coeff_determination: -1.0522
# Epoch 103/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0086 - coeff_determination: -1.1476
# Epoch 00103: loss improved from 0.00810 to 0.00796, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0080 - coeff_determination: -0.9591
# Epoch 104/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0075 - coeff_determination: -0.5741
# Epoch 00104: loss improved from 0.00796 to 0.00793, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0079 - coeff_determination: -0.9011
# Epoch 105/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0073 - coeff_determination: -0.5602
# Epoch 00105: loss improved from 0.00793 to 0.00788, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0079 - coeff_determination: -0.8526
# Epoch 106/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0079 - coeff_determination: -0.9934
# Epoch 00106: loss improved from 0.00788 to 0.00784, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0078 - coeff_determination: -0.7263
# Epoch 107/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -1.1013
# Epoch 00107: loss improved from 0.00784 to 0.00777, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0078 - coeff_determination: -0.7524
# Epoch 108/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0067 - coeff_determination: -0.2631
# Epoch 00108: loss improved from 0.00777 to 0.00773, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0077 - coeff_determination: -0.7084
# Epoch 109/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0073 - coeff_determination: -0.6670
# Epoch 00109: loss improved from 0.00773 to 0.00770, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0077 - coeff_determination: -0.7198
# Epoch 110/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0073 - coeff_determination: -0.3906
# Epoch 00110: loss improved from 0.00770 to 0.00769, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0077 - coeff_determination: -0.6438
# Epoch 111/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0074 - coeff_determination: -0.4578
# Epoch 00111: loss did not improve from 0.00769
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0077 - coeff_determination: -0.6214
# Epoch 112/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0068 - coeff_determination: -0.2240
# Epoch 00112: loss improved from 0.00769 to 0.00763, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0076 - coeff_determination: -0.6380
# Epoch 113/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0068 - coeff_determination: -0.1877
# Epoch 00113: loss improved from 0.00763 to 0.00759, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0076 - coeff_determination: -0.6414
# Epoch 114/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0077 - coeff_determination: -0.7910
# Epoch 00114: loss improved from 0.00759 to 0.00750, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0075 - coeff_determination: -0.5844
# Epoch 115/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0082 - coeff_determination: -0.7412
# Epoch 00115: loss improved from 0.00750 to 0.00746, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0075 - coeff_determination: -0.5820
# Epoch 116/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0078 - coeff_determination: -0.9449
# Epoch 00116: loss improved from 0.00746 to 0.00743, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0074 - coeff_determination: -0.5711
# Epoch 117/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0065 - coeff_determination: -0.1293
# Epoch 00117: loss improved from 0.00743 to 0.00735, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0073 - coeff_determination: -0.5539
# Epoch 118/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0071 - coeff_determination: -0.6901
# Epoch 00118: loss improved from 0.00735 to 0.00721, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0072 - coeff_determination: -0.4897
# Epoch 119/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0072 - coeff_determination: -0.4419
# Epoch 00119: loss improved from 0.00721 to 0.00716, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0072 - coeff_determination: -0.5267
# Epoch 120/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0071 - coeff_determination: -0.3104
# Epoch 00120: loss improved from 0.00716 to 0.00699, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0070 - coeff_determination: -0.5058
# Epoch 121/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0062 - coeff_determination: -0.2900
# Epoch 00121: loss improved from 0.00699 to 0.00690, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0069 - coeff_determination: -0.4508
# Epoch 122/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0069 - coeff_determination: -0.7296
# Epoch 00122: loss improved from 0.00690 to 0.00683, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0068 - coeff_determination: -0.4867
# Epoch 123/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0075 - coeff_determination: -0.6779
# Epoch 00123: loss improved from 0.00683 to 0.00665, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0066 - coeff_determination: -0.3223
# Epoch 124/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0060 - coeff_determination: -0.0572
# Epoch 00124: loss improved from 0.00665 to 0.00651, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0065 - coeff_determination: -0.3943
# Epoch 125/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0063 - coeff_determination: -0.1816
# Epoch 00125: loss improved from 0.00651 to 0.00640, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0064 - coeff_determination: -0.2075
# Epoch 126/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0061 - coeff_determination: -0.2452
# Epoch 00126: loss improved from 0.00640 to 0.00615, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0062 - coeff_determination: -0.2104
# Epoch 127/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0069 - coeff_determination: -0.3832
# Epoch 00127: loss improved from 0.00615 to 0.00607, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0061 - coeff_determination: -0.1486
# Epoch 128/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0052 - coeff_determination: 0.0978
# Epoch 00128: loss improved from 0.00607 to 0.00595, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0059 - coeff_determination: -0.0895
# Epoch 129/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0057 - coeff_determination: -0.1674
# Epoch 00129: loss improved from 0.00595 to 0.00584, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0058 - coeff_determination: -0.0872
# Epoch 130/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0062 - coeff_determination: -0.0869
# Epoch 00130: loss improved from 0.00584 to 0.00570, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0057 - coeff_determination: 0.0154
# Epoch 131/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0051 - coeff_determination: 0.0801
# Epoch 00131: loss improved from 0.00570 to 0.00560, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0056 - coeff_determination: 0.0256
# Epoch 132/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0064 - coeff_determination: -0.2707
# Epoch 00132: loss improved from 0.00560 to 0.00554, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0055 - coeff_determination: 0.0560
# Epoch 133/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0060 - coeff_determination: -0.1121
# Epoch 00133: loss improved from 0.00554 to 0.00552, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0055 - coeff_determination: 0.0722
# Epoch 134/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0055 - coeff_determination: 0.0196
# Epoch 00134: loss improved from 0.00552 to 0.00541, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0054 - coeff_determination: 0.1266
# Epoch 135/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0056 - coeff_determination: -0.0074
# Epoch 00135: loss improved from 0.00541 to 0.00534, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0053 - coeff_determination: 0.1551
# Epoch 136/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0052 - coeff_determination: 0.1769
# Epoch 00136: loss improved from 0.00534 to 0.00529, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0053 - coeff_determination: 0.1687
# Epoch 137/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0058 - coeff_determination: 0.0058
# Epoch 00137: loss improved from 0.00529 to 0.00523, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0052 - coeff_determination: 0.1838
# Epoch 138/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.3462
# Epoch 00138: loss improved from 0.00523 to 0.00516, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0052 - coeff_determination: 0.1846
# Epoch 139/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0048 - coeff_determination: 0.2570
# Epoch 00139: loss improved from 0.00516 to 0.00509, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0051 - coeff_determination: 0.2422
# Epoch 140/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.4740
# Epoch 00140: loss improved from 0.00509 to 0.00507, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0051 - coeff_determination: 0.1970
# Epoch 141/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0060 - coeff_determination: -0.0696
# Epoch 00141: loss improved from 0.00507 to 0.00502, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0050 - coeff_determination: 0.2406
# Epoch 142/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0055 - coeff_determination: -0.0633
# Epoch 00142: loss improved from 0.00502 to 0.00495, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0049 - coeff_determination: 0.2349
# Epoch 143/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0053 - coeff_determination: 0.0771
# Epoch 00143: loss improved from 0.00495 to 0.00490, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0049 - coeff_determination: 0.2493
# Epoch 144/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.4845
# Epoch 00144: loss improved from 0.00490 to 0.00486, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0049 - coeff_determination: 0.2693
# Epoch 145/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0049 - coeff_determination: 0.3804
# Epoch 00145: loss improved from 0.00486 to 0.00477, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0048 - coeff_determination: 0.3161
# Epoch 146/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0054 - coeff_determination: 0.0418
# Epoch 00146: loss improved from 0.00477 to 0.00472, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0047 - coeff_determination: 0.2885
# Epoch 147/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0059 - coeff_determination: -0.1531
# Epoch 00147: loss improved from 0.00472 to 0.00468, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0047 - coeff_determination: 0.2842
# Epoch 148/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0043 - coeff_determination: 0.4597
# Epoch 00148: loss improved from 0.00468 to 0.00464, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0046 - coeff_determination: 0.3252
# Epoch 149/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0050 - coeff_determination: 0.2598
# Epoch 00149: loss improved from 0.00464 to 0.00461, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0046 - coeff_determination: 0.3431
# Epoch 150/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0028 - coeff_determination: 0.6295
# Epoch 00150: loss improved from 0.00461 to 0.00455, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0045 - coeff_determination: 0.3570
# Epoch 151/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0059 - coeff_determination: 0.0430
# Epoch 00151: loss improved from 0.00455 to 0.00451, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0045 - coeff_determination: 0.3706
# Epoch 152/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0049 - coeff_determination: 0.3197
# Epoch 00152: loss improved from 0.00451 to 0.00444, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0044 - coeff_determination: 0.3705
# Epoch 153/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.5011
# Epoch 00153: loss improved from 0.00444 to 0.00441, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0044 - coeff_determination: 0.3948
# Epoch 154/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0056 - coeff_determination: 0.2306
# Epoch 00154: loss improved from 0.00441 to 0.00436, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0044 - coeff_determination: 0.4268
# Epoch 155/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0053 - coeff_determination: 0.2757
# Epoch 00155: loss improved from 0.00436 to 0.00434, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0043 - coeff_determination: 0.4225
# Epoch 156/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.5451
# Epoch 00156: loss improved from 0.00434 to 0.00429, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0043 - coeff_determination: 0.4261
# Epoch 157/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0040 - coeff_determination: 0.5318
# Epoch 00157: loss improved from 0.00429 to 0.00423, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0042 - coeff_determination: 0.4311
# Epoch 158/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.3513
# Epoch 00158: loss improved from 0.00423 to 0.00412, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0041 - coeff_determination: 0.4512
# Epoch 159/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.5134
# Epoch 00159: loss improved from 0.00412 to 0.00412, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0041 - coeff_determination: 0.4382
# Epoch 160/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0035 - coeff_determination: 0.6088
# Epoch 00160: loss did not improve from 0.00412
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0041 - coeff_determination: 0.4541
# Epoch 161/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0047 - coeff_determination: 0.3821
# Epoch 00161: loss improved from 0.00412 to 0.00407, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0041 - coeff_determination: 0.4590
# Epoch 162/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0027 - coeff_determination: 0.6489
# Epoch 00162: loss improved from 0.00407 to 0.00406, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0041 - coeff_determination: 0.4956
# Epoch 163/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0039 - coeff_determination: 0.5515
# Epoch 00163: loss improved from 0.00406 to 0.00398, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0040 - coeff_determination: 0.4785
# Epoch 164/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.5612
# Epoch 00164: loss improved from 0.00398 to 0.00391, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0039 - coeff_determination: 0.5120
# Epoch 165/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0026 - coeff_determination: 0.7068
# Epoch 00165: loss improved from 0.00391 to 0.00389, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0039 - coeff_determination: 0.4781
# Epoch 166/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0028 - coeff_determination: 0.6757
# Epoch 00166: loss improved from 0.00389 to 0.00382, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0038 - coeff_determination: 0.5160
# Epoch 167/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0037 - coeff_determination: 0.5519
# Epoch 00167: loss improved from 0.00382 to 0.00376, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0038 - coeff_determination: 0.5176
# Epoch 168/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0041 - coeff_determination: 0.4443
# Epoch 00168: loss improved from 0.00376 to 0.00375, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0038 - coeff_determination: 0.5372
# Epoch 169/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.5584
# Epoch 00169: loss improved from 0.00375 to 0.00369, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0037 - coeff_determination: 0.5352
# Epoch 170/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0045 - coeff_determination: 0.3396
# Epoch 00170: loss improved from 0.00369 to 0.00360, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0036 - coeff_determination: 0.5490
# Epoch 171/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0038 - coeff_determination: 0.4461
# Epoch 00171: loss did not improve from 0.00360
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0036 - coeff_determination: 0.5424
# Epoch 172/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0034 - coeff_determination: 0.5170
# Epoch 00172: loss improved from 0.00360 to 0.00360, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 3ms/sample - loss: 0.0036 - coeff_determination: 0.5611
# Epoch 173/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0027 - coeff_determination: 0.7371
# Epoch 00173: loss did not improve from 0.00360
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0037 - coeff_determination: 0.5331
# Epoch 174/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 0.0033 - coeff_determination: 0.6305
# Epoch 00174: loss did not improve from 0.00360
# 20/20 [==============================] - 0s 2ms/sample - loss: 0.0037 - coeff_determination: 0.5646
# ...
#  4/20 [=====>........................] - ETA: 0s - loss: 1.5903e-05 - coeff_determination: 0.9987
# Epoch 00562: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.5681e-05 - coeff_determination: 0.9979
# Epoch 563/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.7914e-05 - coeff_determination: 0.9985
# Epoch 00563: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.4826e-05 - coeff_determination: 0.9979
# Epoch 564/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.9035e-05 - coeff_determination: 0.9977
# Epoch 00564: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 1ms/sample - loss: 2.5430e-05 - coeff_determination: 0.9979
# Epoch 565/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.1490e-05 - coeff_determination: 0.9991
# Epoch 00565: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.3881e-05 - coeff_determination: 0.9980
# Epoch 566/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.1123e-05 - coeff_determination: 0.9991
# Epoch 00566: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.5400e-05 - coeff_determination: 0.9979
# Epoch 567/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.1156e-05 - coeff_determination: 0.9983
# Epoch 00567: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.2655e-05 - coeff_determination: 0.9981
# Epoch 568/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.0897e-05 - coeff_determination: 0.9992
# Epoch 00568: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.5107e-05 - coeff_determination: 0.9979
# Epoch 569/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.0679e-05 - coeff_determination: 0.9982
# Epoch 00569: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.3798e-05 - coeff_determination: 0.9981
# Epoch 570/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.5341e-05 - coeff_determination: 0.9987
# Epoch 00570: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.6429e-05 - coeff_determination: 0.9979
# Epoch 571/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.8521e-05 - coeff_determination: 0.9986
# Epoch 00571: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.7957e-05 - coeff_determination: 0.9977
# Epoch 572/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 4.1418e-05 - coeff_determination: 0.9967
# Epoch 00572: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.7916e-05 - coeff_determination: 0.9978
# Epoch 573/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.0939e-05 - coeff_determination: 0.9983
# Epoch 00573: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.5397e-05 - coeff_determination: 0.9979
# Epoch 574/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.5867e-06 - coeff_determination: 0.9992
# Epoch 00574: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.6912e-05 - coeff_determination: 0.9979
# Epoch 575/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.4809e-05 - coeff_determination: 0.9989
# Epoch 00575: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.7565e-05 - coeff_determination: 0.9977
# Epoch 576/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.8538e-05 - coeff_determination: 0.9985
# Epoch 00576: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 3.5964e-05 - coeff_determination: 0.9972
# Epoch 577/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 3.8257e-05 - coeff_determination: 0.9970
# Epoch 00577: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 6.0012e-05 - coeff_determination: 0.9951
# Epoch 578/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.3152e-04 - coeff_determination: 0.9883
# Epoch 00578: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 6.4854e-05 - coeff_determination: 0.9946
# Epoch 579/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 4.1379e-05 - coeff_determination: 0.9965
# Epoch 00579: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 4.5208e-05 - coeff_determination: 0.9963
# Epoch 580/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 3.8272e-05 - coeff_determination: 0.9970
# Epoch 00580: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 4.6180e-05 - coeff_determination: 0.9962
# Epoch 581/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 5.4755e-05 - coeff_determination: 0.9956
# Epoch 00581: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 5.6823e-05 - coeff_determination: 0.9954
# Epoch 582/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 8.6235e-05 - coeff_determination: 0.9932
# Epoch 00582: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 5.4271e-05 - coeff_determination: 0.9956
# Epoch 583/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 5.6451e-05 - coeff_determination: 0.9951
# Epoch 00583: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 5.4355e-05 - coeff_determination: 0.9956
# Epoch 584/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 5.3781e-05 - coeff_determination: 0.9959
# Epoch 00584: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 5.8711e-05 - coeff_determination: 0.9953
# Epoch 585/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.6904e-05 - coeff_determination: 0.9927
# Epoch 00585: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 6.9704e-05 - coeff_determination: 0.9943
# Epoch 586/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 5.1888e-05 - coeff_determination: 0.9961
# Epoch 00586: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 7.0031e-05 - coeff_determination: 0.9944
# Epoch 587/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 6.4405e-05 - coeff_determination: 0.9948
# Epoch 00587: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 7.5689e-05 - coeff_determination: 0.9935
# Epoch 588/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 6.3066e-05 - coeff_determination: 0.9939
# Epoch 00588: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.2510e-04 - coeff_determination: 0.9900
# Epoch 589/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.4111e-05 - coeff_determination: 0.9925
# Epoch 00589: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 1ms/sample - loss: 2.1438e-04 - coeff_determination: 0.9826
# Epoch 590/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.4858e-04 - coeff_determination: 0.9881
# Epoch 00590: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 3.3384e-04 - coeff_determination: 0.9744
# Epoch 591/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.6828e-04 - coeff_determination: 0.9851
# Epoch 00591: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.4493e-04 - coeff_determination: 0.9796
# Epoch 592/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.2559e-04 - coeff_determination: 0.9898
# Epoch 00592: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.4058e-04 - coeff_determination: 0.9885
# Epoch 593/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.9287e-04 - coeff_determination: 0.9862
# Epoch 00593: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.9681e-04 - coeff_determination: 0.9842
# Epoch 594/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.6751e-04 - coeff_determination: 0.9864
# Epoch 00594: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.5143e-04 - coeff_determination: 0.9877
# Epoch 595/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.4541e-04 - coeff_determination: 0.9886
# Epoch 00595: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.6117e-04 - coeff_determination: 0.9870
# Epoch 596/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.7368e-04 - coeff_determination: 0.9774
# Epoch 00596: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.5090e-04 - coeff_determination: 0.9877
# Epoch 597/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.8950e-05 - coeff_determination: 0.9927
# Epoch 00597: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.4891e-04 - coeff_determination: 0.9877
# Epoch 598/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.2683e-04 - coeff_determination: 0.9899
# Epoch 00598: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.3815e-04 - coeff_determination: 0.9884
# Epoch 599/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 9.4224e-05 - coeff_determination: 0.9919
# Epoch 00599: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.3296e-04 - coeff_determination: 0.9892
# Epoch 600/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.3759e-04 - coeff_determination: 0.9891
# Epoch 00600: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.5466e-04 - coeff_determination: 0.9875
# Epoch 601/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.0228e-04 - coeff_determination: 0.9923
# Epoch 00601: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.1086e-04 - coeff_determination: 0.9910
# Epoch 602/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 8.5772e-05 - coeff_determination: 0.9929
# Epoch 00602: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 9.4528e-05 - coeff_determination: 0.9923
# Epoch 603/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 8.3201e-05 - coeff_determination: 0.9939
# Epoch 00603: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.1936e-04 - coeff_determination: 0.9901
# Epoch 604/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 7.5679e-05 - coeff_determination: 0.9940
# Epoch 00604: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 7.8120e-05 - coeff_determination: 0.9936
# Epoch 605/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.0256e-04 - coeff_determination: 0.9906
# Epoch 00605: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 7.2371e-05 - coeff_determination: 0.9941
# Epoch 606/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 6.4460e-05 - coeff_determination: 0.9949
# Epoch 00606: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 5.1320e-05 - coeff_determination: 0.9958
# Epoch 607/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 7.6424e-05 - coeff_determination: 0.9943
# Epoch 00607: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 4.9142e-05 - coeff_determination: 0.9960
# Epoch 608/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 6.5529e-05 - coeff_determination: 0.9945
# Epoch 00608: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 4.4741e-05 - coeff_determination: 0.9963
# Epoch 609/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 4.4803e-05 - coeff_determination: 0.9964
# Epoch 00609: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 3.9729e-05 - coeff_determination: 0.9968
# Epoch 610/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 4.1994e-05 - coeff_determination: 0.9966
# Epoch 00610: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 3.7321e-05 - coeff_determination: 0.9969
# Epoch 611/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 3.1246e-05 - coeff_determination: 0.9976
# Epoch 00611: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 1ms/sample - loss: 2.8883e-05 - coeff_determination: 0.9976
# Epoch 612/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.8741e-05 - coeff_determination: 0.9977
# Epoch 00612: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 3.2443e-05 - coeff_determination: 0.9973
# Epoch 613/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.8805e-05 - coeff_determination: 0.9977
# Epoch 00613: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.2713e-05 - coeff_determination: 0.9981
# Epoch 614/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.7245e-05 - coeff_determination: 0.9979
# Epoch 00614: loss did not improve from 0.00002
# 20/20 [==============================] - 0s 2ms/sample - loss: 2.3371e-05 - coeff_determination: 0.9981
# Epoch 615/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.4266e-05 - coeff_determination: 0.9988
# Epoch 00615: loss improved from 0.00002 to 0.00002, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.6911e-05 - coeff_determination: 0.9986
# Epoch 616/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 2.2561e-05 - coeff_determination: 0.9981
# Epoch 00616: loss improved from 0.00002 to 0.00002, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.5054e-05 - coeff_determination: 0.9988
# Epoch 617/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.5319e-05 - coeff_determination: 0.9988
# Epoch 00617: loss improved from 0.00002 to 0.00001, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.4236e-05 - coeff_determination: 0.9988
# Epoch 618/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.7307e-05 - coeff_determination: 0.9985
# Epoch 00618: loss did not improve from 0.00001
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.5038e-05 - coeff_determination: 0.9988
# Epoch 619/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 4.5970e-06 - coeff_determination: 0.9996
# Epoch 00619: loss improved from 0.00001 to 0.00001, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.0691e-05 - coeff_determination: 0.9991
# Epoch 620/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 5.3789e-06 - coeff_determination: 0.9996
# Epoch 00620: loss did not improve from 0.00001
# 20/20 [==============================] - 0s 2ms/sample - loss: 1.1079e-05 - coeff_determination: 0.9991
# Epoch 621/1000
#  4/20 [=====>........................] - ETA: 0s - loss: 1.3093e-05 - coeff_determination: 0.9988
# Epoch 00621: loss improved from 0.00001 to 0.00001, saving model to NAT_MLP_PT.h5
# 20/20 [==============================] - 0s 2ms/sample - loss: 9.8275e-06 - coeff_determination: 0.9992

# %%
print('Time elapsed:',end_time-start_time)
# Out:
# Time elapsed: 28.144092082977295

# %%
# Testing
mlp_model.load_weights(weights_filepath)
plt_array = np.arange(500,dtype='int')


filename = '../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../SWE_Data/PCA_Vectors_q1.npy')[:,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.reshape(np.copy(true_pca_evol),newshape=(1,500*40))

test_inputs = np.copy(test_data[:,:40*seq_num])
test_outputs = np.copy(test_data[:,40*seq_num:])

test_locs = np.zeros(shape=(1,2))
test_locs[0,0] = -1.0/2.7
test_locs[0,1] = -1.0/4.0

test_inputs = np.concatenate((test_inputs,test_locs),axis=-1)

# %%
pred_pca = mlp_model.predict(test_inputs)
pred_pca = np.concatenate((test_inputs[:,:800],pred_pca),axis=-1)

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
mode_num = 0
ax[0,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[0,0].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
ax[0,0].set_title('Mode 1')

mode_num = 1
ax[1,0].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[1,0].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
ax[1,0].set_title('Mode 2')

mode_num = 2
ax[0,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[0,1].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
ax[0,1].set_title('Mode 3')

mode_num = 3
ax[1,1].plot(test_data[0,plt_array*(40)+mode_num],label='True')
ax[1,1].plot(pred_pca[0,plt_array*(40)+mode_num],label='Predicted')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
# Plotting some contours
# True field
true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
true_recon = np.matmul(pca_vectors,true_rb)[:,-1].reshape(64,64)

pred_rb = pred_pca[0,:].reshape(500,40)
pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
pred_recon = np.matmul(pca_vectors,pred_rb)[:,-1].reshape(64,64)


fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
cx = ax[0].contourf(true_recon)
ax[1].contourf(pred_recon)

fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %%
np.save('Figures/NAT_MLP_PT_Preds.npy',pred_pca)
np.save('Figures/NAT_MLP_PT_Fields.npy',pred_recon)
