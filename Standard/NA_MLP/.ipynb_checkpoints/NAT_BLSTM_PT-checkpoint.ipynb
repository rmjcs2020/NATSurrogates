# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.set_random_seed(10)
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 16, # was 10
    'legend.fontsize': 16, # was 10
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
plt.rcParams.update(params)

# %%
# Generating training data that goes from initial condition location to PCA coefficient trajectory
num_modes=40
locs = np.load('../../SWE_Data/Data/Locations.npy')
pca_coeffs = np.load('../../SWE_Data/PCA_Coefficients_q1.npy')[0:num_modes,:]

coeff_scaler = MinMaxScaler()
pca_coeffs_scaled = np.transpose(coeff_scaler.fit_transform(np.transpose(pca_coeffs)))

# %%
num_sims = np.shape(locs)[0]
num_ivs = np.shape(locs)[1]
num_coeffs = np.shape(pca_coeffs)[0]
burn_in = 20

# %%
# Reshape
training_data_ip = np.zeros(shape=(num_sims,num_coeffs+num_ivs,burn_in),dtype='double')
training_data_op = np.zeros(shape=(num_sims,num_coeffs+num_ivs,500-burn_in),dtype='double')

for sim in range(num_sims):
    training_data_ip[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim:500*sim+burn_in]
    training_data_ip[sim,-num_ivs:,:] = locs[sim,:,None]
    training_data_op[sim,:-num_ivs,:] = pca_coeffs_scaled[:,500*sim+burn_in:500*(sim+1)]
    training_data_op[sim,-num_ivs:,:] = locs[sim,:,None]

# %%
from tensorflow.keras.layers import Input, Dense, Lambda, Add, LSTM, Dropout, Bidirectional
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# %%
weights_filepath = 'NAT_BLSTM_PT.h5'

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
lstm_inputs = Input(shape=(num_coeffs+num_ivs,burn_in),name='nat_inputs')
h1 = Bidirectional(LSTM(145,return_sequences=True))(lstm_inputs)
h2 = Bidirectional(LSTM(145,return_sequences=True))(h1)
lstm_outputs = Dense(500-burn_in,activation=None)(h2)

lstm_model = Model(inputs=lstm_inputs,outputs=lstm_outputs)
 
# design network
my_adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint,EarlyStoppingByLossVal()]

# fit network
lstm_model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
lstm_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0126 14:13:04.700819 139796408706880 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0126 14:13:04.709687 139796408706880 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0126 14:13:04.710762 139796408706880 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0126 14:13:04.711477 139796408706880 deprecation.py:506] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# nat_inputs (InputLayer)      [(None, 42, 20)]          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 42, 290)           192560
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 42, 290)           505760
# _________________________________________________________________
# dense (Dense)                (None, 42, 480)           139680
# =================================================================
# Total params: 838,000
# Trainable params: 838,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 5000
batch_size = 4
train_mode = True

from time import time
start_time = time()

if train_mode:
    train_history = lstm_model.fit(x=training_data_ip, y=training_data_op, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
    np.save('NAT_BLSTM_PT.npy',train_history.history['loss'])
    
end_time = time()
# Out:
# W0121 17:10:25.340900 140516054693696 deprecation.py:323] From /home/rmlans/anaconda3/envs/deephyper_env/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5000
# 12/20 [=================>............] - ETA: 1s - loss: 0.2476 - coeff_determination: -62.0023
# Epoch 00001: loss improved from inf to 0.23672, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 2s 122ms/sample - loss: 0.2367 - coeff_determination: -53.2236
# Epoch 2/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.1717 - coeff_determination: -13.7025
# Epoch 00002: loss improved from 0.23672 to 0.15055, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.1506 - coeff_determination: -9.6206
# Epoch 3/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0770 - coeff_determination: -0.7774
# Epoch 00003: loss improved from 0.15055 to 0.07092, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0709 - coeff_determination: -0.6209
# Epoch 4/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0468 - coeff_determination: -0.5929
# Epoch 00004: loss improved from 0.07092 to 0.04054, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0405 - coeff_determination: -0.7181
# Epoch 5/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0261 - coeff_determination: -1.5644
# Epoch 00005: loss improved from 0.04054 to 0.02519, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0252 - coeff_determination: -1.6794
# Epoch 6/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0249 - coeff_determination: -2.0706
# Epoch 00006: loss improved from 0.02519 to 0.02482, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0248 - coeff_determination: -1.9482
# Epoch 7/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0212 - coeff_determination: -1.4817
# Epoch 00007: loss improved from 0.02482 to 0.02269, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0227 - coeff_determination: -1.6466
# Epoch 8/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0196 - coeff_determination: -1.5802
# Epoch 00008: loss improved from 0.02269 to 0.02071, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0207 - coeff_determination: -1.7978
# Epoch 9/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0191 - coeff_determination: -1.9900
# Epoch 00009: loss improved from 0.02071 to 0.01915, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0192 - coeff_determination: -2.0502
# Epoch 10/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0185 - coeff_determination: -2.0749
# Epoch 00010: loss improved from 0.01915 to 0.01861, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0186 - coeff_determination: -1.9815
# Epoch 11/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0190 - coeff_determination: -1.9063
# Epoch 00011: loss improved from 0.01861 to 0.01804, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0180 - coeff_determination: -1.7207
# Epoch 12/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0183 - coeff_determination: -1.6361
# Epoch 00012: loss improved from 0.01804 to 0.01753, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0175 - coeff_determination: -1.5413
# Epoch 13/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0183 - coeff_determination: -1.3710
# Epoch 00013: loss improved from 0.01753 to 0.01710, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0171 - coeff_determination: -1.4304
# Epoch 14/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0181 - coeff_determination: -1.4290
# Epoch 00014: loss improved from 0.01710 to 0.01672, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0167 - coeff_determination: -1.2946
# Epoch 15/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0163 - coeff_determination: -0.9941
# Epoch 00015: loss improved from 0.01672 to 0.01636, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0164 - coeff_determination: -1.2059
# Epoch 16/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0163 - coeff_determination: -1.0972
# Epoch 00016: loss improved from 0.01636 to 0.01604, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0160 - coeff_determination: -1.1001
# Epoch 17/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0156 - coeff_determination: -1.1392
# Epoch 00017: loss improved from 0.01604 to 0.01576, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0158 - coeff_determination: -1.0164
# Epoch 18/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0155 - coeff_determination: -0.9629
# Epoch 00018: loss improved from 0.01576 to 0.01551, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0155 - coeff_determination: -0.9066
# Epoch 19/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0148 - coeff_determination: -0.9253
# Epoch 00019: loss improved from 0.01551 to 0.01524, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0152 - coeff_determination: -0.8607
# Epoch 20/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0149 - coeff_determination: -0.7829
# Epoch 00020: loss improved from 0.01524 to 0.01503, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0150 - coeff_determination: -0.7481
# Epoch 21/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0138 - coeff_determination: -0.9380
# Epoch 00021: loss improved from 0.01503 to 0.01480, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0148 - coeff_determination: -0.7482
# Epoch 22/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0153 - coeff_determination: -0.5714
# Epoch 00022: loss improved from 0.01480 to 0.01461, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0146 - coeff_determination: -0.5919
# Epoch 23/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0154 - coeff_determination: -0.3906
# Epoch 00023: loss improved from 0.01461 to 0.01443, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0144 - coeff_determination: -0.5614
# Epoch 24/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0139 - coeff_determination: -0.4800
# Epoch 00024: loss improved from 0.01443 to 0.01421, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0142 - coeff_determination: -0.4383
# Epoch 25/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0134 - coeff_determination: -0.4148
# Epoch 00025: loss improved from 0.01421 to 0.01404, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0140 - coeff_determination: -0.4617
# Epoch 26/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0138 - coeff_determination: -0.2152
# Epoch 00026: loss improved from 0.01404 to 0.01391, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0139 - coeff_determination: -0.3833
# Epoch 27/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0137 - coeff_determination: -0.2623
# Epoch 00027: loss improved from 0.01391 to 0.01378, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0138 - coeff_determination: -0.2768
# Epoch 28/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: -0.1621
# Epoch 00028: loss improved from 0.01378 to 0.01363, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0136 - coeff_determination: -0.2356
# Epoch 29/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0139 - coeff_determination: -0.1784
# Epoch 00029: loss improved from 0.01363 to 0.01351, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0135 - coeff_determination: -0.1687
# Epoch 30/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: -0.1284
# Epoch 00030: loss improved from 0.01351 to 0.01339, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0134 - coeff_determination: -0.1894
# Epoch 31/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0131 - coeff_determination: -0.2384
# Epoch 00031: loss improved from 0.01339 to 0.01328, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0133 - coeff_determination: -0.1917
# Epoch 32/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0131 - coeff_determination: -0.1835
# Epoch 00032: loss improved from 0.01328 to 0.01316, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0132 - coeff_determination: -0.1401
# Epoch 33/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0133 - coeff_determination: -0.1055
# Epoch 00033: loss improved from 0.01316 to 0.01304, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0130 - coeff_determination: -0.0761
# Epoch 34/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0133 - coeff_determination: 0.0016
# Epoch 00034: loss improved from 0.01304 to 0.01295, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0130 - coeff_determination: -0.0651
# Epoch 35/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0129 - coeff_determination: -0.1537
# Epoch 00035: loss improved from 0.01295 to 0.01285, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0128 - coeff_determination: -0.0751
# Epoch 36/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0129 - coeff_determination: -0.0930
# Epoch 00036: loss improved from 0.01285 to 0.01271, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0127 - coeff_determination: -0.0213
# Epoch 37/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0123 - coeff_determination: 0.0253
# Epoch 00037: loss improved from 0.01271 to 0.01264, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0126 - coeff_determination: -0.0593
# Epoch 38/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0123 - coeff_determination: -0.1571
# Epoch 00038: loss improved from 0.01264 to 0.01254, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0125 - coeff_determination: -0.0274
# Epoch 39/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0124 - coeff_determination: 0.0444
# Epoch 00039: loss improved from 0.01254 to 0.01245, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 11ms/sample - loss: 0.0125 - coeff_determination: -0.0494
# Epoch 40/5000
# 12/20 [=================>............] - ETA: 0s - loss: 0.0124 - coeff_determination: -0.1592
# Epoch 00040: loss improved from 0.01245 to 0.01233, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 13ms/sample - loss: 0.0123 - coeff_determination: -0.0452
# Epoch 41/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.0929
# Epoch 00041: loss improved from 0.01233 to 0.01228, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0123 - coeff_determination: 0.0436
# Epoch 42/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0121 - coeff_determination: 0.1689
# Epoch 00042: loss improved from 0.01228 to 0.01217, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0122 - coeff_determination: 0.0611
# Epoch 43/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0120 - coeff_determination: 0.0960
# Epoch 00043: loss improved from 0.01217 to 0.01205, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0120 - coeff_determination: 0.0535
# Epoch 44/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.1735
# Epoch 00044: loss improved from 0.01205 to 0.01196, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0120 - coeff_determination: 0.1312
# Epoch 45/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0116 - coeff_determination: 0.1562
# Epoch 00045: loss improved from 0.01196 to 0.01186, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 12ms/sample - loss: 0.0119 - coeff_determination: 0.1072
# Epoch 46/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0118 - coeff_determination: 0.2021
# Epoch 00046: loss improved from 0.01186 to 0.01177, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0118 - coeff_determination: 0.1518
# Epoch 47/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0119 - coeff_determination: 0.1378
# Epoch 00047: loss improved from 0.01177 to 0.01167, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0117 - coeff_determination: 0.1762
# Epoch 48/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0114 - coeff_determination: 0.1101
# Epoch 00048: loss improved from 0.01167 to 0.01158, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0116 - coeff_determination: 0.1423
# Epoch 49/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0115 - coeff_determination: 0.1701
# Epoch 00049: loss improved from 0.01158 to 0.01148, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0115 - coeff_determination: 0.1759
# Epoch 50/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0117 - coeff_determination: 0.1079
# Epoch 00050: loss improved from 0.01148 to 0.01142, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0114 - coeff_determination: 0.0584
# Epoch 51/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0112 - coeff_determination: 0.1938
# Epoch 00051: loss improved from 0.01142 to 0.01133, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0113 - coeff_determination: 0.2043
# Epoch 52/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0112 - coeff_determination: 0.1461
# Epoch 00052: loss improved from 0.01133 to 0.01128, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0113 - coeff_determination: 0.1827
# Epoch 53/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0112 - coeff_determination: 0.1710
# Epoch 00053: loss improved from 0.01128 to 0.01116, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0112 - coeff_determination: 0.1698
# Epoch 54/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.2748
# Epoch 00054: loss improved from 0.01116 to 0.01109, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0111 - coeff_determination: 0.2531
# Epoch 55/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0111 - coeff_determination: 0.1004
# Epoch 00055: loss improved from 0.01109 to 0.01105, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0110 - coeff_determination: 0.1873
# Epoch 56/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.2243
# Epoch 00056: loss improved from 0.01105 to 0.01104, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0110 - coeff_determination: 0.2290
# Epoch 57/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.0126
# Epoch 00057: loss improved from 0.01104 to 0.01100, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0110 - coeff_determination: 0.0599
# Epoch 58/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0109 - coeff_determination: 0.2071
# Epoch 00058: loss improved from 0.01100 to 0.01089, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0109 - coeff_determination: 0.2098
# Epoch 59/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.2657
# Epoch 00059: loss improved from 0.01089 to 0.01083, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0108 - coeff_determination: 0.2820
# Epoch 60/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0108 - coeff_determination: 0.1802
# Epoch 00060: loss improved from 0.01083 to 0.01078, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0108 - coeff_determination: 0.2102
# Epoch 61/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.3097
# Epoch 00061: loss improved from 0.01078 to 0.01075, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0107 - coeff_determination: 0.2809
# Epoch 62/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.3084
# Epoch 00062: loss improved from 0.01075 to 0.01074, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0107 - coeff_determination: 0.2709
# Epoch 63/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3150
# Epoch 00063: loss did not improve from 0.01074
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0107 - coeff_determination: 0.2689
# Epoch 64/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.1876
# Epoch 00064: loss improved from 0.01074 to 0.01070, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0107 - coeff_determination: 0.2422
# Epoch 65/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.3171
# Epoch 00065: loss improved from 0.01070 to 0.01065, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0106 - coeff_determination: 0.2786
# Epoch 66/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.1039
# Epoch 00066: loss improved from 0.01065 to 0.01060, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 34ms/sample - loss: 0.0106 - coeff_determination: 0.1660
# Epoch 67/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0107 - coeff_determination: 0.3646
# Epoch 00067: loss improved from 0.01060 to 0.01058, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 29ms/sample - loss: 0.0106 - coeff_determination: 0.2779
# Epoch 68/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0106 - coeff_determination: 0.2902
# Epoch 00068: loss improved from 0.01058 to 0.01056, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 31ms/sample - loss: 0.0106 - coeff_determination: 0.3276
# Epoch 69/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.4104
# Epoch 00069: loss improved from 0.01056 to 0.01052, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0105 - coeff_determination: 0.2107
# Epoch 70/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.2847
# Epoch 00070: loss improved from 0.01052 to 0.01051, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0105 - coeff_determination: 0.3134
# Epoch 71/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.1723
# Epoch 00071: loss improved from 0.01051 to 0.01048, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0105 - coeff_determination: 0.2611
# Epoch 72/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0105 - coeff_determination: 0.3599
# Epoch 00072: loss improved from 0.01048 to 0.01044, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0104 - coeff_determination: 0.3277
# Epoch 73/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.2574
# Epoch 00073: loss improved from 0.01044 to 0.01043, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0104 - coeff_determination: 0.2762
# Epoch 74/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.2050
# Epoch 00074: loss did not improve from 0.01043
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0104 - coeff_determination: 0.2733
# Epoch 75/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3251
# Epoch 00075: loss did not improve from 0.01043
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0104 - coeff_determination: 0.2130
# Epoch 76/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.3310
# Epoch 00076: loss improved from 0.01043 to 0.01038, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0104 - coeff_determination: 0.3578
# Epoch 77/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0104 - coeff_determination: 0.3449
# Epoch 00077: loss did not improve from 0.01038
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0104 - coeff_determination: 0.3204
# Epoch 78/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0103 - coeff_determination: 0.2211
# Epoch 00078: loss improved from 0.01038 to 0.01029, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0103 - coeff_determination: 0.2951
# Epoch 79/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2947
# Epoch 00079: loss improved from 0.01029 to 0.01027, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0103 - coeff_determination: 0.3395
# Epoch 80/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.4230
# Epoch 00080: loss improved from 0.01027 to 0.01024, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0102 - coeff_determination: 0.2950
# Epoch 81/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.2160
# Epoch 00081: loss improved from 0.01024 to 0.01022, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0102 - coeff_determination: 0.2659
# Epoch 82/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3204
# Epoch 00082: loss improved from 0.01022 to 0.01016, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0102 - coeff_determination: 0.2970
# Epoch 83/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.3928
# Epoch 00083: loss improved from 0.01016 to 0.01013, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0101 - coeff_determination: 0.3561
# Epoch 84/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0101 - coeff_determination: 0.2637
# Epoch 00084: loss improved from 0.01013 to 0.01009, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0101 - coeff_determination: 0.2995
# Epoch 85/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0102 - coeff_determination: 0.4029
# Epoch 00085: loss improved from 0.01009 to 0.01008, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0101 - coeff_determination: 0.3901
# Epoch 86/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3393
# Epoch 00086: loss improved from 0.01008 to 0.01002, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0100 - coeff_determination: 0.3018
# Epoch 87/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.3350
# Epoch 00087: loss improved from 0.01002 to 0.01000, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0100 - coeff_determination: 0.3553
# Epoch 88/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0100 - coeff_determination: 0.2106
# Epoch 00088: loss improved from 0.01000 to 0.00995, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0099 - coeff_determination: 0.2886
# Epoch 89/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.4453
# Epoch 00089: loss improved from 0.00995 to 0.00992, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0099 - coeff_determination: 0.3755
# Epoch 90/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0099 - coeff_determination: 0.3493
# Epoch 00090: loss improved from 0.00992 to 0.00987, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0099 - coeff_determination: 0.3945
# Epoch 91/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.3632
# Epoch 00091: loss improved from 0.00987 to 0.00985, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0098 - coeff_determination: 0.3936
# Epoch 92/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.3549
# Epoch 00092: loss improved from 0.00985 to 0.00980, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0098 - coeff_determination: 0.3918
# Epoch 93/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.2885
# Epoch 00093: loss improved from 0.00980 to 0.00977, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0098 - coeff_determination: 0.3091
# Epoch 94/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4332
# Epoch 00094: loss improved from 0.00977 to 0.00974, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0097 - coeff_determination: 0.3964
# Epoch 95/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.3884
# Epoch 00095: loss improved from 0.00974 to 0.00972, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 29ms/sample - loss: 0.0097 - coeff_determination: 0.4201
# Epoch 96/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0098 - coeff_determination: 0.2898
# Epoch 00096: loss did not improve from 0.00972
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0097 - coeff_determination: 0.3491
# Epoch 97/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3095
# Epoch 00097: loss improved from 0.00972 to 0.00968, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0097 - coeff_determination: 0.3498
# Epoch 98/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.4235
# Epoch 00098: loss improved from 0.00968 to 0.00961, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0096 - coeff_determination: 0.4265
# Epoch 99/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0097 - coeff_determination: 0.3978
# Epoch 00099: loss improved from 0.00961 to 0.00957, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0096 - coeff_determination: 0.4130
# Epoch 100/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0096 - coeff_determination: 0.3898
# Epoch 00100: loss improved from 0.00957 to 0.00956, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0096 - coeff_determination: 0.4331
# Epoch 101/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: 0.4672
# Epoch 00101: loss improved from 0.00956 to 0.00950, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0095 - coeff_determination: 0.4170
# Epoch 102/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: 0.4174
# Epoch 00102: loss improved from 0.00950 to 0.00948, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 28ms/sample - loss: 0.0095 - coeff_determination: 0.3832
# Epoch 103/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: 0.4486
# Epoch 00103: loss improved from 0.00948 to 0.00945, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0094 - coeff_determination: 0.4264
# Epoch 104/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: 0.3516
# Epoch 00104: loss improved from 0.00945 to 0.00942, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 32ms/sample - loss: 0.0094 - coeff_determination: 0.3766
# Epoch 105/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0094 - coeff_determination: 0.4439
# Epoch 00105: loss improved from 0.00942 to 0.00937, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0094 - coeff_determination: 0.4554
# Epoch 106/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0093 - coeff_determination: 0.4055
# Epoch 00106: loss improved from 0.00937 to 0.00930, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0093 - coeff_determination: 0.4436
# Epoch 107/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0093 - coeff_determination: 0.5054
# Epoch 00107: loss improved from 0.00930 to 0.00928, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0093 - coeff_determination: 0.4510
# Epoch 108/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0092 - coeff_determination: 0.4647
# Epoch 00108: loss improved from 0.00928 to 0.00923, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0092 - coeff_determination: 0.4238
# Epoch 109/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0092 - coeff_determination: 0.4289
# Epoch 00109: loss improved from 0.00923 to 0.00922, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0092 - coeff_determination: 0.4513
# Epoch 110/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0092 - coeff_determination: 0.4037
# Epoch 00110: loss improved from 0.00922 to 0.00914, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0091 - coeff_determination: 0.4456
# Epoch 111/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0091 - coeff_determination: 0.4194
# Epoch 00111: loss improved from 0.00914 to 0.00912, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0091 - coeff_determination: 0.4641
# Epoch 112/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0091 - coeff_determination: 0.4965
# Epoch 00112: loss improved from 0.00912 to 0.00909, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0091 - coeff_determination: 0.4611
# Epoch 113/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: 0.4591
# Epoch 00113: loss improved from 0.00909 to 0.00903, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0090 - coeff_determination: 0.4610
# Epoch 114/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: 0.4318
# Epoch 00114: loss improved from 0.00903 to 0.00898, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0090 - coeff_determination: 0.4544
# Epoch 115/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: 0.5000
# Epoch 00115: loss improved from 0.00898 to 0.00891, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0089 - coeff_determination: 0.4850
# Epoch 116/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: 0.4135
# Epoch 00116: loss improved from 0.00891 to 0.00889, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0089 - coeff_determination: 0.4653
# Epoch 117/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0089 - coeff_determination: 0.4757
# Epoch 00117: loss improved from 0.00889 to 0.00882, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0088 - coeff_determination: 0.5024
# Epoch 118/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0088 - coeff_determination: 0.5571
# Epoch 00118: loss improved from 0.00882 to 0.00878, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0088 - coeff_determination: 0.4473
# Epoch 119/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0087 - coeff_determination: 0.5418
# Epoch 00119: loss improved from 0.00878 to 0.00871, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0087 - coeff_determination: 0.4799
# Epoch 120/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0087 - coeff_determination: 0.5046
# Epoch 00120: loss improved from 0.00871 to 0.00868, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0087 - coeff_determination: 0.4928
# Epoch 121/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0085 - coeff_determination: 0.2515
# Epoch 00121: loss improved from 0.00868 to 0.00866, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0087 - coeff_determination: 0.3229
# Epoch 122/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0086 - coeff_determination: 0.3966
# Epoch 00122: loss improved from 0.00866 to 0.00864, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0086 - coeff_determination: 0.4509
# Epoch 123/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0086 - coeff_determination: 0.5259
# Epoch 00123: loss improved from 0.00864 to 0.00859, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0086 - coeff_determination: 0.4208
# Epoch 124/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0086 - coeff_determination: 0.5655
# Epoch 00124: loss improved from 0.00859 to 0.00851, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0085 - coeff_determination: 0.4884
# Epoch 125/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0083 - coeff_determination: 0.4157
# Epoch 00125: loss improved from 0.00851 to 0.00848, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0085 - coeff_determination: 0.4625
# Epoch 126/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0084 - coeff_determination: 0.5755
# Epoch 00126: loss improved from 0.00848 to 0.00841, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0084 - coeff_determination: 0.5217
# Epoch 127/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0085 - coeff_determination: 0.5074
# Epoch 00127: loss did not improve from 0.00841
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0084 - coeff_determination: 0.5174
# Epoch 128/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0084 - coeff_determination: 0.5270
# Epoch 00128: loss improved from 0.00841 to 0.00837, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0084 - coeff_determination: 0.5351
# Epoch 129/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0084 - coeff_determination: 0.5567
# Epoch 00129: loss improved from 0.00837 to 0.00835, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0084 - coeff_determination: 0.5222
# Epoch 130/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0085 - coeff_determination: 0.4794
# Epoch 00130: loss did not improve from 0.00835
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0084 - coeff_determination: 0.5181
# Epoch 131/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0082 - coeff_determination: 0.5086
# Epoch 00131: loss improved from 0.00835 to 0.00833, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 18ms/sample - loss: 0.0083 - coeff_determination: 0.5143
# Epoch 132/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0084 - coeff_determination: 0.5556
# Epoch 00132: loss improved from 0.00833 to 0.00826, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0083 - coeff_determination: 0.5184
# Epoch 133/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0083 - coeff_determination: 0.4977
# Epoch 00133: loss improved from 0.00826 to 0.00825, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0082 - coeff_determination: 0.4900
# Epoch 134/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0083 - coeff_determination: 0.5157
# Epoch 00134: loss improved from 0.00825 to 0.00813, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 20ms/sample - loss: 0.0081 - coeff_determination: 0.5534
# Epoch 135/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0080 - coeff_determination: 0.4344
# Epoch 00135: loss improved from 0.00813 to 0.00807, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0081 - coeff_determination: 0.4790
# Epoch 136/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0082 - coeff_determination: 0.5791
# Epoch 00136: loss did not improve from 0.00807
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0082 - coeff_determination: 0.5301
# Epoch 137/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0080 - coeff_determination: 0.5069
# Epoch 00137: loss did not improve from 0.00807
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0081 - coeff_determination: 0.5343
# Epoch 138/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0080 - coeff_determination: 0.4910
# Epoch 00138: loss improved from 0.00807 to 0.00804, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0080 - coeff_determination: 0.5261
# Epoch 139/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0079 - coeff_determination: 0.5569
# Epoch 00139: loss improved from 0.00804 to 0.00794, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 23ms/sample - loss: 0.0079 - coeff_determination: 0.5439
# Epoch 140/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0078 - coeff_determination: 0.5760
# Epoch 00140: loss improved from 0.00794 to 0.00794, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0079 - coeff_determination: 0.5482
# Epoch 141/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0079 - coeff_determination: 0.4744
# Epoch 00141: loss improved from 0.00794 to 0.00789, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 21ms/sample - loss: 0.0079 - coeff_determination: 0.5108
# Epoch 142/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0080 - coeff_determination: 0.5680
# Epoch 00142: loss improved from 0.00789 to 0.00783, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 26ms/sample - loss: 0.0078 - coeff_determination: 0.5795
# Epoch 143/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0078 - coeff_determination: 0.5969
# Epoch 00143: loss did not improve from 0.00783
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0078 - coeff_determination: 0.5772
# Epoch 144/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0077 - coeff_determination: 0.5866
# Epoch 00144: loss improved from 0.00783 to 0.00780, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 27ms/sample - loss: 0.0078 - coeff_determination: 0.5703
# Epoch 145/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0078 - coeff_determination: 0.5553
# Epoch 00145: loss improved from 0.00780 to 0.00773, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0077 - coeff_determination: 0.5835
# Epoch 146/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0077 - coeff_determination: 0.5710
# Epoch 00146: loss improved from 0.00773 to 0.00771, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 19ms/sample - loss: 0.0077 - coeff_determination: 0.5694
# Epoch 147/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0077 - coeff_determination: 0.5644
# Epoch 00147: loss improved from 0.00771 to 0.00765, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0076 - coeff_determination: 0.5663
# Epoch 148/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0076 - coeff_determination: 0.5712
# Epoch 00148: loss improved from 0.00765 to 0.00758, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 29ms/sample - loss: 0.0076 - coeff_determination: 0.5808
# Epoch 149/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0075 - coeff_determination: 0.5865
# Epoch 00149: loss improved from 0.00758 to 0.00753, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 1s 25ms/sample - loss: 0.0075 - coeff_determination: 0.5777
# Epoch 150/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0074 - coeff_determination: 0.5660
# Epoch 00150: loss improved from 0.00753 to 0.00748, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 24ms/sample - loss: 0.0075 - coeff_determination: 0.5789
# Epoch 151/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0074 - coeff_determination: 0.5999
# Epoch 00151: loss improved from 0.00748 to 0.00745, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 22ms/sample - loss: 0.0074 - coeff_determination: 0.5990
# Epoch 152/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0073 - coeff_determination: 0.5428
# Epoch 00152: loss improved from 0.00745 to 0.00740, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0074 - coeff_determination: 0.5838
# Epoch 153/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0074 - coeff_determination: 0.6364
# Epoch 00153: loss improved from 0.00740 to 0.00739, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0074 - coeff_determination: 0.6072
# Epoch 154/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0073 - coeff_determination: 0.6380
# Epoch 00154: loss improved from 0.00739 to 0.00732, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 16ms/sample - loss: 0.0073 - coeff_determination: 0.5980
# Epoch 155/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0072 - coeff_determination: 0.6164
# Epoch 00155: loss improved from 0.00732 to 0.00731, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0073 - coeff_determination: 0.6137
# Epoch 156/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0072 - coeff_determination: 0.5803
# Epoch 00156: loss improved from 0.00731 to 0.00727, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0073 - coeff_determination: 0.5791
# Epoch 157/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0071 - coeff_determination: 0.6250
# Epoch 00157: loss improved from 0.00727 to 0.00723, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 17ms/sample - loss: 0.0072 - coeff_determination: 0.6273
# Epoch 158/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0072 - coeff_determination: 0.5254
# Epoch 00158: loss improved from 0.00723 to 0.00717, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0072 - coeff_determination: 0.5616
# Epoch 159/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0073 - coeff_determination: 0.5795
# Epoch 00159: loss did not improve from 0.00717
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0072 - coeff_determination: 0.5802
# Epoch 160/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0071 - coeff_determination: 0.6306
# Epoch 00160: loss improved from 0.00717 to 0.00715, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0071 - coeff_determination: 0.6291
# Epoch 161/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0071 - coeff_determination: 0.6567
# Epoch 00161: loss improved from 0.00715 to 0.00711, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0071 - coeff_determination: 0.6241
# Epoch 162/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0071 - coeff_determination: 0.6203
# Epoch 00162: loss did not improve from 0.00711
# 20/20 [==============================] - 0s 14ms/sample - loss: 0.0072 - coeff_determination: 0.6220
# Epoch 163/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0071 - coeff_determination: 0.5699
# Epoch 00163: loss improved from 0.00711 to 0.00707, saving model to NAT_BLSTM_PT.h5
# 20/20 [==============================] - 0s 15ms/sample - loss: 0.0071 - coeff_determination: 0.6126
# Epoch 164/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0070 - coeff_determination: 0.5961
# ...
# Epoch 4941/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.5038e-05 - coeff_determination: 0.9987
# Epoch 04941: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 14ms/sample - loss: 3.5182e-05 - coeff_determination: 0.9987
# Epoch 4942/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.4889e-05 - coeff_determination: 0.9986
# Epoch 04942: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 17ms/sample - loss: 3.4806e-05 - coeff_determination: 0.9987
# Epoch 4943/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.5371e-05 - coeff_determination: 0.9987
# Epoch 04943: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.5598e-05 - coeff_determination: 0.9987
# Epoch 4944/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.5664e-05 - coeff_determination: 0.9987
# Epoch 04944: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.5639e-05 - coeff_determination: 0.9986
# Epoch 4945/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.5395e-05 - coeff_determination: 0.9987
# Epoch 04945: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.5492e-05 - coeff_determination: 0.9987
# Epoch 4946/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6519e-05 - coeff_determination: 0.9986
# Epoch 04946: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 20ms/sample - loss: 3.6973e-05 - coeff_determination: 0.9986
# Epoch 4947/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.5929e-05 - coeff_determination: 0.9987
# Epoch 04947: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 20ms/sample - loss: 3.7206e-05 - coeff_determination: 0.9985
# Epoch 4948/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8815e-05 - coeff_determination: 0.9984
# Epoch 04948: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 16ms/sample - loss: 3.8517e-05 - coeff_determination: 0.9985
# Epoch 4949/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8939e-05 - coeff_determination: 0.9986
# Epoch 04949: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 16ms/sample - loss: 3.8641e-05 - coeff_determination: 0.9986
# Epoch 4950/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7986e-05 - coeff_determination: 0.9986
# Epoch 04950: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.7718e-05 - coeff_determination: 0.9986
# Epoch 4951/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6711e-05 - coeff_determination: 0.9986
# Epoch 04951: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 25ms/sample - loss: 3.8076e-05 - coeff_determination: 0.9986
# Epoch 4952/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8442e-05 - coeff_determination: 0.9986
# Epoch 04952: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 24ms/sample - loss: 3.8974e-05 - coeff_determination: 0.9985
# Epoch 4953/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8745e-05 - coeff_determination: 0.9986
# Epoch 04953: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.8452e-05 - coeff_determination: 0.9985
# Epoch 4954/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.9999e-05 - coeff_determination: 0.9985
# Epoch 04954: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.9914e-05 - coeff_determination: 0.9985
# Epoch 4955/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.9445e-05 - coeff_determination: 0.9984
# Epoch 04955: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.9027e-05 - coeff_determination: 0.9985
# Epoch 4956/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7185e-05 - coeff_determination: 0.9986
# Epoch 04956: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 15ms/sample - loss: 3.7286e-05 - coeff_determination: 0.9986
# Epoch 4957/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8211e-05 - coeff_determination: 0.9985
# Epoch 04957: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 15ms/sample - loss: 3.8065e-05 - coeff_determination: 0.9986
# Epoch 4958/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7912e-05 - coeff_determination: 0.9986
# Epoch 04958: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 17ms/sample - loss: 3.8177e-05 - coeff_determination: 0.9986
# Epoch 4959/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6462e-05 - coeff_determination: 0.9988
# Epoch 04959: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 18ms/sample - loss: 3.7280e-05 - coeff_determination: 0.9985
# Epoch 4960/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7673e-05 - coeff_determination: 0.9985
# Epoch 04960: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.7741e-05 - coeff_determination: 0.9986
# Epoch 4961/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7812e-05 - coeff_determination: 0.9984
# Epoch 04961: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 22ms/sample - loss: 3.7245e-05 - coeff_determination: 0.9986
# Epoch 4962/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6369e-05 - coeff_determination: 0.9987
# Epoch 04962: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 19ms/sample - loss: 3.6937e-05 - coeff_determination: 0.9986
# Epoch 4963/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6258e-05 - coeff_determination: 0.9985
# Epoch 04963: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 20ms/sample - loss: 3.6383e-05 - coeff_determination: 0.9986
# Epoch 4964/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6840e-05 - coeff_determination: 0.9986
# Epoch 04964: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 17ms/sample - loss: 3.6951e-05 - coeff_determination: 0.9986
# Epoch 4965/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.9309e-05 - coeff_determination: 0.9984
# Epoch 04965: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 3.9166e-05 - coeff_determination: 0.9985
# Epoch 4966/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0375e-05 - coeff_determination: 0.9985
# Epoch 04966: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 4.0622e-05 - coeff_determination: 0.9985
# Epoch 4967/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0566e-05 - coeff_determination: 0.9986
# Epoch 04967: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 24ms/sample - loss: 4.0230e-05 - coeff_determination: 0.9985
# Epoch 4968/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.1688e-05 - coeff_determination: 0.9985
# Epoch 04968: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 4.1491e-05 - coeff_determination: 0.9985
# Epoch 4969/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0241e-05 - coeff_determination: 0.9985
# Epoch 04969: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 22ms/sample - loss: 4.0611e-05 - coeff_determination: 0.9984
# Epoch 4970/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.9097e-05 - coeff_determination: 0.9984
# Epoch 04970: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 24ms/sample - loss: 3.9331e-05 - coeff_determination: 0.9985
# Epoch 4971/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.9598e-05 - coeff_determination: 0.9985
# Epoch 04971: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 3.9628e-05 - coeff_determination: 0.9985
# Epoch 4972/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0930e-05 - coeff_determination: 0.9984
# Epoch 04972: loss did not improve from 0.00003
# 20/20 [==============================] - 1s 27ms/sample - loss: 4.1045e-05 - coeff_determination: 0.9984
# Epoch 4973/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.4652e-05 - coeff_determination: 0.9984
# Epoch 04973: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 25ms/sample - loss: 4.3698e-05 - coeff_determination: 0.9983
# Epoch 4974/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.1637e-05 - coeff_determination: 0.9984
# Epoch 04974: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 4.2108e-05 - coeff_determination: 0.9984
# Epoch 4975/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0903e-05 - coeff_determination: 0.9985
# Epoch 04975: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 20ms/sample - loss: 4.0859e-05 - coeff_determination: 0.9985
# Epoch 4976/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0544e-05 - coeff_determination: 0.9986
# Epoch 04976: loss did not improve from 0.00003
# 20/20 [==============================] - 1s 26ms/sample - loss: 4.1226e-05 - coeff_determination: 0.9983
# Epoch 4977/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.6940e-05 - coeff_determination: 0.9983
# Epoch 04977: loss did not improve from 0.00003
# 20/20 [==============================] - 1s 26ms/sample - loss: 4.8729e-05 - coeff_determination: 0.9982
# Epoch 4978/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2766e-05 - coeff_determination: 0.9981
# Epoch 04978: loss did not improve from 0.00003
# 20/20 [==============================] - 1s 27ms/sample - loss: 5.0850e-05 - coeff_determination: 0.9981
# Epoch 4979/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.5609e-05 - coeff_determination: 0.9983
# Epoch 04979: loss did not improve from 0.00003
# 20/20 [==============================] - 1s 25ms/sample - loss: 4.6515e-05 - coeff_determination: 0.9982
# Epoch 4980/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.5123e-05 - coeff_determination: 0.9983
# Epoch 04980: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 25ms/sample - loss: 4.4914e-05 - coeff_determination: 0.9983
# Epoch 4981/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.4134e-05 - coeff_determination: 0.9983
# Epoch 04981: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 4.4012e-05 - coeff_determination: 0.9984
# Epoch 4982/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.3160e-05 - coeff_determination: 0.9983
# Epoch 04982: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 25ms/sample - loss: 4.3236e-05 - coeff_determination: 0.9982
# Epoch 4983/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.2262e-05 - coeff_determination: 0.9985
# Epoch 04983: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 22ms/sample - loss: 4.1682e-05 - coeff_determination: 0.9984
# Epoch 4984/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.1667e-05 - coeff_determination: 0.9985
# Epoch 04984: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 4.1494e-05 - coeff_determination: 0.9984
# Epoch 4985/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0374e-05 - coeff_determination: 0.9985
# Epoch 04985: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 4.0615e-05 - coeff_determination: 0.9985
# Epoch 4986/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.1322e-05 - coeff_determination: 0.9984
# Epoch 04986: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 4.1141e-05 - coeff_determination: 0.9984
# Epoch 4987/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0437e-05 - coeff_determination: 0.9984
# Epoch 04987: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 3.9941e-05 - coeff_determination: 0.9985
# Epoch 4988/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8981e-05 - coeff_determination: 0.9985
# Epoch 04988: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 19ms/sample - loss: 3.9527e-05 - coeff_determination: 0.9985
# Epoch 4989/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8172e-05 - coeff_determination: 0.9986
# Epoch 04989: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 19ms/sample - loss: 3.8058e-05 - coeff_determination: 0.9986
# Epoch 4990/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7582e-05 - coeff_determination: 0.9986
# Epoch 04990: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 19ms/sample - loss: 3.8293e-05 - coeff_determination: 0.9986
# Epoch 4991/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7777e-05 - coeff_determination: 0.9986
# Epoch 04991: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.7857e-05 - coeff_determination: 0.9985
# Epoch 4992/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7782e-05 - coeff_determination: 0.9986
# Epoch 04992: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.7483e-05 - coeff_determination: 0.9986
# Epoch 4993/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.7005e-05 - coeff_determination: 0.9986
# Epoch 04993: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 20ms/sample - loss: 3.6677e-05 - coeff_determination: 0.9986
# Epoch 4994/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6706e-05 - coeff_determination: 0.9987
# Epoch 04994: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 21ms/sample - loss: 3.6839e-05 - coeff_determination: 0.9986
# Epoch 4995/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6226e-05 - coeff_determination: 0.9986
# Epoch 04995: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 22ms/sample - loss: 3.6111e-05 - coeff_determination: 0.9987
# Epoch 4996/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.6207e-05 - coeff_determination: 0.9984
# Epoch 04996: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 3.6433e-05 - coeff_determination: 0.9985
# Epoch 4997/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8234e-05 - coeff_determination: 0.9985
# Epoch 04997: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 24ms/sample - loss: 3.8054e-05 - coeff_determination: 0.9985
# Epoch 4998/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 3.8567e-05 - coeff_determination: 0.9984
# Epoch 04998: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 24ms/sample - loss: 3.8812e-05 - coeff_determination: 0.9985
# Epoch 4999/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.2433e-05 - coeff_determination: 0.9983
# Epoch 04999: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 22ms/sample - loss: 4.2648e-05 - coeff_determination: 0.9983
# Epoch 5000/5000
# 16/20 [=======================>......] - ETA: 0s - loss: 4.0428e-05 - coeff_determination: 0.9985
# Epoch 05000: loss did not improve from 0.00003
# 20/20 [==============================] - 0s 23ms/sample - loss: 3.9829e-05 - coeff_determination: 0.9985

# %%
print('Time elapsed:',end_time-start_time)
# Out:
# Time elapsed: 1637.2789919376373

# %%
# Testing
import matplotlib.pyplot as plt
lstm_model.load_weights(weights_filepath)

filename = '../../SWE_Data/Data/snapshot_matrix_pod_test.npy'
test_data = np.load(filename)[0:64*64,:]
pca_vectors = np.load('../../SWE_Data/PCA_Vectors_q1.npy')[:64*64,:num_modes]

true_pca_evol = coeff_scaler.transform(np.matmul(np.transpose(test_data),pca_vectors))
test_data = np.zeros(shape=(1,num_coeffs+num_ivs,500))
test_data[0,0:num_coeffs,:] = np.transpose(true_pca_evol[:,:])

test_data[0,-2,:] = -1.0/2.7
test_data[0,-1,:] = -1.0/4.0

# %%
pred_pca = lstm_model.predict(test_data[:,:,:burn_in])
pred_pca = np.concatenate((test_data[:,:,:burn_in],pred_pca),axis=-1)

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(12,10))
ax[0,0].plot(test_data[0,0,:],label='True')
ax[0,0].plot(pred_pca[0,0,:],label='Predicted')
ax[0,0].set_title('Mode 1')


ax[1,0].plot(test_data[0,1,:],label='True')
ax[1,0].plot(pred_pca[0,1,:],label='Predicted')
ax[1,0].set_title('Mode 2')

ax[0,1].plot(test_data[0,2,:],label='True')
ax[0,1].plot(pred_pca[0,2,:],label='Predicted')
ax[0,1].set_title('Mode 3')

ax[1,1].plot(test_data[0,3,:],label='True')
ax[1,1].plot(pred_pca[0,3,:],label='Predicted')
ax[1,1].set_title('Mode 4')

plt.tight_layout()
plt.legend()
plt.show()

# %%
# Plotting some contours
# True field
true_rb = np.transpose(coeff_scaler.inverse_transform(true_pca_evol))
true_recon = np.matmul(pca_vectors,true_rb)[:,-2].reshape(64,64)

pred_rb = np.transpose(pred_pca[0,:num_modes,:])
pred_rb = np.transpose(coeff_scaler.inverse_transform(pred_rb))
pred_recon = np.matmul(pca_vectors,pred_rb)[:,-2].reshape(64,64)


fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(12,5))
cx = ax[0].contourf(true_recon)
ax[1].contourf(pred_recon)

fig.colorbar(cx,ax=ax[0],fraction=0.046, pad=0.04)
fig.colorbar(cx,ax=ax[1],fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %%
np.save('Figures/NAT_BLSTM_PT_Preds.npy',pred_pca)
np.save('Figures/NAT_BLSTM_PT_Fields.npy',pred_recon)
